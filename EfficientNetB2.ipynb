# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
from glob import glob
import cv2
from matplotlib import pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate, KFold
from keras.losses import SparseCategoricalCrossentropy, CategoricalCrossentropy
from xgboost import XGBClassifier
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, confusion_matrix, f1_score, precision_score, recall_score, roc_curve, auc
from google.colab import drive
# import glob



from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Importing the dataset

# %%
images_path = {}
images_path["malignant"] = glob("/content/drive/MyDrive/dani/GasHisSDB/160/Abnormal/*.png")
images_path["benign"] = glob("/content/drive/MyDrive/dani/GasHisSDB/160/Normal/*.png")


images_class = {
    'benign' : 0,
    'malignant' : 1
}

import sys

from tensorflow.keras.applications import ResNet50
from keras.models import Model
import keras

pre_trained_models = {}


from tensorflow.keras.applications import EfficientNetB2
import numpy as np


pre_trained_models["EfficientNetB2"] = EfficientNetB2(include_top=False, input_shape=(224, 224, 3), pooling="avg", weights = 'imagenet')
for layer in pre_trained_models["EfficientNetB2"].layers:
    layer.trainable = False


# print(images_path["malignant"])
counter = 0




Y = []
Z = []
pos = 0
for label in images_path:
    counter = 0
    for image_path in images_path[label]:
        # print(counter, ' / ', all)
        counter += 1
        if(1):
          image = cv2.imread(image_path)
          image = cv2.resize(image,(224, 224))
          Z.append(image)
          
          if(counter % 10 == 0):
            temp = np.array(Z)
            

            feature_EfficientNetB0 = pre_trained_models["EfficientNetB2"].predict(temp)
            print(feature_EfficientNetB0)

            for b in feature_EfficientNetB0:
              c = b.tolist()
              if(pos == 0):
                  X =  [c]
              else:
                X.append(c)


              pos += 1
              # print("shapeX:")
              # o = np.array(X)
              # print(o.shape)


           
            
            # print(X)
            Z = []
          

          Y.append(images_class[label])
          # print(sys.getsizeof(X)/1000000)
          print("counter:")
          print(counter)
          print("label:" + label)
        else:
          continue

print(np.size(X))
print(np.size(Y))
# Out:
# Streaming output truncated to the last 5000 lines.
#  ...
#  [-0.14755511 -0.2016253  -0.18239868 ... -0.20449363 -0.22299485
#   -0.24831745]
#  [ 0.30745283 -0.06563765 -0.21577556 ... -0.23188649 -0.1616623
#   -0.09438467]
#  [-0.05490961 -0.18460943 -0.214033   ... -0.16757476 -0.18273257
#   -0.11258955]]
# counter:
# 19000
# label:benign
# counter:
# 19001
# label:benign
# counter:
# 19002
# label:benign
# counter:
# 19003
# label:benign
# counter:
# 19004
# label:benign
# counter:
# 19005
# label:benign
# counter:
# 19006
# label:benign
# counter:
# 19007
# label:benign
# counter:
# 19008
# label:benign
# counter:
# 19009
# label:benign
# [[-0.1523006  -0.18092518 -0.18166408 ... -0.18932569 -0.18162833
#   -0.20891833]
#  [-0.02928322  0.06203378 -0.00828561 ... -0.2052148  -0.21479605
#   -0.12287928]
#  [-0.10105336  0.209682   -0.05853244 ... -0.16858207  0.35017163
#    0.7505755 ]
#  ...
#  [-0.09370636 -0.18939103 -0.16960685 ... -0.19659986 -0.05665943
#   -0.1041083 ]
#  [-0.07965598 -0.13024354  0.24630171 ... -0.24433422 -0.10765254
#   -0.18156247]
#  [-0.08633519  0.20797503 -0.1637025  ... -0.08549222 -0.18054166
#   -0.24292392]]
# counter:
# 19010
# label:benign
# counter:
# 19011
# label:benign
# counter:
# 19012
# label:benign
# counter:
# 19013
# label:benign
# counter:
# 19014
# label:benign
# counter:
# 19015
# label:benign
# counter:
# 19016
# label:benign
# counter:
# 19017
# label:benign
# counter:
# 19018
# label:benign
# counter:
# 19019
# label:benign
# [[-0.06759849 -0.17192477 -0.17454982 ... -0.22287577 -0.21677692
#   -0.0986319 ]
#  [ 0.03106146 -0.14438233 -0.14557245 ... -0.23982342 -0.20859765
#   -0.18492109]
#  [ 0.04762232  0.0877711  -0.12903368 ... -0.1569369  -0.19986437
#   -0.20517978]
#  ...
#  [-0.06604426 -0.05079788 -0.12159402 ... -0.1990151  -0.0710523
#   -0.04175881]
#  [-0.13329765 -0.062985   -0.11558697 ... -0.24251956 -0.23947088
#   -0.2061571 ]
#  [-0.17817512 -0.18505523 -0.19753556 ... -0.17726897 -0.1563512
#   -0.19850801]]
# counter:
# 19020
# label:benign
# counter:
# 19021
# label:benign
# counter:
# 19022
# label:benign
# counter:
# 19023
# label:benign
# counter:
# 19024
# label:benign
# counter:
# 19025
# label:benign
# counter:
# 19026
# label:benign
# counter:
# 19027
# label:benign
# counter:
# 19028
# label:benign
# counter:
# 19029
# label:benign
# [[-0.1719703  -0.15539204 -0.17908038 ... -0.10622628 -0.1616994
#   -0.1990242 ]
#  [-0.11886141 -0.15753007 -0.18226618 ... -0.19307442 -0.1668202
#   -0.22347437]
#  [-0.06632504 -0.07593083  0.02114125 ... -0.22052754  0.13693261
#    0.09877681]
#  ...
#  [-0.2116832  -0.1482123  -0.14671078 ... -0.14951062 -0.18715417
#    0.01211276]
#  [-0.00096876 -0.17712687 -0.11289755 ... -0.25046682 -0.14240487
#   -0.21088254]
#  [-0.09435199 -0.20726374 -0.16894567 ... -0.23642367 -0.235105
#   -0.1633923 ]]
# counter:
# 19030
# label:benign
# counter:
# 19031
# label:benign
# counter:
# 19032
# label:benign
# counter:
# 19033
# label:benign
# counter:
# 19034
# label:benign
# counter:
# 19035
# label:benign
# counter:
# 19036
# label:benign
# counter:
# 19037
# label:benign
# counter:
# 19038
# label:benign
# counter:
# 19039
# label:benign
# [[-0.07018797 -0.07768508 -0.16713223 ... -0.19507308 -0.19757892
#   -0.2298839 ]
#  [ 0.03576812 -0.00588141 -0.13783678 ... -0.17996685 -0.18496767
#   -0.20010541]
#  [ 0.16407791 -0.2277906  -0.09924769 ...  0.08139531 -0.15629528
#   -0.20130585]
#  ...
#  [-0.0906187  -0.19882406 -0.16844812 ... -0.12700573 -0.1552263
#   -0.13007653]
#  [-0.15564595 -0.1220788  -0.20860754 ... -0.17686991 -0.24644968
#   -0.0172891 ]
#  [-0.00859224 -0.19286315 -0.24687667 ... -0.20747074 -0.2466503
#    0.3113734 ]]
# counter:
# 19040
# label:benign
# counter:
# 19041
# label:benign
# counter:
# 19042
# label:benign
# counter:
# 19043
# label:benign
# counter:
# 19044
# label:benign
# counter:
# 19045
# label:benign
# counter:
# 19046
# label:benign
# counter:
# 19047
# label:benign
# counter:
# 19048
# label:benign
# counter:
# 19049
# label:benign
# [[-0.02613381 -0.08485343 -0.17482089 ... -0.09188325 -0.22660828
#    0.36892906]
#  [-0.11065416 -0.14986457 -0.17967547 ... -0.17372683 -0.18964793
#   -0.1985431 ]
#  [ 0.12980443 -0.20638144 -0.17712219 ... -0.23646712 -0.22028273
#   -0.19895056]
#  ...
#  [-0.04534875 -0.20393993 -0.08940502 ... -0.21582463 -0.14019608
#   -0.12292958]
#  [ 0.00934212 -0.13374963 -0.13785625 ... -0.03230935 -0.23901166
#   -0.21762688]
#  [-0.03165491 -0.2158046  -0.07456963 ... -0.22532411 -0.21127823
#   -0.13503823]]
# counter:
# 19050
# label:benign
# counter:
# 19051
# label:benign
# counter:
# 19052
# label:benign
# counter:
# 19053
# label:benign
# counter:
# 19054
# label:benign
# counter:
# 19055
# label:benign
# counter:
# 19056
# label:benign
# counter:
# 19057
# label:benign
# counter:
# 19058
# label:benign
# counter:
# 19059
# label:benign
# [[-0.08880705 -0.21924758 -0.14593095 ... -0.24935316 -0.13752142
#   -0.14934924]
#  [-0.07226361 -0.2394547  -0.14678735 ... -0.23284467 -0.20268206
#    0.01223679]
#  [-0.09956071 -0.04868477 -0.19574335 ... -0.18738338 -0.00471469
#   -0.10209794]
#  ...
#  [-0.11627421 -0.1830834  -0.17909105 ... -0.14624171 -0.2136139
#   -0.18568593]
#  [ 0.06253166 -0.1369611  -0.15924191 ... -0.23574758 -0.19162112
#   -0.13099432]
#  [-0.03286905 -0.1791596  -0.2314614  ... -0.18069331 -0.23524185
#    1.7254516 ]]
# counter:
# 19060
# label:benign
# counter:
# 19061
# label:benign
# counter:
# 19062
# label:benign
# counter:
# 19063
# label:benign
# counter:
# 19064
# label:benign
# counter:
# 19065
# label:benign
# counter:
# 19066
# label:benign
# counter:
# 19067
# label:benign
# counter:
# 19068
# label:benign
# counter:
# 19069
# label:benign
# [[-0.13919291 -0.18521711 -0.16576898 ... -0.21931393 -0.22736265
#   -0.22956823]
#  [-0.06944714 -0.20091617  0.06643461 ... -0.24022408 -0.15565254
#   -0.11261116]
#  [ 0.00143571 -0.14111349 -0.01466924 ... -0.23129039 -0.1670224
#   -0.09187743]
#  ...
#  [-0.02415787  0.09446429 -0.04922912 ... -0.24271926 -0.18368046
#   -0.10624278]
#  [-0.06714284 -0.17623717  0.0311431  ... -0.2382918  -0.21153146
#   -0.14399722]
#  [-0.04898873 -0.16563231 -0.18210371 ... -0.05300716 -0.24598855
#   -0.00981577]]
# counter:
# 19070
# label:benign
# counter:
# 19071
# label:benign
# counter:
# 19072
# label:benign
# counter:
# 19073
# label:benign
# counter:
# 19074
# label:benign
# counter:
# 19075
# label:benign
# counter:
# 19076
# label:benign
# counter:
# 19077
# label:benign
# counter:
# 19078
# label:benign
# counter:
# 19079
# label:benign
# [[ 0.01336343 -0.06279384  0.05600337 ... -0.22437946  0.12223766
#   -0.17759188]
#  [-0.16182393 -0.12730387 -0.19633362 ... -0.07586427 -0.20975907
#   -0.2436047 ]
#  [-0.08729648 -0.15907563 -0.19551851 ... -0.26020536 -0.24470188
#    1.6801525 ]
#  ...
#  [-0.09427678  0.08870307 -0.18476897 ... -0.2249326  -0.2262665
#   -0.0777731 ]
#  [-0.14730853 -0.20478019  0.31730503 ... -0.23683445 -0.16125484
#   -0.12487914]
#  [ 0.06077585 -0.17179535 -0.09498411 ... -0.21498056 -0.18495949
#    0.10506496]]
# counter:
# 19080
# label:benign
# counter:
# 19081
# label:benign
# counter:
# 19082
# label:benign
# counter:
# 19083
# label:benign
# counter:
# 19084
# label:benign
# counter:
# 19085
# label:benign
# counter:
# 19086
# label:benign
# counter:
# 19087
# label:benign
# counter:
# 19088
# label:benign
# counter:
# 19089
# label:benign
# [[-0.17404069 -0.1814885  -0.16193935 ... -0.25571972 -0.24680196
#   -0.05666239]
#  [ 0.04439928 -0.19704652 -0.19311441 ... -0.13209942 -0.23106386
#    0.00607343]
#  [-0.10915849  0.04005815 -0.10408092 ... -0.03267576 -0.19917081
#   -0.17922778]
#  ...
#  [-0.09623199 -0.1787784  -0.2332216  ... -0.16093923 -0.19327696
#    0.62744665]
#  [-0.09944122 -0.15500313  0.1678241  ... -0.21841061 -0.09636332
#    0.25705016]
#  [-0.03226649  0.06693478  0.03946035 ... -0.21964747 -0.19745335
#   -0.14322451]]
# counter:
# 19090
# label:benign
# counter:
# 19091
# label:benign
# counter:
# 19092
# label:benign
# counter:
# 19093
# label:benign
# counter:
# 19094
# label:benign
# counter:
# 19095
# label:benign
# counter:
# 19096
# label:benign
# counter:
# 19097
# label:benign
# counter:
# 19098
# label:benign
# counter:
# 19099
# label:benign
# [[-0.07559977 -0.16608359 -0.05338937 ... -0.23120725 -0.2186473
#    0.49004096]
#  [-0.23480709 -0.19671728 -0.19811712 ... -0.15834117 -0.24339604
#   -0.14980781]
#  [-0.1858654  -0.2047355   0.19726981 ... -0.13723285 -0.13024834
#   -0.19867603]
#  ...
#  [-0.02343336 -0.12139759 -0.18122865 ... -0.12283216 -0.15488946
#   -0.16027641]
#  [-0.11970662 -0.21270199 -0.13810991 ... -0.21938138 -0.25763738
#   -0.16301799]
#  [-0.15166412 -0.07604361 -0.19086957 ... -0.16409323 -0.2340358
#   -0.20224287]]
# counter:
# 19100
# label:benign
# counter:
# 19101
# label:benign
# counter:
# 19102
# label:benign
# counter:
# 19103
# label:benign
# counter:
# 19104
# label:benign
# counter:
# 19105
# label:benign
# counter:
# 19106
# label:benign
# counter:
# 19107
# label:benign
# counter:
# 19108
# label:benign
# counter:
# 19109
# label:benign
# [[ 0.14194404 -0.18369167 -0.17040437 ... -0.05698295 -0.17346737
#   -0.21561898]
#  [-0.02524914 -0.17732705 -0.20485622 ... -0.2006363  -0.22032656
#   -0.14288759]
#  [-0.06826963 -0.17344818 -0.17703398 ... -0.20041642 -0.14253303
#   -0.19075981]
#  ...
#  [-0.13614334 -0.1733822  -0.10229675 ... -0.23412967 -0.20496146
#   -0.15986256]
#  [-0.08481137 -0.11455154 -0.22720572 ... -0.25310823  0.06391505
#    0.24369155]
#  [ 0.02673962 -0.1262991  -0.034097   ... -0.19245398 -0.21597926
#   -0.17250684]]
# counter:
# 19110
# label:benign
# counter:
# 19111
# label:benign
# counter:
# 19112
# label:benign
# counter:
# 19113
# label:benign
# counter:
# 19114
# label:benign
# counter:
# 19115
# label:benign
# counter:
# 19116
# label:benign
# counter:
# 19117
# label:benign
# counter:
# 19118
# label:benign
# counter:
# 19119
# label:benign
# [[ 0.0845129  -0.19978382 -0.18790378 ... -0.21467514 -0.2418061
#    0.19248264]
#  [-0.03492727  0.02802952 -0.11610594 ... -0.2274864  -0.23775811
#   -0.17402819]
#  [-0.04415571 -0.10609104 -0.0880134  ... -0.0961763  -0.25397062
#   -0.1685652 ]
#  ...
#  [-0.12524371 -0.21559346 -0.15012082 ... -0.19898179 -0.21235874
#   -0.05336733]
#  [-0.17722014 -0.06382809  0.5197034  ... -0.23302655 -0.18512918
#   -0.14466444]
#  [ 0.05140626 -0.2002588  -0.12562205 ... -0.14661199 -0.21746458
#   -0.18771152]]
# counter:
# 19120
# label:benign
# counter:
# 19121
# label:benign
# counter:
# 19122
# label:benign
# counter:
# 19123
# label:benign
# counter:
# 19124
# label:benign
# counter:
# 19125
# label:benign
# counter:
# 19126
# label:benign
# counter:
# 19127
# label:benign
# counter:
# 19128
# label:benign
# counter:
# 19129
# label:benign
# [[-0.08752364 -0.26192686  0.24047756 ... -0.25365523 -0.22051686
#   -0.14677016]
#  [-0.11885978  0.10178569 -0.10957357 ... -0.22195695 -0.20760722
#   -0.15183552]
#  [-0.1747511  -0.14594714 -0.20177664 ... -0.20966376 -0.18697014
#    1.110285  ]
#  ...
#  [-0.05358423 -0.19688205 -0.15432726 ... -0.21813163 -0.23234734
#   -0.06401496]
#  [-0.04978207 -0.13934892 -0.20274702 ... -0.07903223 -0.17187779
#    1.024144  ]
#  [-0.10430431 -0.01844259 -0.16650398 ... -0.24809386 -0.21604131
#   -0.13460322]]
# counter:
# 19130
# label:benign
# counter:
# 19131
# label:benign
# counter:
# 19132
# label:benign
# counter:
# 19133
# label:benign
# counter:
# 19134
# label:benign
# counter:
# 19135
# label:benign
# counter:
# 19136
# label:benign
# counter:
# 19137
# label:benign
# counter:
# 19138
# label:benign
# counter:
# 19139
# label:benign
# [[-0.06303066 -0.16835323 -0.18414193 ... -0.14236267 -0.2257862
#   -0.23035967]
#  [-0.11520057 -0.18102276 -0.20460677 ... -0.14677532 -0.25487447
#   -0.23693144]
#  [-0.14578664 -0.22537217 -0.16752434 ... -0.23264097 -0.20767428
#   -0.12903808]
#  ...
#  [-0.11985349 -0.17936695  0.21773387 ... -0.22336967 -0.15776409
#   -0.15502548]
#  [-0.2299843  -0.20037319 -0.18151277 ... -0.14584124 -0.14918944
#   -0.19899705]
#  [ 0.11637921 -0.19105086 -0.1878625  ... -0.1994897  -0.15758608
#   -0.11060194]]
# counter:
# 19140
# label:benign
# counter:
# 19141
# label:benign
# counter:
# 19142
# label:benign
# counter:
# 19143
# label:benign
# counter:
# 19144
# label:benign
# counter:
# 19145
# label:benign
# counter:
# 19146
# label:benign
# counter:
# 19147
# label:benign
# counter:
# 19148
# label:benign
# counter:
# 19149
# label:benign
# [[-3.4516364e-02 -1.8744105e-01 -1.8135518e-01 ... -2.2767091e-01
#   -1.6267028e-01 -2.4761187e-02]
#  [-1.2231055e-01 -1.8254223e-01 -2.1585511e-01 ... -2.3015088e-01
#   -2.2866546e-01 -2.1061887e-01]
#  [ 1.9802022e-01 -1.4992025e-01  1.8402952e-01 ... -4.8656366e-04
#    1.0594914e-01 -2.2098641e-01]
#  ...
#  [ 2.3580894e-01 -1.7848499e-01 -1.2462884e-01 ... -1.0382105e-02
#   -2.0158817e-01 -4.3128330e-02]
#  [-1.0694081e-01 -2.1139114e-01 -1.2481826e-01 ... -2.0120576e-01
#   -2.3109294e-01 -6.4164676e-02]
#  [-1.1226109e-02 -2.0318490e-01 -2.4812296e-01 ... -2.0308521e-01
#   -2.0619945e-01  1.0778354e+00]]
# counter:
# 19150
# label:benign
# counter:
# 19151
# label:benign
# counter:
# 19152
# label:benign
# counter:
# 19153
# label:benign
# counter:
# 19154
# label:benign
# counter:
# 19155
# label:benign
# counter:
# 19156
# label:benign
# counter:
# 19157
# label:benign
# counter:
# 19158
# label:benign
# counter:
# 19159
# label:benign
# [[-0.05851248 -0.19024913 -0.1679376  ... -0.25686547 -0.08664758
#   -0.12809391]
#  [ 0.16372974 -0.1647056  -0.15329866 ... -0.24374783 -0.15839253
#   -0.11509278]
#  [-0.21962571 -0.17239366 -0.14468664 ... -0.20646866 -0.21305916
#   -0.19926694]
#  ...
#  [ 0.17021936 -0.18376024 -0.00822064 ... -0.12916628 -0.16806778
#   -0.15824534]
#  [-0.12631716 -0.22566497 -0.17188765 ... -0.20635974 -0.23848468
#   -0.22970441]
#  [-0.07516121  0.03737374  0.00228272 ... -0.24019809  0.04807846
#   -0.13493113]]
# counter:
# 19160
# label:benign
# counter:
# 19161
# label:benign
# counter:
# 19162
# label:benign
# counter:
# 19163
# label:benign
# counter:
# 19164
# label:benign
# counter:
# 19165
# label:benign
# counter:
# 19166
# label:benign
# counter:
# 19167
# label:benign
# counter:
# 19168
# label:benign
# counter:
# 19169
# label:benign
# [[-0.18584639 -0.16444474 -0.21578865 ... -0.13815765 -0.24964084
#    0.0961506 ]
#  [-0.05890011  0.33711913 -0.11442766 ... -0.20643866 -0.24868849
#   -0.19379877]
#  [-0.08693022 -0.06576814 -0.02327422 ... -0.2276727  -0.23338097
#   -0.03706086]
#  ...
#  [ 0.02305741 -0.12395515 -0.19926566 ... -0.22865106 -0.0639209
#    0.30607793]
#  [-0.01707758 -0.18589826 -0.14750661 ... -0.23484725 -0.24307182
#   -0.05635542]
#  [-0.05775681 -0.21808541 -0.21854609 ... -0.21522903 -0.17360787
#   -0.19788045]]
# counter:
# 19170
# label:benign
# counter:
# 19171
# label:benign
# counter:
# 19172
# label:benign
# counter:
# 19173
# label:benign
# counter:
# 19174
# label:benign
# counter:
# 19175
# label:benign
# counter:
# 19176
# label:benign
# counter:
# 19177
# label:benign
# counter:
# 19178
# label:benign
# counter:
# 19179
# label:benign
# [[-0.08663375 -0.14365475 -0.08283527 ... -0.24415256 -0.13700269
#   -0.09705378]
#  [-0.08879442 -0.1999019   0.12335142 ... -0.2200398  -0.18557283
#   -0.19170867]
#  [-0.13419405 -0.20342654 -0.18110745 ... -0.16881344 -0.2204408
#   -0.19926387]
#  ...
#  [-0.08552503 -0.21272604 -0.17658354 ... -0.23571518 -0.10066815
#   -0.1693179 ]
#  [-0.15587883 -0.15899545 -0.10491479 ... -0.24011873 -0.19749781
#   -0.07837885]
#  [-0.09463664 -0.16051966 -0.01690919 ... -0.238367   -0.19484545
#   -0.08754289]]
# counter:
# 19180
# label:benign
# counter:
# 19181
# label:benign
# counter:
# 19182
# label:benign
# counter:
# 19183
# label:benign
# counter:
# 19184
# label:benign
# counter:
# 19185
# label:benign
# counter:
# 19186
# label:benign
# counter:
# 19187
# label:benign
# counter:
# 19188
# label:benign
# counter:
# 19189
# label:benign
# [[-0.09383337 -0.16629554 -0.16004813 ... -0.21028145 -0.12268079
#    0.09233382]
#  [-0.12037718 -0.18053502 -0.12023789 ... -0.13320224 -0.2589291
#   -0.20803809]
#  [-0.12141149 -0.17258549 -0.19015802 ... -0.23856771 -0.20946406
#   -0.19014576]
#  ...
#  [-0.14872359 -0.16858533 -0.1215464  ... -0.22477905 -0.1682675
#   -0.10336163]
#  [-0.02795571 -0.16350752  0.05741363 ... -0.23353703 -0.12577996
#   -0.15643248]
#  [-0.07418802 -0.16818106  0.0136088  ... -0.02090803  0.5681654
#    0.31362194]]
# counter:
# 19190
# label:benign
# counter:
# 19191
# label:benign
# counter:
# 19192
# label:benign
# counter:
# 19193
# label:benign
# counter:
# 19194
# label:benign
# counter:
# 19195
# label:benign
# counter:
# 19196
# label:benign
# counter:
# 19197
# label:benign
# counter:
# 19198
# label:benign
# counter:
# 19199
# label:benign
# [[ 0.00233101 -0.19306815 -0.1717077  ... -0.01332389 -0.11209012
#   -0.1775783 ]
#  [-0.22593041 -0.24597776 -0.15379535 ... -0.1599834  -0.21306042
#    0.301864  ]
#  [-0.05553076 -0.15964457 -0.15476733 ... -0.20086043 -0.2282987
#   -0.2245746 ]
#  ...
#  [-0.22939675 -0.1506683  -0.17038257 ...  0.08892377 -0.1963827
#   -0.16401672]
#  [-0.05774719 -0.13532433 -0.10703877 ... -0.15622497 -0.23596764
#   -0.22355796]
#  [-0.06275584 -0.08138721 -0.13013142 ... -0.21114656 -0.21819565
#   -0.20227446]]
# counter:
# 19200
# label:benign
# counter:
# 19201
# label:benign
# counter:
# 19202
# label:benign
# counter:
# 19203
# label:benign
# counter:
# 19204
# label:benign
# counter:
# 19205
# label:benign
# counter:
# 19206
# label:benign
# counter:
# 19207
# label:benign
# counter:
# 19208
# label:benign
# counter:
# 19209
# label:benign
# [[-3.8167164e-02 -6.8779416e-02 -1.5551420e-01 ... -2.0686126e-01
#   -3.0287184e-02  9.9164777e-02]
#  [-5.4629870e-02 -1.9070184e-01 -2.1106365e-01 ... -2.3567168e-01
#    9.5146550e-03 -1.3572600e-01]
#  [-9.6950971e-02 -2.0858233e-01 -1.6839072e-04 ... -2.4031943e-01
#   -2.4771053e-01 -1.8529758e-01]
#  ...
#  [-1.6210841e-01 -1.1200307e-01 -1.7158465e-01 ... -2.3877746e-01
#   -2.1336104e-01 -2.1250771e-01]
#  [ 5.0304744e-02 -1.8668403e-01  3.4829536e-01 ... -1.9725551e-01
#   -2.2036675e-01 -1.2393607e-01]
#  [-1.1021130e-01 -1.0507329e-01 -1.5919237e-01 ... -2.2983283e-01
#   -4.6401661e-02 -2.1424477e-01]]
# counter:
# 19210
# label:benign
# counter:
# 19211
# label:benign
# counter:
# 19212
# label:benign
# counter:
# 19213
# label:benign
# counter:
# 19214
# label:benign
# counter:
# 19215
# label:benign
# counter:
# 19216
# label:benign
# counter:
# 19217
# label:benign
# counter:
# 19218
# label:benign
# counter:
# 19219
# label:benign
# [[-0.1142419  -0.11363503 -0.17750672 ... -0.24010418 -0.14319281
#   -0.11014843]
#  [-0.04819492  0.09094054 -0.13930228 ... -0.1634289  -0.23271883
#   -0.16079393]
#  [-0.04269119 -0.01400533  0.16414523 ... -0.24610622 -0.22573371
#   -0.11115623]
#  ...
#  [-0.1719576  -0.16157216 -0.23670106 ... -0.14565921 -0.21868649
#    0.19192208]
#  [ 0.0342679   0.35251722  0.21431796 ... -0.18149768 -0.21377602
#   -0.10661526]
#  [ 0.02605292  0.02691701 -0.00186526 ... -0.07743628 -0.14476933
#    0.5042934 ]]
# counter:
# 19220
# label:benign
# counter:
# 19221
# label:benign
# counter:
# 19222
# label:benign
# counter:
# 19223
# label:benign
# counter:
# 19224
# label:benign
# counter:
# 19225
# label:benign
# counter:
# 19226
# label:benign
# counter:
# 19227
# label:benign
# counter:
# 19228
# label:benign
# counter:
# 19229
# label:benign
# [[-0.09859777 -0.18075195 -0.1957293  ... -0.23093012 -0.21544906
#   -0.03036135]
#  [-0.20908572 -0.19627216 -0.21038991 ... -0.17379805 -0.20950513
#    0.03980516]
#  [-0.01413468 -0.16913795 -0.20821495 ... -0.22926396 -0.19759281
#   -0.15781814]
#  ...
#  [-0.04208089 -0.22962894 -0.18726087 ... -0.1726148  -0.2340409
#   -0.09290215]
#  [-0.07382867 -0.2031306  -0.22215074 ... -0.2535186  -0.23129496
#   -0.14390688]
#  [-0.2152101  -0.1939204  -0.17340776 ... -0.20900571 -0.20813307
#   -0.1027723 ]]
# counter:
# 19230
# label:benign
# counter:
# 19231
# label:benign
# counter:
# 19232
# label:benign
# counter:
# 19233
# label:benign
# counter:
# 19234
# label:benign
# counter:
# 19235
# label:benign
# counter:
# 19236
# label:benign
# counter:
# 19237
# label:benign
# counter:
# 19238
# label:benign
# counter:
# 19239
# label:benign
# [[-0.12796238 -0.10123979 -0.09175883 ... -0.24033675  0.45889795
#   -0.07099891]
#  [-0.152374   -0.10687888 -0.0654029  ... -0.25678328 -0.11859033
#   -0.21597797]
#  [-0.07500856 -0.21109875 -0.16968554 ... -0.21060105 -0.22025833
#   -0.19054443]
#  ...
#  [-0.09926719  0.21938393 -0.11095311 ... -0.22688544 -0.10389394
#   -0.1799651 ]
#  [ 0.48579535 -0.18323983 -0.16536812 ... -0.22505666 -0.11197136
#   -0.10230895]
#  [-0.08157384  0.03385255 -0.13460551 ... -0.20753579 -0.14827059
#   -0.11213722]]
# counter:
# 19240
# label:benign
# counter:
# 19241
# label:benign
# counter:
# 19242
# label:benign
# counter:
# 19243
# label:benign
# counter:
# 19244
# label:benign
# counter:
# 19245
# label:benign
# counter:
# 19246
# label:benign
# counter:
# 19247
# label:benign
# counter:
# 19248
# label:benign
# counter:
# 19249
# label:benign
# [[-0.14558202 -0.17037438 -0.07610925 ... -0.1217006  -0.217081
#    0.20581791]
#  [-0.10854115 -0.14312954 -0.11338101 ... -0.26271892 -0.21340726
#   -0.16806991]
#  [-0.03425042 -0.20570719 -0.24219933 ... -0.1054258  -0.2175276
#   -0.09146006]
#  ...
#  [ 0.00918632 -0.18690968 -0.15958549 ... -0.22136395 -0.20919439
#   -0.04666106]
#  [-0.10298628 -0.09839946  0.01256562 ... -0.23164132 -0.13881885
#   -0.1896609 ]
#  [ 0.07720463  0.03186796 -0.09283327 ...  0.05245781 -0.10060559
#   -0.10909191]]
# counter:
# 19250
# label:benign
# counter:
# 19251
# label:benign
# counter:
# 19252
# label:benign
# counter:
# 19253
# label:benign
# counter:
# 19254
# label:benign
# counter:
# 19255
# label:benign
# counter:
# 19256
# label:benign
# counter:
# 19257
# label:benign
# counter:
# 19258
# label:benign
# counter:
# 19259
# label:benign
# [[-0.02131706 -0.17035346 -0.1495324  ... -0.24486989 -0.21127304
#   -0.12963818]
#  [ 0.06844384 -0.1793859  -0.0059752  ...  0.14195621 -0.23791002
#   -0.23949794]
#  [ 0.00239038 -0.23463057 -0.15904927 ... -0.25077707 -0.17906807
#   -0.21287782]
#  ...
#  [-0.13909602 -0.13470641 -0.17548461 ... -0.11448237 -0.20483582
#   -0.18644446]
#  [-0.05747131 -0.02635266 -0.19718166 ... -0.23148035 -0.1896168
#   -0.09693512]
#  [-0.10635874 -0.15993282 -0.16992633 ... -0.18077843 -0.18185806
#   -0.10899853]]
# counter:
# 19260
# label:benign
# counter:
# 19261
# label:benign
# counter:
# 19262
# label:benign
# counter:
# 19263
# label:benign
# counter:
# 19264
# label:benign
# counter:
# 19265
# label:benign
# counter:
# 19266
# label:benign
# counter:
# 19267
# label:benign
# counter:
# 19268
# label:benign
# counter:
# 19269
# label:benign
# [[-0.1500515  -0.19843648 -0.16331793 ... -0.19872124 -0.23447528
#   -0.04397883]
#  [ 0.02004069 -0.1765978  -0.21224748 ... -0.19424528 -0.21081828
#    0.28244597]
#  [-0.18320777 -0.02240261 -0.00548455 ... -0.2344727  -0.14902748
#   -0.16256288]
#  ...
#  [-0.09490415 -0.2018373  -0.08857224 ... -0.20483585 -0.20223412
#   -0.2235569 ]
#  [-0.09072012 -0.14609039 -0.01882161 ... -0.2608175  -0.24837966
#   -0.12757327]
#  [-0.05132312 -0.1678256  -0.17083767 ... -0.25544143 -0.2495886
#   -0.10477143]]
# counter:
# 19270
# label:benign
# counter:
# 19271
# label:benign
# counter:
# 19272
# label:benign
# counter:
# 19273
# label:benign
# counter:
# 19274
# label:benign
# counter:
# 19275
# label:benign
# counter:
# 19276
# label:benign
# counter:
# 19277
# label:benign
# counter:
# 19278
# label:benign
# counter:
# 19279
# label:benign
# [[ 0.06202742 -0.20208615 -0.20562382 ... -0.12534595 -0.0591712
#   -0.1658353 ]
#  [-0.21838288 -0.142979   -0.19010665 ... -0.20484746 -0.19451639
#    0.07843368]
#  [-0.07973613 -0.13984166 -0.03009146 ... -0.20995554 -0.18504213
#   -0.07828379]
#  ...
#  [-0.10417684 -0.19215779 -0.18701987 ... -0.23556896 -0.18105139
#   -0.22685024]
#  [-0.2157497  -0.17651457 -0.17613724 ... -0.14763655 -0.15217051
#   -0.12636684]
#  [-0.085917   -0.18098578 -0.14491941 ... -0.01566512 -0.18244915
#   -0.04351807]]
# counter:
# 19280
# label:benign
# counter:
# 19281
# label:benign
# counter:
# 19282
# label:benign
# counter:
# 19283
# label:benign
# counter:
# 19284
# label:benign
# counter:
# 19285
# label:benign
# counter:
# 19286
# label:benign
# counter:
# 19287
# label:benign
# counter:
# 19288
# label:benign
# counter:
# 19289
# label:benign
# [[-0.04515385 -0.2105339  -0.03621265 ... -0.15590829 -0.1989198
#   -0.1695477 ]
#  [-0.13356571  0.07155841 -0.06084065 ... -0.23319602 -0.19292909
#    0.24498959]
#  [ 0.24176392 -0.19108087 -0.14726572 ... -0.18323377 -0.19441114
#   -0.13492611]
#  ...
#  [-0.11675452 -0.152992    0.45467225 ... -0.16505934 -0.08541788
#   -0.19765338]
#  [-0.12202316 -0.13980581 -0.15840732 ... -0.20147859 -0.22109471
#    0.03341619]
#  [-0.1458528  -0.22995111 -0.08928241 ... -0.23749092 -0.02786023
#   -0.0578344 ]]
# counter:
# 19290
# label:benign
# counter:
# 19291
# label:benign
# counter:
# 19292
# label:benign
# counter:
# 19293
# label:benign
# counter:
# 19294
# label:benign
# counter:
# 19295
# label:benign
# counter:
# 19296
# label:benign
# counter:
# 19297
# label:benign
# counter:
# 19298
# label:benign
# counter:
# 19299
# label:benign
# [[ 0.10513834 -0.2316567  -0.1757043  ... -0.24645577 -0.22286262
#   -0.08157744]
#  [-0.03667945  0.1832266  -0.0164009  ... -0.2109347  -0.13839704
#    0.44600713]
#  [-0.07144351 -0.19937451 -0.22588857 ... -0.16503218 -0.23372254
#    0.25558916]
#  ...
#  [-0.01899482 -0.22713093 -0.0842531  ... -0.22616406 -0.19326091
#    0.40778902]
#  [-0.08170652 -0.22942507 -0.16959964 ... -0.19174987 -0.2530656
#   -0.12072869]
#  [-0.12021542 -0.22472574  0.07395061 ... -0.2278998  -0.19700177
#   -0.17606315]]
# counter:
# 19300
# label:benign
# counter:
# 19301
# label:benign
# counter:
# 19302
# label:benign
# counter:
# 19303
# label:benign
# counter:
# 19304
# label:benign
# counter:
# 19305
# label:benign
# counter:
# 19306
# label:benign
# counter:
# 19307
# label:benign
# counter:
# 19308
# label:benign
# counter:
# 19309
# label:benign
# [[-0.10901821 -0.15862884 -0.19499657 ... -0.08692611 -0.23945728
#   -0.17336547]
#  [-0.19833861 -0.19057724 -0.18148644 ... -0.11407916 -0.21173956
#    0.53851867]
#  [-0.09552355 -0.15332305 -0.16294128 ... -0.13516915 -0.19717933
#    0.05607309]
#  ...
#  [ 0.0228938  -0.24060616 -0.16455325 ... -0.24425755 -0.24899895
#   -0.17350522]
#  [-0.08000537 -0.21563306 -0.18248045 ... -0.1706578  -0.19776268
#   -0.18889426]
#  [-0.08676497 -0.2263841  -0.10893197 ... -0.24315482 -0.04681779
#   -0.2044054 ]]
# counter:
# 19310
# label:benign
# counter:
# 19311
# label:benign
# counter:
# 19312
# label:benign
# counter:
# 19313
# label:benign
# counter:
# 19314
# label:benign
# counter:
# 19315
# label:benign
# counter:
# 19316
# label:benign
# counter:
# 19317
# label:benign
# counter:
# 19318
# label:benign
# counter:
# 19319
# label:benign
# [[-0.11032323 -0.22690575  0.05036505 ... -0.20817088  0.02226789
#   -0.19132549]
#  [-0.11855832 -0.1631069  -0.16376188 ... -0.24775465 -0.24358413
#   -0.06110171]
#  [-0.00887349 -0.19164567 -0.2126079  ... -0.11178678 -0.16196835
#    0.3109028 ]
#  ...
#  [-0.06506447 -0.19854239 -0.09887578 ... -0.1629683  -0.21626455
#   -0.21951492]
#  [-0.14009455 -0.21801732 -0.0971064  ... -0.21952784 -0.22033376
#   -0.01872265]
#  [-0.1143864  -0.16182977 -0.15517433 ... -0.21355055 -0.24418037
#    0.11262329]]
# counter:
# 19320
# label:benign
# counter:
# 19321
# label:benign
# counter:
# 19322
# label:benign
# counter:
# 19323
# label:benign
# counter:
# 19324
# label:benign
# counter:
# 19325
# label:benign
# counter:
# 19326
# label:benign
# counter:
# 19327
# label:benign
# counter:
# 19328
# label:benign
# counter:
# 19329
# label:benign
# [[-0.00413081 -0.1326955  -0.24819474 ...  0.4504944  -0.15509067
#    0.27508947]
#  [-0.11535197 -0.0487109  -0.13028842 ... -0.06567291 -0.24812844
#   -0.0757406 ]
#  [-0.20441093 -0.07598918 -0.15050235 ... -0.13861644 -0.26231956
#   -0.20351338]
#  ...
#  [-0.18737106 -0.20504022 -0.13844784 ... -0.2447085  -0.22281715
#   -0.0598953 ]
#  [-0.02042887 -0.20333709  0.08208487 ... -0.2295321  -0.19701129
#   -0.14315076]
#  [-0.04643289 -0.03676977  0.19402786 ... -0.05363082  0.02760068
#   -0.14054048]]
# counter:
# 19330
# label:benign
# counter:
# 19331
# label:benign
# counter:
# 19332
# label:benign
# counter:
# 19333
# label:benign
# counter:
# 19334
# label:benign
# counter:
# 19335
# label:benign
# counter:
# 19336
# label:benign
# counter:
# 19337
# label:benign
# counter:
# 19338
# label:benign
# counter:
# 19339
# label:benign
# [[-0.18482369  0.107335   -0.01239016 ... -0.22464383 -0.02438921
#   -0.11845125]
#  [ 0.00612728 -0.16973165 -0.15146528 ... -0.21759702 -0.18778694
#   -0.21625604]
#  [-0.09423351 -0.22581838 -0.14274192 ... -0.19135395 -0.22685586
#   -0.21086968]
#  ...
#  [ 0.02422822 -0.1940193  -0.16934185 ... -0.15036643 -0.2378137
#   -0.14854948]
#  [-0.10011408 -0.19211775 -0.19745564 ... -0.19588952 -0.2249768
#    0.6563757 ]
#  [-0.04670785 -0.17753015 -0.1486177  ... -0.12360561 -0.24114859
#   -0.17320526]]
# counter:
# 19340
# label:benign
# counter:
# 19341
# label:benign
# counter:
# 19342
# label:benign
# counter:
# 19343
# label:benign
# counter:
# 19344
# label:benign
# counter:
# 19345
# label:benign
# counter:
# 19346
# label:benign
# counter:
# 19347
# label:benign
# counter:
# 19348
# label:benign
# counter:
# 19349
# label:benign
# [[-0.0808004  -0.12320805  0.06962751 ... -0.20485206  0.06027932
#    0.04594137]
#  [ 0.08499092 -0.16702619 -0.19181927 ... -0.19428241 -0.17928122
#   -0.22480856]
#  [-0.12950101 -0.24035926 -0.20550784 ... -0.14024083 -0.16236784
#   -0.18028016]
#  ...
#  [-0.15886597 -0.20718582 -0.15855701 ... -0.23225592 -0.23645586
#    0.0162824 ]
#  [-0.05256388 -0.17278647 -0.18539174 ... -0.23101628 -0.14912592
#   -0.04254739]
#  [-0.07599862 -0.19193634  0.24341267 ... -0.1744772   0.00544514
#    0.12163582]]
# counter:
# 19350
# label:benign
# counter:
# 19351
# label:benign
# counter:
# 19352
# label:benign
# counter:
# 19353
# label:benign
# counter:
# 19354
# label:benign
# counter:
# 19355
# label:benign
# counter:
# 19356
# label:benign
# counter:
# 19357
# label:benign
# counter:
# 19358
# label:benign
# counter:
# 19359
# label:benign
# [[ 0.01282126 -0.17538886  0.00925298 ... -0.24404748  0.06028643
#   -0.18270974]
#  [-0.08017252 -0.19363561  0.15116724 ... -0.23953825 -0.21074237
#   -0.0723424 ]
#  [-0.09204964 -0.22603984 -0.1473099  ... -0.19177112 -0.17600179
#   -0.05673838]
#  ...
#  [-0.01842012 -0.16428769 -0.2289243  ... -0.18863966 -0.2450706
#    1.1035275 ]
#  [-0.06220693 -0.22937456 -0.12410948 ... -0.24645627 -0.11951384
#   -0.23755123]
#  [-0.05027258 -0.22324471 -0.14028753 ... -0.2466998  -0.20786776
#    0.12744099]]
# counter:
# 19360
# label:benign
# counter:
# 19361
# label:benign
# counter:
# 19362
# label:benign
# counter:
# 19363
# label:benign
# counter:
# 19364
# label:benign
# counter:
# 19365
# label:benign
# counter:
# 19366
# label:benign
# counter:
# 19367
# label:benign
# counter:
# 19368
# label:benign
# counter:
# 19369
# label:benign
# [[-0.02929512 -0.21433741 -0.20270704 ... -0.23420544 -0.21897131
#   -0.10430878]
#  [ 0.01628887 -0.04704429 -0.18606995 ... -0.20564316 -0.2062709
#   -0.1123518 ]
#  [-0.01275691  0.0232156  -0.18190187 ...  0.0107568  -0.1531085
#   -0.0898333 ]
#  ...
#  [-0.07400551 -0.15375768 -0.19465597 ... -0.16963863 -0.21419105
#   -0.20805675]
#  [-0.03082342 -0.07909359 -0.07452268 ... -0.21119322 -0.2301834
#   -0.11935738]
#  [-0.14200978 -0.19724828 -0.16509327 ... -0.17874236 -0.19226849
#   -0.05234328]]
# counter:
# 19370
# label:benign
# counter:
# 19371
# label:benign
# counter:
# 19372
# label:benign
# counter:
# 19373
# label:benign
# counter:
# 19374
# label:benign
# counter:
# 19375
# label:benign
# counter:
# 19376
# label:benign
# counter:
# 19377
# label:benign
# counter:
# 19378
# label:benign
# counter:
# 19379
# label:benign
# [[ 0.10177408 -0.17758256 -0.13004863 ...  0.08932669 -0.15846905
#   -0.23284252]
#  [-0.13377133  0.22626017 -0.03928227 ... -0.18778455 -0.21146677
#    0.01445155]
#  [-0.14645018  0.31642878 -0.09599    ... -0.247226   -0.04718157
#    0.03923071]
#  ...
#  [-0.0493363   0.2304243  -0.19148844 ... -0.13765931 -0.20593625
#    0.00252973]
#  [-0.04853406 -0.06248368 -0.0210705  ... -0.09154764 -0.13486566
#   -0.14083037]
#  [-0.13934709 -0.08229964 -0.14722104 ... -0.21331617 -0.19476682
#   -0.19384415]]
# counter:
# 19380
# label:benign
# counter:
# 19381
# label:benign
# counter:
# 19382
# label:benign
# counter:
# 19383
# label:benign
# counter:
# 19384
# label:benign
# counter:
# 19385
# label:benign
# counter:
# 19386
# label:benign
# counter:
# 19387
# label:benign
# counter:
# 19388
# label:benign
# counter:
# 19389
# label:benign
# [[-0.05988424  0.14826247  0.16334021 ... -0.19809741  0.02400151
#    0.27302426]
#  [ 0.00749892 -0.20795618 -0.19198939 ... -0.24413073 -0.20140584
#    0.04458327]
#  [ 0.06829865 -0.2337167  -0.1312901  ... -0.23263946 -0.19302216
#   -0.20429868]
#  ...
#  [-0.10014951 -0.1446687   0.27057686 ... -0.24137639  0.05751912
#   -0.08552088]
#  [-0.05540719 -0.14476262 -0.11179601 ... -0.03001965 -0.23510928
#   -0.2408915 ]
#  [-0.11941752 -0.23644555 -0.04487926 ... -0.25958148 -0.06454732
#   -0.19021262]]
# counter:
# 19390
# label:benign
# counter:
# 19391
# label:benign
# counter:
# 19392
# label:benign
# counter:
# 19393
# label:benign
# counter:
# 19394
# label:benign
# counter:
# 19395
# label:benign
# counter:
# 19396
# label:benign
# counter:
# 19397
# label:benign
# counter:
# 19398
# label:benign
# counter:
# 19399
# label:benign
# [[ 0.5960558  -0.21088646  0.01002584 ... -0.20959607 -0.20995572
#   -0.09970346]
#  [-0.0451128  -0.20982346 -0.2354152  ... -0.2534997  -0.18248111
#    0.50815415]
#  [-0.06842407 -0.20790799 -0.14035864 ... -0.14676136 -0.22999084
#   -0.2168487 ]
#  ...
#  [-0.07666457 -0.145555   -0.21793695 ... -0.2241909  -0.24399672
#    0.7701365 ]
#  [ 0.02579701  0.45291686 -0.07666986 ... -0.20634481 -0.21302047
#   -0.08519199]
#  [-0.07225318  0.00145904  0.01674321 ... -0.21933767 -0.20090231
#   -0.15060808]]
# counter:
# 19400
# label:benign
# counter:
# 19401
# label:benign
# counter:
# 19402
# label:benign
# counter:
# 19403
# label:benign
# counter:
# 19404
# label:benign
# counter:
# 19405
# label:benign
# counter:
# 19406
# label:benign
# counter:
# 19407
# label:benign
# counter:
# 19408
# label:benign
# counter:
# 19409
# label:benign
# [[-7.09524900e-02  3.15617435e-02 -1.65095657e-01 ... -2.48399079e-01
#   -1.78872049e-01 -2.55721956e-01]
#  [-1.16616383e-01 -1.93863720e-01 -2.15879694e-01 ... -4.05688584e-02
#   -2.25341424e-01  1.25755858e+00]
#  [-1.76309973e-01 -1.13186613e-01 -2.10264072e-01 ... -1.81895137e-01
#   -2.30870008e-01  7.79542550e-02]
#  ...
#  [ 1.09143546e-02 -1.24225065e-01 -3.82353105e-02 ... -2.38320112e-01
#    9.32330787e-02 -1.53795704e-01]
#  [-3.09457573e-05 -2.37793908e-01  3.76942724e-01 ... -1.99461833e-01
#   -9.11441147e-02 -2.09522620e-01]
#  [-1.06489636e-01 -2.01500386e-01 -1.95443988e-01 ... -2.34750599e-01
#   -2.27548167e-01 -2.37436593e-01]]
# counter:
# 19410
# label:benign
# counter:
# 19411
# label:benign
# counter:
# 19412
# label:benign
# counter:
# 19413
# label:benign
# counter:
# 19414
# label:benign
# counter:
# 19415
# label:benign
# counter:
# 19416
# label:benign
# counter:
# 19417
# label:benign
# counter:
# 19418
# label:benign
# counter:
# 19419
# label:benign
# [[-0.10947724 -0.19565006  0.04731913 ... -0.20591855 -0.07793474
#   -0.1081415 ]
#  [ 0.03939825 -0.01445817 -0.18365738 ... -0.24705213 -0.20355847
#   -0.13099208]
#  [-0.00824803  0.17739266  0.123905   ... -0.18108362 -0.1230837
#   -0.03395238]
#  ...
#  [-0.20014897 -0.17510387 -0.1917446  ... -0.13887458 -0.18561223
#   -0.07097911]
#  [ 0.03277677 -0.05157722 -0.1444162  ... -0.18918064 -0.19835722
#   -0.03657364]
#  [ 0.0437082  -0.21448553 -0.11319774 ... -0.14975886 -0.18483195
#   -0.1819604 ]]
# counter:
# 19420
# label:benign
# counter:
# 19421
# label:benign
# counter:
# 19422
# label:benign
# counter:
# 19423
# label:benign
# counter:
# 19424
# label:benign
# counter:
# 19425
# label:benign
# counter:
# 19426
# label:benign
# counter:
# 19427
# label:benign
# counter:
# 19428
# label:benign
# counter:
# 19429
# label:benign
# [[-0.12035863 -0.18004678 -0.18337114 ... -0.07602893 -0.21032679
#    0.03100478]
#  [-0.1718094  -0.1973831  -0.10923813 ... -0.24059601 -0.236041
#   -0.20190397]
#  [-0.01882024 -0.14607282 -0.17762992 ... -0.2114172  -0.2432668
#   -0.13749321]
#  ...
#  [-0.09437273 -0.22290601 -0.13606964 ... -0.23192355 -0.19597049
#   -0.220065  ]
#  [-0.17692593 -0.20508611 -0.18143296 ... -0.18904354 -0.22429359
#   -0.192247  ]
#  [-0.11876194 -0.18545708 -0.18992311 ... -0.21446925 -0.21970719
#   -0.03568714]]
# counter:
# 19430
# label:benign
# counter:
# 19431
# label:benign
# counter:
# 19432
# label:benign
# counter:
# 19433
# label:benign
# counter:
# 19434
# label:benign
# counter:
# 19435
# label:benign
# counter:
# 19436
# label:benign
# counter:
# 19437
# label:benign
# counter:
# 19438
# label:benign
# counter:
# 19439
# label:benign
# [[ 0.05602944 -0.06010526 -0.1083696  ... -0.22303692 -0.21114042
#    0.01022768]
#  [-0.03827715 -0.17300169 -0.19527707 ... -0.15989392 -0.21838002
#    0.49896932]
#  [-0.2040632  -0.1293343  -0.12763457 ... -0.20842913 -0.23025158
#   -0.20378849]
#  ...
#  [-0.12530969 -0.20919952  0.1426981  ... -0.2108397  -0.20057641
#    0.02538297]
#  [-0.23731452 -0.08691984 -0.05536718 ... -0.20791046 -0.1307656
#   -0.19776766]
#  [-0.08598493 -0.10257629 -0.16486531 ... -0.20910248 -0.22121066
#   -0.15360837]]
# counter:
# 19440
# label:benign
# counter:
# 19441
# label:benign
# counter:
# 19442
# label:benign
# counter:
# 19443
# label:benign
# counter:
# 19444
# label:benign
# counter:
# 19445
# label:benign
# counter:
# 19446
# label:benign
# counter:
# 19447
# label:benign
# counter:
# 19448
# label:benign
# counter:
# 19449
# label:benign
# [[ 0.03570173 -0.17084889 -0.18191676 ... -0.21784934 -0.21931049
#    0.3447047 ]
#  [-0.10371234 -0.03903058  0.19905518 ... -0.22341421 -0.13486491
#   -0.19482869]
#  [-0.04009942 -0.12779105 -0.11584987 ... -0.19478285 -0.21832824
#   -0.17629457]
#  ...
#  [-0.13158797  0.02501033 -0.05227287 ... -0.24416631  0.15894854
#   -0.06696475]
#  [-0.14119722 -0.21863243 -0.13421467 ... -0.14024378 -0.19530883
#   -0.05278704]
#  [-0.1136404  -0.20296153 -0.22995676 ... -0.09708891 -0.2340948
#    0.5896081 ]]
# counter:
# 19450
# label:benign
# counter:
# 19451
# label:benign
# counter:
# 19452
# label:benign
# counter:
# 19453
# label:benign
# counter:
# 19454
# label:benign
# counter:
# 19455
# label:benign
# counter:
# 19456
# label:benign
# counter:
# 19457
# label:benign
# counter:
# 19458
# label:benign
# counter:
# 19459
# label:benign
# [[-0.00368529 -0.22488168 -0.1731728  ... -0.21016227 -0.19356315
#    0.21701387]
#  [-0.07569157 -0.19834857  0.011008   ... -0.15307261 -0.20911413
#   -0.22622816]
#  [-0.19610646 -0.2379881  -0.0429868  ... -0.20348333 -0.1652572
#   -0.21669476]
#  ...
#  [ 0.12297475 -0.19917382 -0.08480692 ... -0.23406549 -0.24061571
#   -0.15957758]
#  [-0.08528019 -0.20573376 -0.17018129 ... -0.20621094 -0.23288529
#    0.9659541 ]
#  [-0.00460369 -0.06879836 -0.07856032 ... -0.23515925  0.3332408
#    0.06543341]]
# counter:
# 19460
# label:benign
# counter:
# 19461
# label:benign
# counter:
# 19462
# label:benign
# counter:
# 19463
# label:benign
# counter:
# 19464
# label:benign
# counter:
# 19465
# label:benign
# counter:
# 19466
# label:benign
# counter:
# 19467
# label:benign
# counter:
# 19468
# label:benign
# counter:
# 19469
# label:benign
# [[ 0.02748057 -0.2339571  -0.10114505 ... -0.2094953  -0.22833455
#    0.11499075]
#  [-0.04664142 -0.093053    0.2215903  ... -0.24295317 -0.21166456
#   -0.17571907]
#  [-0.210219   -0.10930274 -0.17201826 ... -0.15362687 -0.21970282
#   -0.0919645 ]
#  ...
#  [ 0.02842498 -0.2236625  -0.18827885 ... -0.17434864 -0.23663202
#   -0.18666145]
#  [-0.0054508  -0.15362294 -0.1964653  ... -0.21634173 -0.23122038
#   -0.21245664]
#  [-0.03790015  0.04434061 -0.18219434 ...  0.04842679 -0.23534639
#   -0.12400249]]
# counter:
# 19470
# label:benign
# counter:
# 19471
# label:benign
# counter:
# 19472
# label:benign
# counter:
# 19473
# label:benign
# counter:
# 19474
# label:benign
# counter:
# 19475
# label:benign
# counter:
# 19476
# label:benign
# counter:
# 19477
# label:benign
# counter:
# 19478
# label:benign
# counter:
# 19479
# label:benign
# [[-0.16988145 -0.21085544 -0.11032937 ... -0.23033738 -0.09007925
#   -0.19776687]
#  [ 0.00151008 -0.23359042 -0.15295805 ... -0.24396034 -0.18546131
#    0.11534188]
#  [-0.11579367 -0.19807845 -0.05137868 ... -0.24597354 -0.11730833
#   -0.08890889]
#  ...
#  [ 0.08078539 -0.2142997  -0.15812574 ... -0.25472727 -0.20837529
#   -0.18547796]
#  [-0.04833387 -0.12400924 -0.22266012 ... -0.2310031  -0.2279669
#    0.5797692 ]
#  [-0.07759243 -0.14582661 -0.0835342  ...  0.08184383 -0.1501683
#   -0.21341904]]
# counter:
# 19480
# label:benign
# counter:
# 19481
# label:benign
# counter:
# 19482
# label:benign
# counter:
# 19483
# label:benign
# counter:
# 19484
# label:benign
# counter:
# 19485
# label:benign
# counter:
# 19486
# label:benign
# counter:
# 19487
# label:benign
# counter:
# 19488
# label:benign
# counter:
# 19489
# label:benign
# [[-7.7997394e-02 -2.5570521e-01 -1.5139550e-01 ... -2.1103318e-01
#   -2.3573092e-01 -1.4586319e-01]
#  [-5.3631268e-02 -1.7376213e-01 -1.4930272e-01 ... -7.7049926e-02
#   -2.3115532e-01 -1.4572076e-01]
#  [-1.4337800e-01 -1.8424988e-01 -1.8928888e-01 ... -2.3331153e-01
#   -2.2393133e-01 -1.3520710e-01]
#  ...
#  [-8.0359913e-02 -2.1186237e-01 -2.2078128e-01 ... -1.8093240e-01
#   -2.2919782e-01 -2.0041846e-01]
#  [-1.7810294e-01 -1.8401971e-01 -1.7688745e-01 ... -2.1787822e-01
#   -1.9722354e-01  9.4724178e-02]
#  [-3.5597355e-04  1.9349475e-01 -3.4530666e-02 ... -2.4671839e-01
#   -1.8834555e-01  9.8976672e-01]]
# counter:
# 19490
# label:benign
# counter:
# 19491
# label:benign
# counter:
# 19492
# label:benign
# counter:
# 19493
# label:benign
# counter:
# 19494
# label:benign
# counter:
# 19495
# label:benign
# counter:
# 19496
# label:benign
# counter:
# 19497
# label:benign
# counter:
# 19498
# label:benign
# counter:
# 19499
# label:benign
# [[-0.07936658  0.18457936 -0.21569806 ... -0.21252798  0.16201732
#    0.11798022]
#  [-0.13245732 -0.18053536 -0.04761608 ... -0.19834048 -0.21212523
#   -0.17666344]
#  [-0.1478241  -0.0563462  -0.03156202 ... -0.17808357 -0.21722808
#   -0.05682626]
#  ...
#  [-0.12834188  0.14994021 -0.17159486 ... -0.21788812 -0.1939523
#   -0.20711738]
#  [-0.01802232  0.10450243 -0.1398899  ... -0.0204676  -0.2154071
#    0.66124886]
#  [ 0.02808243 -0.23357181  0.29736775 ... -0.23319486 -0.16568355
#   -0.13899745]]
# counter:
# 19500
# label:benign
# counter:
# 19501
# label:benign
# counter:
# 19502
# label:benign
# counter:
# 19503
# label:benign
# counter:
# 19504
# label:benign
# counter:
# 19505
# label:benign
# counter:
# 19506
# label:benign
# counter:
# 19507
# label:benign
# counter:
# 19508
# label:benign
# counter:
# 19509
# label:benign
# [[-0.08331286 -0.17653975 -0.14891803 ... -0.09006453 -0.01525192
#    0.03473943]
#  [-0.09168635 -0.04846203 -0.11133796 ... -0.17398098 -0.11938755
#   -0.08756055]
#  [-0.14397874 -0.17381312 -0.14712778 ... -0.1744856  -0.16759223
#   -0.23602232]
#  ...
#  [-0.05938316 -0.1460238  -0.25323832 ... -0.23264651 -0.22931989
#    0.1983788 ]
#  [ 0.04797211 -0.11198867 -0.22406814 ...  0.5299189  -0.1635465
#    0.16450705]
#  [-0.1317071  -0.11610162 -0.2166062  ... -0.08784387 -0.22368571
#    0.0505137 ]]
# counter:
# 19510
# label:benign
# counter:
# 19511
# label:benign
# counter:
# 19512
# label:benign
# counter:
# 19513
# label:benign
# counter:
# 19514
# label:benign
# counter:
# 19515
# label:benign
# counter:
# 19516
# label:benign
# counter:
# 19517
# label:benign
# counter:
# 19518
# label:benign
# counter:
# 19519
# label:benign
# [[-0.16177894 -0.24484907 -0.12256562 ... -0.19714513  0.12890767
#   -0.10978938]
#  [-0.02816916  0.21720664 -0.07788187 ... -0.21979724 -0.19483466
#   -0.18194777]
#  [-0.03044899 -0.21429563 -0.22795047 ... -0.19558734 -0.24414408
#   -0.15685429]
#  ...
#  [ 0.08701015  0.07474986  0.14742492 ... -0.19358477 -0.19967745
#   -0.06419957]
#  [-0.13946763 -0.18691331 -0.18821321 ... -0.23032492 -0.17374383
#   -0.14767471]
#  [-0.07529362 -0.20173784 -0.09489158 ... -0.17852497 -0.12081881
#   -0.15191998]]
# counter:
# 19520
# label:benign
# counter:
# 19521
# label:benign
# counter:
# 19522
# label:benign
# counter:
# 19523
# label:benign
# counter:
# 19524
# label:benign
# counter:
# 19525
# label:benign
# counter:
# 19526
# label:benign
# counter:
# 19527
# label:benign
# counter:
# 19528
# label:benign
# counter:
# 19529
# label:benign
# [[-0.09524631 -0.09585266 -0.16364413 ... -0.22122276 -0.22989732
#   -0.25717503]
#  [-0.06388343 -0.06099567  0.1342127  ...  0.02540061 -0.18491204
#   -0.2151427 ]
#  [ 0.01484986 -0.23436908 -0.13411756 ... -0.06716591 -0.23995665
#   -0.08544572]
#  ...
#  [-0.05695376 -0.11690173 -0.16143796 ... -0.16265911 -0.14676143
#   -0.20071366]
#  [-0.14117736 -0.20352565 -0.15333839 ... -0.24171811 -0.2501527
#   -0.22179528]
#  [ 0.00206009  0.15025026 -0.18566875 ... -0.11939647 -0.22167933
#   -0.16246834]]
# counter:
# 19530
# label:benign
# counter:
# 19531
# label:benign
# counter:
# 19532
# label:benign
# counter:
# 19533
# label:benign
# counter:
# 19534
# label:benign
# counter:
# 19535
# label:benign
# counter:
# 19536
# label:benign
# counter:
# 19537
# label:benign
# counter:
# 19538
# label:benign
# counter:
# 19539
# label:benign
# [[-0.10263739 -0.09674887 -0.11387059 ... -0.06580534 -0.09672788
#   -0.14782378]
#  [-0.06445099 -0.20929103 -0.16720742 ... -0.08568923 -0.24950923
#   -0.08926602]
#  [-0.15069817 -0.24307024 -0.190151   ... -0.21008854 -0.2205927
#   -0.1225066 ]
#  ...
#  [-0.16144045 -0.13119337 -0.15801886 ... -0.16570798 -0.17532499
#   -0.18228243]
#  [ 0.08267225 -0.19982673 -0.13866614 ... -0.25032735 -0.13626625
#   -0.00122648]
#  [ 0.00107643 -0.06530453 -0.09667187 ... -0.10272767 -0.23348483
#   -0.16014934]]
# counter:
# 19540
# label:benign
# counter:
# 19541
# label:benign
# counter:
# 19542
# label:benign
# counter:
# 19543
# label:benign
# counter:
# 19544
# label:benign
# counter:
# 19545
# label:benign
# counter:
# 19546
# label:benign
# counter:
# 19547
# label:benign
# counter:
# 19548
# label:benign
# counter:
# 19549
# label:benign
# [[-0.15425423 -0.1629178  -0.1439288  ... -0.24089217 -0.22090961
#   -0.05281701]
#  [-0.10932608 -0.15108788  0.0167989  ... -0.1901158  -0.11751626
#   -0.1746591 ]
#  [-0.12358442 -0.02665694 -0.02861908 ... -0.21365632 -0.09426066
#   -0.18763517]
#  ...
#  [-0.12792356 -0.16589998 -0.1776975  ... -0.04495349 -0.12185792
#   -0.1744193 ]
#  [-0.14671706 -0.14238454 -0.1674443  ... -0.18996131 -0.19166426
#   -0.20448329]
#  [ 0.00040817 -0.09625632 -0.15473649 ... -0.20660174 -0.14047825
#   -0.1697803 ]]
# counter:
# 19550
# label:benign
# counter:
# 19551
# label:benign
# counter:
# 19552
# label:benign
# counter:
# 19553
# label:benign
# counter:
# 19554
# label:benign
# counter:
# 19555
# label:benign
# counter:
# 19556
# label:benign
# counter:
# 19557
# label:benign
# counter:
# 19558
# label:benign
# counter:
# 19559
# label:benign
# [[-0.07143653  0.01259438 -0.14513579 ... -0.1947939  -0.12974231
#   -0.03824025]
#  [-0.14781146 -0.19247355 -0.2046783  ... -0.23615852 -0.22513275
#    0.33380288]
#  [ 0.01546321 -0.11054077 -0.11637994 ...  0.08962613 -0.15348041
#   -0.03331699]
#  ...
#  [-0.06381034 -0.21798384 -0.00709477 ... -0.25006056 -0.1699271
#   -0.11911565]
#  [-0.06755269  0.02843843 -0.07388923 ... -0.22699712 -0.18125589
#   -0.08293989]
#  [-0.1252023   0.1014837  -0.11668107 ... -0.10914209 -0.17742118
#   -0.10208136]]
# counter:
# 19560
# label:benign
# counter:
# 19561
# label:benign
# counter:
# 19562
# label:benign
# counter:
# 19563
# label:benign
# counter:
# 19564
# label:benign
# counter:
# 19565
# label:benign
# counter:
# 19566
# label:benign
# counter:
# 19567
# label:benign
# counter:
# 19568
# label:benign
# counter:
# 19569
# label:benign
# [[ 0.031114   -0.20301457 -0.17892626 ... -0.2533546  -0.20286249
#   -0.1700603 ]
#  [-0.03897669 -0.04993063 -0.13999239 ... -0.20977432 -0.18120389
#   -0.16179435]
#  [-0.07106514 -0.09949647 -0.12764573 ... -0.01924939 -0.0823931
#   -0.07682609]
#  ...
#  [ 0.00239516 -0.22393121 -0.25281578 ... -0.23318404 -0.258699
#    0.5937487 ]
#  [-0.15120956 -0.14932792 -0.14876625 ... -0.22600207 -0.22445738
#   -0.04391931]
#  [-0.14441012 -0.1700939  -0.02180061 ... -0.06329971 -0.20678659
#   -0.21482241]]
# counter:
# 19570
# label:benign
# counter:
# 19571
# label:benign
# counter:
# 19572
# label:benign
# counter:
# 19573
# label:benign
# counter:
# 19574
# label:benign
# counter:
# 19575
# label:benign
# counter:
# 19576
# label:benign
# counter:
# 19577
# label:benign
# counter:
# 19578
# label:benign
# counter:
# 19579
# label:benign
# [[-0.14570332 -0.2004638  -0.21286589 ... -0.22338085 -0.2052375
#   -0.193465  ]
#  [-0.09475534 -0.20356034 -0.11695354 ...  0.24738279 -0.17820227
#   -0.22471486]
#  [-0.15587924 -0.1913519  -0.14437976 ... -0.23822968 -0.18031603
#   -0.14490014]
#  ...
#  [-0.14589041  0.52790487 -0.05845518 ... -0.21196665 -0.12505583
#   -0.11923708]
#  [ 0.0250299  -0.1312072  -0.04215794 ... -0.00601228 -0.09773091
#   -0.21018639]
#  [-0.01128068 -0.06312764  0.02769669 ... -0.24143423 -0.21311696
#   -0.03117767]]
# counter:
# 19580
# label:benign
# counter:
# 19581
# label:benign
# counter:
# 19582
# label:benign
# counter:
# 19583
# label:benign
# counter:
# 19584
# label:benign
# counter:
# 19585
# label:benign
# counter:
# 19586
# label:benign
# counter:
# 19587
# label:benign
# counter:
# 19588
# label:benign
# counter:
# 19589
# label:benign
# [[-0.05926279  0.04754111  0.2108238  ... -0.16405584 -0.19449654
#   -0.17590669]
#  [-0.15294105 -0.18532583 -0.23759735 ... -0.13005745 -0.18256652
#    0.64600515]
#  [-0.06060376 -0.21367867 -0.13751505 ... -0.21681723 -0.16875859
#    0.0184094 ]
#  ...
#  [ 0.08915898 -0.1139629   0.01157646 ... -0.20280921 -0.21853928
#   -0.1311322 ]
#  [-0.1484224  -0.1308165  -0.19917305 ... -0.22439347 -0.19746257
#    0.50456727]
#  [ 0.03408489 -0.10336298 -0.20238645 ... -0.22581306 -0.23153542
#   -0.03415921]]
# counter:
# 19590
# label:benign
# counter:
# 19591
# label:benign
# counter:
# 19592
# label:benign
# counter:
# 19593
# label:benign
# counter:
# 19594
# label:benign
# counter:
# 19595
# label:benign
# counter:
# 19596
# label:benign
# counter:
# 19597
# label:benign
# counter:
# 19598
# label:benign
# counter:
# 19599
# label:benign
# [[-0.07566271  0.3399396  -0.14406046 ... -0.257836    0.25174323
#    0.16089606]
#  [-0.10213182 -0.06553685  0.20842786 ... -0.25186044 -0.18306668
#   -0.16395804]
#  [-0.04315236 -0.12890433 -0.14888565 ... -0.19782446 -0.20926511
#   -0.19639073]
#  ...
#  [-0.16551816 -0.22709851 -0.19668399 ... -0.1656748  -0.24168402
#   -0.07662894]
#  [-0.09726032 -0.21361826 -0.09519694 ... -0.22833684 -0.21778731
#   -0.01119701]
#  [-0.1964341  -0.2060042  -0.19301452 ... -0.23290735 -0.14115012
#    0.0020282 ]]
# counter:
# 19600
# label:benign
# counter:
# 19601
# label:benign
# counter:
# 19602
# label:benign
# counter:
# 19603
# label:benign
# counter:
# 19604
# label:benign
# counter:
# 19605
# label:benign
# counter:
# 19606
# label:benign
# counter:
# 19607
# label:benign
# counter:
# 19608
# label:benign
# counter:
# 19609
# label:benign
# [[-0.03353672 -0.04221559 -0.07733709 ... -0.22397162 -0.06005037
#    0.89965177]
#  [-0.07007908 -0.17927665 -0.22580227 ... -0.0768552  -0.24494158
#   -0.18598728]
#  [-0.11641578  0.30205816 -0.09563011 ... -0.24721064 -0.12811165
#   -0.14920174]
#  ...
#  [-0.20664044 -0.10031296 -0.1084452  ... -0.17288646 -0.21027271
#   -0.09965023]
#  [-0.2304331  -0.17844431 -0.11922303 ... -0.23631866 -0.25533432
#    0.20543972]
#  [-0.04586674 -0.13424937 -0.24627283 ... -0.13209999 -0.18894969
#   -0.04123875]]
# counter:
# 19610
# label:benign
# counter:
# 19611
# label:benign
# counter:
# 19612
# label:benign
# counter:
# 19613
# label:benign
# counter:
# 19614
# label:benign
# counter:
# 19615
# label:benign
# counter:
# 19616
# label:benign
# ...
#    0.13790023]
#  [ 0.08637457 -0.13665316 -0.13025028 ... -0.20190583 -0.18666497
#    0.0759478 ]
#  [ 0.11900819 -0.19481823 -0.10925385 ... -0.2450705  -0.23111446
#   -0.1269824 ]
#  ...
#  [ 0.18579027 -0.19643873 -0.21422493 ... -0.11788097 -0.20718604
#   -0.22539291]
#  [-0.16158321 -0.15686305 -0.19132958 ... -0.05838261 -0.22746629
#   -0.23547134]
#  [-0.07428909 -0.05062968 -0.19019258 ... -0.16594575 -0.2304385
#   -0.17784406]]
# counter:
# 19960
# label:benign
# counter:
# 19961
# label:benign
# counter:
# 19962
# label:benign
# counter:
# 19963
# label:benign
# counter:
# 19964
# label:benign
# counter:
# 19965
# label:benign
# counter:
# 19966
# label:benign
# counter:
# 19967
# label:benign
# counter:
# 19968
# label:benign
# counter:
# 19969
# label:benign
# [[-0.10946503 -0.12711784 -0.1801211  ... -0.19410235 -0.15894212
#   -0.18719897]
#  [ 0.05500437 -0.04489594 -0.20389676 ... -0.2550962   0.1369269
#   -0.0048308 ]
#  [ 0.00296381 -0.07071272 -0.21930805 ... -0.2312229  -0.22603434
#   -0.11217436]
#  ...
#  [-0.03612639 -0.02171583 -0.09991439 ... -0.19114083 -0.23055439
#    1.1081297 ]
#  [-0.0573676  -0.05896632 -0.09577523 ... -0.15341614 -0.2333409
#   -0.19805472]
#  [-0.00691414 -0.22039895 -0.17553882 ... -0.2421444  -0.2351059
#    0.03790686]]
# counter:
# 19970
# label:benign
# counter:
# 19971
# label:benign
# counter:
# 19972
# label:benign
# counter:
# 19973
# label:benign
# counter:
# 19974
# label:benign
# counter:
# 19975
# label:benign
# counter:
# 19976
# label:benign
# counter:
# 19977
# label:benign
# counter:
# 19978
# label:benign
# counter:
# 19979
# label:benign
# [[-0.08898291 -0.13769805 -0.21601602 ... -0.22460079 -0.16531774
#    0.05645322]
#  [-0.05639672 -0.15713409 -0.16692987 ... -0.20924096 -0.22903933
#    0.47013152]
#  [-0.15298629 -0.17610268 -0.14876008 ... -0.17698987 -0.21130802
#   -0.21688728]
#  ...
#  [-0.07930384  0.10322221  0.36085635 ... -0.21176665  0.05741474
#   -0.01678093]
#  [-0.1505549  -0.21733926 -0.14907429 ... -0.10536724 -0.20858023
#   -0.05052756]
#  [ 0.03355681 -0.15409234 -0.14248477 ... -0.24010812 -0.21764024
#   -0.15067664]]
# counter:
# 19980
# label:benign
# counter:
# 19981
# label:benign
# counter:
# 19982
# label:benign
# counter:
# 19983
# label:benign
# counter:
# 19984
# label:benign
# counter:
# 19985
# label:benign
# counter:
# 19986
# label:benign
# counter:
# 19987
# label:benign
# counter:
# 19988
# label:benign
# counter:
# 19989
# label:benign
# [[-0.20498636 -0.19445275 -0.02010083 ... -0.19587041 -0.20132026
#   -0.15005773]
#  [-0.02531126 -0.19219102 -0.15639916 ... -0.22574465 -0.20724337
#   -0.16771401]
#  [-0.13335672 -0.12685655 -0.13362528 ... -0.13002898 -0.17898431
#   -0.22940478]
#  ...
#  [-0.04818865 -0.16011316  0.08139952 ... -0.2484935  -0.14883962
#   -0.13219632]
#  [-0.04959822 -0.17152137 -0.16792406 ... -0.08988855 -0.1888487
#    0.0193144 ]
#  [-0.07732698 -0.14840563 -0.18901543 ... -0.13312776 -0.21438657
#   -0.2308089 ]]
# counter:
# 19990
# label:benign
# counter:
# 19991
# label:benign
# counter:
# 19992
# label:benign
# counter:
# 19993
# label:benign
# counter:
# 19994
# label:benign
# counter:
# 19995
# label:benign
# counter:
# 19996
# label:benign
# counter:
# 19997
# label:benign
# counter:
# 19998
# label:benign
# counter:
# 19999
# label:benign
# [[ 0.01739922 -0.18613805 -0.15272771 ... -0.19517612 -0.22342858
#    0.19482052]
#  [-0.16962695 -0.1765567  -0.08051586 ... -0.14474688 -0.12340648
#   -0.21336593]
#  [-0.05388224 -0.03187454  0.01574403 ... -0.10445309 -0.11866979
#   -0.20609692]
#  ...
#  [ 0.01242387 -0.22232583 -0.14779596 ... -0.19146289 -0.24663766
#   -0.16331309]
#  [ 0.00688241 -0.13888556 -0.20470828 ... -0.20457351 -0.22088031
#   -0.14464863]
#  [-0.04498418 -0.11483632 -0.07101219 ... -0.1520835  -0.22191224
#   -0.14460912]]
# counter:
# 20000
# label:benign
# counter:
# 20001
# label:benign
# counter:
# 20002
# label:benign
# counter:
# 20003
# label:benign
# counter:
# 20004
# label:benign
# counter:
# 20005
# label:benign
# counter:
# 20006
# label:benign
# counter:
# 20007
# label:benign
# counter:
# 20008
# label:benign
# counter:
# 20009
# label:benign
# [[-0.0818764  -0.15923664 -0.03257937 ... -0.235979   -0.18516314
#   -0.0741901 ]
#  [-0.0867343  -0.23434933 -0.24672234 ... -0.15058596  0.12401992
#   -0.13711464]
#  [-0.07745211 -0.22343528 -0.21315238 ... -0.23444928 -0.23835571
#   -0.17638387]
#  ...
#  [-0.17875297 -0.16321595 -0.18925744 ... -0.16999838 -0.21092902
#   -0.15891987]
#  [-0.02811831 -0.14646439 -0.09717216 ... -0.22802326 -0.23688944
#   -0.13619363]
#  [-0.12674396 -0.1928021  -0.06208015 ... -0.2005754  -0.19143525
#   -0.1536838 ]]
# counter:
# 20010
# label:benign
# counter:
# 20011
# label:benign
# counter:
# 20012
# label:benign
# counter:
# 20013
# label:benign
# counter:
# 20014
# label:benign
# counter:
# 20015
# label:benign
# counter:
# 20016
# label:benign
# counter:
# 20017
# label:benign
# counter:
# 20018
# label:benign
# counter:
# 20019
# label:benign
# [[-0.0289983  -0.07982989 -0.18805909 ... -0.13604036 -0.2406533
#    0.5453448 ]
#  [-0.11419925 -0.24400228 -0.19077455 ... -0.23376787 -0.21150523
#    0.13260461]
#  [-0.06732021 -0.05115249 -0.02637791 ... -0.23814121 -0.1517528
#   -0.21723819]
#  ...
#  [ 0.07557666  0.14142337 -0.11046172 ... -0.24123944 -0.1729517
#    0.01707126]
#  [-0.01691504 -0.17976037 -0.10646983 ... -0.22243558 -0.2310293
#   -0.06101081]
#  [-0.02704642  0.14375424  0.07394809 ... -0.24069136 -0.21573766
#   -0.21682549]]
# counter:
# 20020
# label:benign
# counter:
# 20021
# label:benign
# counter:
# 20022
# label:benign
# counter:
# 20023
# label:benign
# counter:
# 20024
# label:benign
# counter:
# 20025
# label:benign
# counter:
# 20026
# label:benign
# counter:
# 20027
# label:benign
# counter:
# 20028
# label:benign
# counter:
# 20029
# label:benign
# [[-0.2088972  -0.16327201 -0.13965204 ... -0.17519283 -0.22890276
#   -0.21252325]
#  [-0.15391532 -0.22385971  0.09026235 ... -0.23638584 -0.1295385
#   -0.06577724]
#  [-0.13544238 -0.12620917 -0.15064    ... -0.15891726 -0.20020746
#   -0.16416194]
#  ...
#  [-0.11649908 -0.23134144 -0.11295058 ... -0.26440504 -0.20387508
#   -0.21853592]
#  [-0.14062159 -0.16473174  0.00981374 ... -0.22010128 -0.21254037
#   -0.18140914]
#  [ 0.00546989 -0.04258988 -0.12350763 ... -0.23481332 -0.02584662
#   -0.12963656]]
# counter:
# 20030
# label:benign
# counter:
# 20031
# label:benign
# counter:
# 20032
# label:benign
# counter:
# 20033
# label:benign
# counter:
# 20034
# label:benign
# counter:
# 20035
# label:benign
# counter:
# 20036
# label:benign
# counter:
# 20037
# label:benign
# counter:
# 20038
# label:benign
# counter:
# 20039
# label:benign
# [[-0.20283538 -0.1989634  -0.17265384 ... -0.21631482  0.31639078
#   -0.12540524]
#  [-0.03445994 -0.16247877  0.02685015 ... -0.22517666 -0.1662827
#    0.05835314]
#  [-0.15601236 -0.22183798  0.04410458 ... -0.18327408 -0.05280863
#   -0.14863384]
#  ...
#  [ 0.14903356 -0.21085463 -0.23429325 ... -0.21154016 -0.22573039
#    0.4661223 ]
#  [-0.10672753  0.2246439  -0.09283456 ... -0.22811043 -0.20905259
#    0.21185887]
#  [-0.021006    0.02715586 -0.09841195 ... -0.24022375  0.00171108
#   -0.14538263]]
# counter:
# 20040
# label:benign
# counter:
# 20041
# label:benign
# counter:
# 20042
# label:benign
# counter:
# 20043
# label:benign
# counter:
# 20044
# label:benign
# counter:
# 20045
# label:benign
# counter:
# 20046
# label:benign
# counter:
# 20047
# label:benign
# counter:
# 20048
# label:benign
# counter:
# 20049
# label:benign
# [[-0.1105464  -0.04580042 -0.16575116 ... -0.21031286 -0.16877325
#   -0.07364611]
#  [ 0.05097311 -0.08163816 -0.1832269  ... -0.16371493 -0.10228463
#   -0.24390945]
#  [-0.055865   -0.11064412 -0.2206149  ... -0.11908682 -0.22325969
#    0.46796966]
#  ...
#  [-0.0351609  -0.08214477 -0.12435707 ... -0.24141622 -0.05718027
#   -0.19262084]
#  [-0.09318707 -0.19582906 -0.12818062 ... -0.22316127 -0.18448932
#   -0.1566258 ]
#  [-0.03094156 -0.2191896  -0.06334252 ... -0.21866073 -0.24116746
#   -0.09976525]]
# counter:
# 20050
# label:benign
# counter:
# 20051
# label:benign
# counter:
# 20052
# label:benign
# counter:
# 20053
# label:benign
# counter:
# 20054
# label:benign
# counter:
# 20055
# label:benign
# counter:
# 20056
# label:benign
# counter:
# 20057
# label:benign
# counter:
# 20058
# label:benign
# counter:
# 20059
# label:benign
# [[-0.10879312 -0.08471971 -0.18866763 ... -0.24084662  0.1072095
#   -0.11972073]
#  [-0.0607089  -0.06857111  0.00794846 ... -0.23020253  0.1102197
#   -0.08437285]
#  [-0.12899151 -0.18508852 -0.19046542 ... -0.19465867 -0.22886065
#    0.88733244]
#  ...
#  [-0.03061067 -0.12452147 -0.20857506 ... -0.23783648 -0.2350167
#   -0.07348985]
#  [-0.04242848 -0.23806217 -0.12785001 ... -0.2236753  -0.21923442
#   -0.21204883]
#  [-0.02201096  0.06903104 -0.13270102 ... -0.08820355 -0.19003733
#    0.00128117]]
# counter:
# 20060
# label:benign
# counter:
# 20061
# label:benign
# counter:
# 20062
# label:benign
# counter:
# 20063
# label:benign
# counter:
# 20064
# label:benign
# counter:
# 20065
# label:benign
# counter:
# 20066
# label:benign
# counter:
# 20067
# label:benign
# counter:
# 20068
# label:benign
# counter:
# 20069
# label:benign
# [[-0.01536517 -0.22403932 -0.07179776 ... -0.22621912 -0.19821243
#   -0.15670943]
#  [ 0.74869996 -0.23876859 -0.06510521 ... -0.24789253 -0.1546815
#   -0.20424256]
#  [ 0.10513181 -0.16752394  0.4829858  ... -0.20794098 -0.18809438
#    0.13231216]
#  ...
#  [-0.16603538 -0.20693499 -0.18571289 ... -0.17326672 -0.19631079
#    0.2662849 ]
#  [-0.2253729  -0.17662315 -0.15872306 ... -0.1908329  -0.22983633
#   -0.12474463]
#  [-0.05252875 -0.1229156  -0.05509249 ... -0.22448719 -0.23031437
#   -0.2189213 ]]
# counter:
# 20070
# label:benign
# counter:
# 20071
# label:benign
# counter:
# 20072
# label:benign
# counter:
# 20073
# label:benign
# counter:
# 20074
# label:benign
# counter:
# 20075
# label:benign
# counter:
# 20076
# label:benign
# counter:
# 20077
# label:benign
# counter:
# 20078
# label:benign
# counter:
# 20079
# label:benign
# [[-1.8713684e-01 -2.0803010e-01 -7.7792883e-02 ... -2.3555291e-01
#   -7.7586554e-02 -2.0055194e-01]
#  [-1.7343612e-01 -9.5187888e-02 -2.1113835e-01 ... -1.4557041e-01
#   -2.2135270e-01  2.9662344e-01]
#  [-6.7771822e-02 -2.0633823e-01 -8.0216698e-02 ... -2.3866366e-01
#   -1.7104582e-01 -7.5831078e-03]
#  ...
#  [-9.3444496e-02  2.6346195e-01 -1.6441180e-01 ... -2.4238349e-01
#   -1.4100598e-01 -2.1141993e-01]
#  [ 1.1475232e-04 -2.1988969e-01 -1.5807129e-01 ... -2.1878880e-01
#   -2.0545876e-01 -9.8061122e-02]
#  [-1.2502885e-01 -1.8158767e-01  3.6311854e-02 ... -2.0202643e-01
#   -2.2127680e-01 -2.2723193e-01]]
# counter:
# 20080
# label:benign
# counter:
# 20081
# label:benign
# counter:
# 20082
# label:benign
# counter:
# 20083
# label:benign
# counter:
# 20084
# label:benign
# counter:
# 20085
# label:benign
# counter:
# 20086
# label:benign
# counter:
# 20087
# label:benign
# counter:
# 20088
# label:benign
# counter:
# 20089
# label:benign
# [[ 0.00383385 -0.20353554 -0.05164889 ... -0.25794262 -0.16345063
#   -0.14576836]
#  [-0.09488186  0.07627809  0.0918977  ... -0.22711769 -0.08412651
#   -0.20361695]
#  [-0.05946701 -0.1359864  -0.15543357 ... -0.14015076 -0.21565989
#   -0.22206111]
#  ...
#  [ 0.02027091 -0.22054076 -0.14146902 ... -0.24831377 -0.23703538
#   -0.2079993 ]
#  [-0.12892674 -0.20681582 -0.2070121  ... -0.19340135 -0.19922706
#    0.05690225]
#  [ 0.37122196 -0.20482886 -0.02507881 ... -0.21255648 -0.1859503
#    0.05889947]]
# counter:
# 20090
# label:benign
# counter:
# 20091
# label:benign
# counter:
# 20092
# label:benign
# counter:
# 20093
# label:benign
# counter:
# 20094
# label:benign
# counter:
# 20095
# label:benign
# counter:
# 20096
# label:benign
# counter:
# 20097
# label:benign
# counter:
# 20098
# label:benign
# counter:
# 20099
# label:benign
# [[-0.13273151 -0.07989478  0.3294225  ... -0.22239572 -0.23055384
#   -0.13060515]
#  [-0.06221334 -0.19370487 -0.10879838 ... -0.25269985 -0.2233881
#   -0.16640371]
#  [-0.12531847 -0.21707213 -0.12392854 ... -0.19070047 -0.18318169
#   -0.15926993]
#  ...
#  [-0.13947558 -0.183729   -0.12156413 ... -0.21251641 -0.23326415
#   -0.23427734]
#  [-0.16386718 -0.0149698  -0.00700031 ... -0.23639756 -0.2270151
#   -0.15087175]
#  [-0.10019197  0.2887273  -0.14151593 ... -0.24562751 -0.14862956
#   -0.19134793]]
# counter:
# 20100
# label:benign
# counter:
# 20101
# label:benign
# counter:
# 20102
# label:benign
# counter:
# 20103
# label:benign
# counter:
# 20104
# label:benign
# counter:
# 20105
# label:benign
# counter:
# 20106
# label:benign
# counter:
# 20107
# label:benign
# counter:
# 20108
# label:benign
# counter:
# 20109
# label:benign
# [[-0.03380131 -0.19918491 -0.19769779 ... -0.20107117 -0.20265901
#   -0.18386231]
#  [-0.11313315  0.2546137  -0.10570993 ... -0.2221902  -0.21804982
#   -0.14346701]
#  [ 0.01030683 -0.21824862 -0.16214103 ... -0.20820497 -0.2253566
#   -0.04587266]
#  ...
#  [-0.07948496 -0.00655599  0.06385761 ... -0.252532   -0.1465993
#   -0.12467845]
#  [-0.11081247 -0.22961974 -0.16526453 ... -0.22169769 -0.22435912
#   -0.1466346 ]
#  [ 0.08562056 -0.20112081 -0.1897658  ... -0.2223571  -0.22202624
#   -0.2050927 ]]
# counter:
# 20110
# label:benign
# counter:
# 20111
# label:benign
# counter:
# 20112
# label:benign
# counter:
# 20113
# label:benign
# counter:
# 20114
# label:benign
# counter:
# 20115
# label:benign
# counter:
# 20116
# label:benign
# counter:
# 20117
# label:benign
# counter:
# 20118
# label:benign
# counter:
# 20119
# label:benign
# [[ 0.04619612 -0.2248663   0.03987272 ... -0.23818912 -0.18994592
#   -0.17580362]
#  [-0.11028715 -0.21286437 -0.17679225 ... -0.14733666 -0.20444283
#    0.00088251]
#  [-0.14857566 -0.13464637 -0.06987687 ... -0.23707958 -0.18173085
#   -0.08894258]
#  ...
#  [-0.09152402  0.00789013 -0.09160712 ... -0.14713216 -0.21904175
#   -0.23731042]
#  [ 0.03701753 -0.14103831  0.02249986 ... -0.22450733 -0.02004514
#   -0.03877043]
#  [-0.17461383 -0.20179297 -0.13530399 ...  0.00284818 -0.22341345
#   -0.20374115]]
# counter:
# 20120
# label:benign
# counter:
# 20121
# label:benign
# counter:
# 20122
# label:benign
# counter:
# 20123
# label:benign
# counter:
# 20124
# label:benign
# counter:
# 20125
# label:benign
# counter:
# 20126
# label:benign
# counter:
# 20127
# label:benign
# counter:
# 20128
# label:benign
# counter:
# 20129
# label:benign
# [[-0.03355255 -0.22875512 -0.19392923 ... -0.1916269  -0.20182277
#    0.31985366]
#  [-0.0555274  -0.14057142  0.02588346 ... -0.20017199 -0.2139691
#   -0.20910615]
#  [-0.08875076  0.217501   -0.06158964 ... -0.2199412   0.2600712
#    0.25220186]
#  ...
#  [-0.0108424  -0.21262431 -0.17861322 ... -0.23286013 -0.18156765
#    0.02412962]
#  [ 0.00388858 -0.2067686   0.03994666 ... -0.22172688 -0.18617053
#   -0.15744258]
#  [ 0.00435237  0.05750949 -0.12980561 ... -0.22619529 -0.21686447
#   -0.18002123]]
# counter:
# 20130
# label:benign
# counter:
# 20131
# label:benign
# counter:
# 20132
# label:benign
# counter:
# 20133
# label:benign
# counter:
# 20134
# label:benign
# counter:
# 20135
# label:benign
# counter:
# 20136
# label:benign
# counter:
# 20137
# label:benign
# counter:
# 20138
# label:benign
# counter:
# 20139
# label:benign
# [[-0.09370457 -0.16421409 -0.07786907 ... -0.22436008  0.19583169
#   -0.09503959]
#  [ 0.06266468 -0.22436544  0.24641287 ... -0.23935796 -0.1485572
#   -0.06864943]
#  [-0.05171533  0.00795637 -0.215541   ... -0.02496622 -0.2214744
#    0.3023232 ]
#  ...
#  [-0.00829619 -0.20112984 -0.14268358 ... -0.20740587 -0.21542892
#   -0.14950128]
#  [-0.13799997 -0.16354747  0.25075942 ... -0.23982936 -0.1743052
#   -0.14735217]
#  [-0.11252995 -0.18781541 -0.03567396 ... -0.24448586  0.32717574
#   -0.18893363]]
# counter:
# 20140
# label:benign
# counter:
# 20141
# label:benign
# counter:
# 20142
# label:benign
# counter:
# 20143
# label:benign
# counter:
# 20144
# label:benign
# counter:
# 20145
# label:benign
# counter:
# 20146
# label:benign
# counter:
# 20147
# label:benign
# counter:
# 20148
# label:benign
# counter:
# 20149
# label:benign
# [[-0.06829412 -0.21062005 -0.12773255 ... -0.23707585 -0.15144023
#   -0.09098469]
#  [-0.13948426 -0.15370752 -0.22482942 ... -0.08435121 -0.23379439
#    0.08840974]
#  [-0.04899741 -0.24526398 -0.18162465 ... -0.2365224  -0.21749865
#   -0.05103761]
#  ...
#  [-0.09435501 -0.15658253 -0.12643152 ... -0.13002624 -0.21527146
#   -0.05167252]
#  [-0.05587983 -0.18089981 -0.2255994  ... -0.00629803 -0.01032721
#    0.2607825 ]
#  [-0.18534267 -0.15422699 -0.13371746 ... -0.24090642 -0.16773757
#   -0.14271054]]
# counter:
# 20150
# label:benign
# counter:
# 20151
# label:benign
# counter:
# 20152
# label:benign
# counter:
# 20153
# label:benign
# counter:
# 20154
# label:benign
# counter:
# 20155
# label:benign
# counter:
# 20156
# label:benign
# counter:
# 20157
# label:benign
# counter:
# 20158
# label:benign
# counter:
# 20159
# label:benign
# [[-0.0435756  -0.0210253   0.01016917 ... -0.23261699 -0.23980232
#   -0.12692323]
#  [-0.14292686 -0.19597018 -0.1407215  ... -0.19703282 -0.2088344
#    0.09134875]
#  [-0.14223158 -0.17770253 -0.20970663 ... -0.24619554 -0.16576469
#    0.19666182]
#  ...
#  [ 0.1020086  -0.09206693 -0.13901262 ... -0.20286208 -0.17994708
#   -0.12132815]
#  [-0.06892668 -0.15183291  0.09724589 ... -0.24484049 -0.18260697
#    0.04412381]
#  [-0.08293647 -0.19071859 -0.2181917  ... -0.09897661 -0.23234192
#   -0.1828022 ]]
# counter:
# 20160
# label:benign
# 46863872
# 33284

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
# from tensorflow.keras.applications.resnet50 import ResNet50
# from keras.models import Model
# import keras

x = np.array(X)
y = np.array(Y)
# pre_trained_models = {}
# pre_trained_models["ResNet50"] = ResNet50(include_top=False, input_shape=(224, 224, 3), pooling="avg", weights = 'imagenet')

# temp = 0
# for layer in pre_trained_models["ResNet50"].layers:
#     layer.trainable = False
#     temp += 1

# print("tedad:")
# print(temp)
# print(sys.getsizeof(pre_trained_models["ResNet50"].layers))
# print(pre_trained_models["ResNet50"].layers)

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=0)
# X_train = pre_trained_models["ResNet50"].predict(X_train)
# X_test = pre_trained_models["ResNet50"].predict(X_test)


# print("X_train:")
# print(X_train.shape)


# print(X_train)

# print("X_test:")
# print(X_test.shape)

print("x:")
print(x.shape)



# print("koltedad:")
# o = pre_trained_models["ResNet50"].predict(x)
# print(o.shape)
# print("kol:")
# print(o)






print(x[0])
# Out:
# x:
# (33284, 1408)
# [-0.16663641 -0.18218459 -0.20257372 ... -0.20337854 -0.1530951
#   0.22736137]

# %% [markdown]
# VGG19

# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import preprocess_input
import numpy as np

model = VGG19(weights='imagenet', pooling="avg", include_top=False)

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# 80150528/80134624 [==============================] - 0s 0us/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-519e6949f247> in <module>()
#       6 model = VGG19(weights='imagenet', pooling="avg", include_top=False)
#       7
# ----> 8 features = model.predict(x)
#       9
#      10 print(features.shape)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     100       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101   ctx.ensure_initialized()
# --> 102   return ops.EagerTensor(value, ctx.device_name, dtype)
#     103
#     104
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type list).

# %% [markdown]
# DenseNet201

# %%
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.applications.densenet import preprocess_input
import numpy as np

model = DenseNet201(weights='imagenet', pooling="avg", include_top=False)

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 1s 0us/step
# 74850304/74836368 [==============================] - 1s 0us/step
# (80, 1920)

# %% [markdown]
# ResNet101

# %%
from tensorflow.keras.applications.resnet import ResNet101
import numpy as np

model = ResNet101(include_top=False, input_shape=(224, 224, 3), pooling="avg", weights = 'imagenet')
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171450368/171446536 [==============================] - 2s 0us/step
# 171458560/171446536 [==============================] - 2s 0us/step
# (80, 2048)

# %% [markdown]
# ResNet152

# %%
from tensorflow.keras.applications.resnet import ResNet152
import numpy as np

model = ResNet152(include_top=False, input_shape=(224, 224, 3), pooling="avg", weights = 'imagenet')
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234700800/234698864 [==============================] - 3s 0us/step
# 234708992/234698864 [==============================] - 3s 0us/step
# (80, 2048)

# %% [markdown]
# InceptionV3

# %%
from tensorflow.keras.applications import InceptionV3
import numpy as np

model = InceptionV3(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# 87924736/87910968 [==============================] - 1s 0us/step
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f582ad4ea70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (80, 2048)

# %% [markdown]
# InceptionResNetV2

# %%
from tensorflow.keras.applications import InceptionResNetV2
import numpy as np

model = InceptionResNetV2(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 2s 0us/step
# 219070464/219055592 [==============================] - 2s 0us/step
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f5827e72a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (80, 1536)

# %% [markdown]
# MobileNet

# %%
from tensorflow.keras.applications import MobileNet
import numpy as np

model = MobileNet(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 0s 0us/step
# 17235968/17225924 [==============================] - 0s 0us/step
# (80, 1024)

# %% [markdown]
# NASNetMobile

# %%
from tensorflow.keras.applications import NASNetMobile
import numpy as np

model = NASNetMobile(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19996672/19993432 [==============================] - 0s 0us/step
# 20004864/19993432 [==============================] - 0s 0us/step
# (80, 1056)

# %% [markdown]
# EfficientNetB0

# %%
from tensorflow.keras.applications import EfficientNetB0
import numpy as np

model = EfficientNetB0(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16711680/16705208 [==============================] - 0s 0us/step
# 16719872/16705208 [==============================] - 0s 0us/step
# (80, 1280)

# %% [markdown]
# EfficientNetB1

# %%
from tensorflow.keras.applications import EfficientNetB1
import numpy as np

model = EfficientNetB1(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb1_notop.h5
# 27025408/27018416 [==============================] - 0s 0us/step
# 27033600/27018416 [==============================] - 0s 0us/step
# (80, 1280)

# %% [markdown]
# EfficientNetB2

# %%
from tensorflow.keras.applications import EfficientNetB2
import numpy as np

model = EfficientNetB2(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31793152/31790344 [==============================] - 0s 0us/step
# 31801344/31790344 [==============================] - 0s 0us/step
# (80, 1408)

# %% [markdown]
# EfficientNetB3

# %%
from tensorflow.keras.applications import EfficientNetB3
import numpy as np

model = EfficientNetB3(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941888/43941136 [==============================] - 0s 0us/step
# 43950080/43941136 [==============================] - 0s 0us/step
# (80, 1536)

# %% [markdown]
# EfficientNetB4

# %%
from tensorflow.keras.applications import EfficientNetB4
import numpy as np

model = EfficientNetB4(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71688192/71686520 [==============================] - 1s 0us/step
# 71696384/71686520 [==============================] - 1s 0us/step
# (80, 1792)

# %% [markdown]
# EfficientNetB5

# %%
from tensorflow.keras.applications import EfficientNetB5
import numpy as np

model = EfficientNetB5(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115269632/115263384 [==============================] - 1s 0us/step
# 115277824/115263384 [==============================] - 1s 0us/step
# (80, 2048)

# %% [markdown]
# EfficientNetB6

# %%
from tensorflow.keras.applications import EfficientNetB6
import numpy as np

model = EfficientNetB6(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb6_notop.h5
# 165240832/165234480 [==============================] - 3s 0us/step
# 165249024/165234480 [==============================] - 3s 0us/step
# (80, 2304)

# %% [markdown]
# EfficientNetB7

# %%
from tensorflow.keras.applications import EfficientNetB7
import numpy as np

model = EfficientNetB7(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258080768/258076736 [==============================] - 3s 0us/step
# 258088960/258076736 [==============================] - 3s 0us/step
# (80, 2560)

# %% [markdown]
# DenseNet121

# %%
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input
import numpy as np

model = DenseNet121(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# 29097984/29084464 [==============================] - 0s 0us/step
# (80, 1024)

# %% [markdown]
# DenseNet169

# %%
from tensorflow.keras.applications import DenseNet169
from tensorflow.keras.applications.densenet import preprocess_input
import numpy as np

model = DenseNet169(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51879936/51877672 [==============================] - 1s 0us/step
# 51888128/51877672 [==============================] - 1s 0us/step
# (80, 1664)

# %% [markdown]
# VGG16

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
import numpy as np

model = VGG16(weights='imagenet', pooling="avg", include_top=False)

for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 58900480/58889256 [==============================] - 1s 0us/step
# (80, 512)

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
result = {}
Classifier = XGBClassifier(learning_rate=0.9, n_estimators=150, random_state=0, seed=0, gamma=0)
Classifier.fit(X_train, Y_train)
Y_pred = Classifier.predict(X_test)
print("Accuracy score : ", accuracy_score(Y_test, Y_pred))
# print(X_train)
# print(X_test)
# print(Y_train)
# print(Y_test)

# print(Y_test)
# print(Y_pred)
# Out:
# Accuracy score :  0.8787302223112358

# %% [markdown]
# ## Visualising the Linear Regression results
