# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
from glob import glob
import cv2
from matplotlib import pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate, KFold
from keras.losses import SparseCategoricalCrossentropy, CategoricalCrossentropy
from xgboost import XGBClassifier
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, confusion_matrix, f1_score, precision_score, recall_score, roc_curve, auc
from google.colab import drive
# import glob



from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Importing the dataset

# %%
images_path = {}
images_path["malignant"] = glob("/content/drive/MyDrive/dani/GasHisSDB/160/Abnormal/*.png")
images_path["benign"] = glob("/content/drive/MyDrive/dani/GasHisSDB/160/Normal/*.png")


images_class = {
    'benign' : 0,
    'malignant' : 1
}

import sys

from tensorflow.keras.applications import ResNet50
from keras.models import Model
import keras

pre_trained_models = {}


from tensorflow.keras.applications import EfficientNetB3
import numpy as np


pre_trained_models["EfficientNetB3"] = EfficientNetB3(include_top=False, input_shape=(224, 224, 3), pooling="avg", weights = 'imagenet')
for layer in pre_trained_models["EfficientNetB3"].layers:
    layer.trainable = False


# print(images_path["malignant"])
counter = 0




Y = []
Z = []
pos = 0
for label in images_path:
    counter = 0
    for image_path in images_path[label]:
        # print(counter, ' / ', all)
        counter += 1
        if(1):
          image = cv2.imread(image_path)
          image = cv2.resize(image,(224, 224))
          Z.append(image)
          
          if(counter % 10 == 0):
            temp = np.array(Z)
            

            feature_EfficientNetB0 = pre_trained_models["EfficientNetB3"].predict(temp)
            print(feature_EfficientNetB0)

            for b in feature_EfficientNetB0:
              c = b.tolist()
              if(pos == 0):
                  X =  [c]
              else:
                X.append(c)


              pos += 1
              # print("shapeX:")
              # o = np.array(X)
              # print(o.shape)


           
            
            # print(X)
            Z = []
          

          Y.append(images_class[label])
          # print(sys.getsizeof(X)/1000000)
          print("counter:")
          print(counter)
          print("label:" + label)
        else:
          continue

print(np.size(X))
print(np.size(Y))
# Out:
# Streaming output truncated to the last 5000 lines.
#  ...
#  [-0.05781547 -0.13845475 -0.22778824 ... -0.11654071 -0.13958451
#   -0.03137468]
#  [-0.18704641 -0.16134995 -0.20335758 ... -0.15759753 -0.16237976
#   -0.08347788]
#  [-0.18555112 -0.08583677 -0.22230174 ...  0.12314878 -0.22908968
#    0.11003173]]
# counter:
# 19000
# label:benign
# counter:
# 19001
# label:benign
# counter:
# 19002
# label:benign
# counter:
# 19003
# label:benign
# counter:
# 19004
# label:benign
# counter:
# 19005
# label:benign
# counter:
# 19006
# label:benign
# counter:
# 19007
# label:benign
# counter:
# 19008
# label:benign
# counter:
# 19009
# label:benign
# [[-0.07627836 -0.14118877 -0.15612444 ... -0.11546952 -0.22953784
#   -0.18275034]
#  [-0.06627689 -0.12393693  0.08422817 ... -0.17791969  0.34665847
#   -0.17735857]
#  [-0.09053686  0.02370981 -0.1746766  ... -0.25382736 -0.10842659
#    0.03303144]
#  ...
#  [-0.10701048 -0.10686028 -0.20138378 ...  0.18082847 -0.1512042
#   -0.00187629]
#  [-0.09575805 -0.21987782 -0.2216017  ... -0.01539711 -0.18249786
#    0.5889857 ]
#  [ 0.00510985 -0.16127643 -0.07592718 ... -0.1792687  -0.14177395
#   -0.23259816]]
# counter:
# 19010
# label:benign
# counter:
# 19011
# label:benign
# counter:
# 19012
# label:benign
# counter:
# 19013
# label:benign
# counter:
# 19014
# label:benign
# counter:
# 19015
# label:benign
# counter:
# 19016
# label:benign
# counter:
# 19017
# label:benign
# counter:
# 19018
# label:benign
# counter:
# 19019
# label:benign
# [[-0.09755135 -0.15143774 -0.0957884  ... -0.20056418 -0.20017993
#   -0.20015684]
#  [-0.2152565   0.00954871 -0.03502303 ... -0.14172718 -0.17610182
#   -0.05354978]
#  [-0.05594438 -0.24012269 -0.1523972  ... -0.24541819 -0.2046819
#   -0.23732314]
#  ...
#  [ 0.00943026 -0.03680796 -0.21295778 ... -0.14193858 -0.16940022
#    0.00655721]
#  [-0.09196013 -0.20567618 -0.09952479 ... -0.1498285  -0.16581464
#   -0.1644155 ]
#  [-0.10926982 -0.11957015 -0.22495441 ... -0.19955082 -0.17660928
#   -0.06580115]]
# counter:
# 19020
# label:benign
# counter:
# 19021
# label:benign
# counter:
# 19022
# label:benign
# counter:
# 19023
# label:benign
# counter:
# 19024
# label:benign
# counter:
# 19025
# label:benign
# counter:
# 19026
# label:benign
# counter:
# 19027
# label:benign
# counter:
# 19028
# label:benign
# counter:
# 19029
# label:benign
# [[-0.04855298 -0.15057136 -0.17512862 ...  0.11991392 -0.05849072
#   -0.21742554]
#  [-0.19688277 -0.12450669 -0.21646975 ... -0.17903288 -0.22213817
#   -0.06572593]
#  [-0.15507974 -0.08526026 -0.12350925 ... -0.10482572 -0.18788864
#    0.29116425]
#  ...
#  [-0.17628309 -0.18079944 -0.17041926 ...  0.03959424 -0.2043291
#   -0.06062232]
#  [-0.15280165 -0.07940944  0.11206564 ... -0.1132362  -0.14851743
#   -0.04973517]
#  [-0.12409852 -0.18708657 -0.1782551  ... -0.19459324 -0.20079458
#    0.30017048]]
# counter:
# 19030
# label:benign
# counter:
# 19031
# label:benign
# counter:
# 19032
# label:benign
# counter:
# 19033
# label:benign
# counter:
# 19034
# label:benign
# counter:
# 19035
# label:benign
# counter:
# 19036
# label:benign
# counter:
# 19037
# label:benign
# counter:
# 19038
# label:benign
# counter:
# 19039
# label:benign
# [[ 0.05483959 -0.07558529 -0.16223435 ... -0.22636104 -0.14207569
#   -0.10716599]
#  [-0.01848857 -0.16569957  0.29564658 ... -0.17626826 -0.08573532
#   -0.2261065 ]
#  [-0.12496266 -0.04786141 -0.05990856 ... -0.06300376 -0.2119433
#    0.08141188]
#  ...
#  [-0.12504932 -0.1172016  -0.11563334 ... -0.10260875 -0.17794316
#    0.03940241]
#  [-0.08981979  0.13890514 -0.14836994 ...  0.08500294 -0.17938448
#   -0.18861015]
#  [-0.15318827  0.19430448  0.0522074  ... -0.24829653 -0.13389869
#   -0.17877373]]
# counter:
# 19040
# label:benign
# counter:
# 19041
# label:benign
# counter:
# 19042
# label:benign
# counter:
# 19043
# label:benign
# counter:
# 19044
# label:benign
# counter:
# 19045
# label:benign
# counter:
# 19046
# label:benign
# counter:
# 19047
# label:benign
# counter:
# 19048
# label:benign
# counter:
# 19049
# label:benign
# [[-0.05704444 -0.03671808 -0.12780398 ... -0.25215745 -0.06768383
#   -0.19090883]
#  [ 0.1913733  -0.05640799 -0.2171655  ...  0.02930795 -0.18649282
#   -0.10666698]
#  [-0.15702784  0.07985061 -0.2106556  ... -0.23151244 -0.18032566
#    0.26909825]
#  ...
#  [-0.09274177 -0.11125494 -0.22393514 ...  0.11874676 -0.11620427
#    0.42495307]
#  [-0.13304722 -0.18302315 -0.19539733 ... -0.14529872 -0.1494558
#   -0.151079  ]
#  [ 0.06346412 -0.13538302 -0.14999926 ... -0.20225029 -0.12637834
#    0.10226014]]
# counter:
# 19050
# label:benign
# counter:
# 19051
# label:benign
# counter:
# 19052
# label:benign
# counter:
# 19053
# label:benign
# counter:
# 19054
# label:benign
# counter:
# 19055
# label:benign
# counter:
# 19056
# label:benign
# counter:
# 19057
# label:benign
# counter:
# 19058
# label:benign
# counter:
# 19059
# label:benign
# [[-0.18876457 -0.05131808 -0.13214788 ... -0.21760423 -0.20801347
#   -0.20037681]
#  [-0.12241646 -0.05493946 -0.21331596 ...  0.2738404  -0.15276809
#   -0.16415559]
#  [-0.08408263 -0.14765207 -0.23245251 ... -0.0885665  -0.16527744
#    0.6296546 ]
#  ...
#  [-0.10096458 -0.13253261  0.3154769  ...  0.28355056 -0.18785158
#   -0.11483347]
#  [-0.04422545 -0.14514808 -0.17358601 ... -0.19648851 -0.12691315
#   -0.17065632]
#  [-0.13807623  0.85246944 -0.10306909 ... -0.22129944 -0.19196229
#   -0.05985591]]
# counter:
# 19060
# label:benign
# counter:
# 19061
# label:benign
# counter:
# 19062
# label:benign
# counter:
# 19063
# label:benign
# counter:
# 19064
# label:benign
# counter:
# 19065
# label:benign
# counter:
# 19066
# label:benign
# counter:
# 19067
# label:benign
# counter:
# 19068
# label:benign
# counter:
# 19069
# label:benign
# [[-0.10752128 -0.18760115 -0.19287337 ... -0.02372226 -0.14616421
#   -0.16127719]
#  [-0.08471298 -0.16016358 -0.19063763 ... -0.14053181 -0.20424493
#    0.07005028]
#  [-0.11344839 -0.15672648 -0.20275599 ... -0.13221627 -0.1667221
#    0.49638265]
#  ...
#  [-0.05535344 -0.17472488 -0.20436178 ... -0.13953535 -0.21486011
#   -0.16620195]
#  [-0.07191697 -0.18151213 -0.23772748 ...  0.01145643 -0.18623753
#    0.0674268 ]
#  [-0.08266833 -0.17360325 -0.22893068 ... -0.19714431 -0.15065342
#   -0.20855464]]
# counter:
# 19070
# label:benign
# counter:
# 19071
# label:benign
# counter:
# 19072
# label:benign
# counter:
# 19073
# label:benign
# counter:
# 19074
# label:benign
# counter:
# 19075
# label:benign
# counter:
# 19076
# label:benign
# counter:
# 19077
# label:benign
# counter:
# 19078
# label:benign
# counter:
# 19079
# label:benign
# [[ 0.01610891 -0.23740809 -0.2413225  ... -0.18327542 -0.04555377
#    0.01775798]
#  [-0.05026958 -0.13805012 -0.03103101 ... -0.24852346 -0.12217931
#   -0.02752561]
#  [-0.07926694  0.33742666 -0.21432443 ... -0.19906943 -0.14090773
#   -0.2259285 ]
#  ...
#  [-0.15489781 -0.12671953 -0.17706777 ... -0.14958335 -0.17197882
#   -0.12927778]
#  [-0.1072558  -0.16748181 -0.19922572 ... -0.20976469 -0.19131958
#    0.23982847]
#  [-0.08566208 -0.16356792 -0.23311011 ... -0.25384277 -0.17727311
#   -0.18901528]]
# counter:
# 19080
# label:benign
# counter:
# 19081
# label:benign
# counter:
# 19082
# label:benign
# counter:
# 19083
# label:benign
# counter:
# 19084
# label:benign
# counter:
# 19085
# label:benign
# counter:
# 19086
# label:benign
# counter:
# 19087
# label:benign
# counter:
# 19088
# label:benign
# counter:
# 19089
# label:benign
# [[-0.01826509 -0.09427267 -0.18312307 ... -0.16801076 -0.2212719
#   -0.17343299]
#  [ 0.07735967 -0.20962487  0.1989998  ... -0.24261081 -0.09711774
#   -0.2209905 ]
#  [-0.07590097 -0.12276874 -0.15615188 ... -0.22221239 -0.18981126
#   -0.18888901]
#  ...
#  [-0.01565333  0.02404764 -0.23759016 ...  0.08940519 -0.19950747
#   -0.22009453]
#  [-0.13281417 -0.14115003 -0.22242095 ... -0.10588288 -0.18504289
#    0.02589996]
#  [-0.06051083 -0.15376176 -0.22502792 ... -0.05196358 -0.17200284
#    0.22151406]]
# counter:
# 19090
# label:benign
# counter:
# 19091
# label:benign
# counter:
# 19092
# label:benign
# counter:
# 19093
# label:benign
# counter:
# 19094
# label:benign
# counter:
# 19095
# label:benign
# counter:
# 19096
# label:benign
# counter:
# 19097
# label:benign
# counter:
# 19098
# label:benign
# counter:
# 19099
# label:benign
# [[-0.15273191 -0.09343424 -0.21211235 ... -0.04551762 -0.12560433
#   -0.16582942]
#  [-0.09751385 -0.06880561 -0.22740918 ... -0.22170779 -0.13502866
#   -0.17764282]
#  [-0.05435994 -0.11356145 -0.15414259 ...  0.18201338 -0.16294861
#    0.1036858 ]
#  ...
#  [-0.01435069 -0.15265398 -0.11530211 ... -0.23440985 -0.11537031
#   -0.24690501]
#  [-0.1451299  -0.19870652 -0.16548032 ... -0.15759176 -0.19062148
#   -0.16080992]
#  [-0.04457675 -0.09111401 -0.2141145  ... -0.14313151 -0.13728456
#   -0.08336664]]
# counter:
# 19100
# label:benign
# counter:
# 19101
# label:benign
# counter:
# 19102
# label:benign
# counter:
# 19103
# label:benign
# counter:
# 19104
# label:benign
# counter:
# 19105
# label:benign
# counter:
# 19106
# label:benign
# counter:
# 19107
# label:benign
# counter:
# 19108
# label:benign
# counter:
# 19109
# label:benign
# [[-0.03606891 -0.15896045  0.13147692 ... -0.13785069 -0.14618042
#    0.14068896]
#  [-0.20890442 -0.14742586 -0.01561296 ... -0.03146638 -0.18785146
#   -0.0039378 ]
#  [-0.11776977 -0.12821008 -0.17300478 ... -0.20562573 -0.14469628
#   -0.17221922]
#  ...
#  [-0.06925353 -0.09138321 -0.1881522  ... -0.2603674  -0.1908018
#   -0.12599951]
#  [ 0.02548869 -0.15409409 -0.25526208 ... -0.18341097 -0.20916645
#   -0.18082303]
#  [-0.18058358 -0.03948742 -0.21239956 ... -0.03329651 -0.17794795
#   -0.14498352]]
# counter:
# 19110
# label:benign
# counter:
# 19111
# label:benign
# counter:
# 19112
# label:benign
# counter:
# 19113
# label:benign
# counter:
# 19114
# label:benign
# counter:
# 19115
# label:benign
# counter:
# 19116
# label:benign
# counter:
# 19117
# label:benign
# counter:
# 19118
# label:benign
# counter:
# 19119
# label:benign
# [[ 0.04598547 -0.15756097  0.24361674 ... -0.2610332  -0.16253072
#   -0.22181757]
#  [-0.07508524 -0.13747948 -0.2208236  ...  0.21393001 -0.2338998
#   -0.06064915]
#  [-0.01534247 -0.13502091 -0.01788127 ... -0.23969805 -0.16455775
#   -0.12231042]
#  ...
#  [-0.08748993 -0.18132451  0.14757171 ... -0.22408243 -0.1839037
#    0.07652411]
#  [-0.06511775 -0.22100823 -0.23682168 ... -0.10067122 -0.14631517
#    0.05087424]
#  [-0.1043909  -0.1838717  -0.19921009 ... -0.26084515 -0.1842874
#   -0.18227214]]
# counter:
# 19120
# label:benign
# counter:
# 19121
# label:benign
# counter:
# 19122
# label:benign
# counter:
# 19123
# label:benign
# counter:
# 19124
# label:benign
# counter:
# 19125
# label:benign
# counter:
# 19126
# label:benign
# counter:
# 19127
# label:benign
# counter:
# 19128
# label:benign
# counter:
# 19129
# label:benign
# [[-0.1181601  -0.11529499 -0.24413788 ... -0.17394777 -0.15335079
#    0.31710336]
#  [-0.08538776 -0.17871049 -0.20959009 ... -0.06011572 -0.14589942
#    0.5914201 ]
#  [-0.22233285 -0.19190864 -0.23824656 ... -0.2180142  -0.19814943
#   -0.1290044 ]
#  ...
#  [-0.22445455 -0.04566453 -0.17322415 ... -0.18369517 -0.19241306
#   -0.00837061]
#  [-0.07206477 -0.10486772 -0.18132602 ... -0.1434717  -0.1486365
#   -0.15791748]
#  [-0.14706232 -0.1107249  -0.2393986  ... -0.15851244 -0.18410519
#   -0.11501493]]
# counter:
# 19130
# label:benign
# counter:
# 19131
# label:benign
# counter:
# 19132
# label:benign
# counter:
# 19133
# label:benign
# counter:
# 19134
# label:benign
# counter:
# 19135
# label:benign
# counter:
# 19136
# label:benign
# counter:
# 19137
# label:benign
# counter:
# 19138
# label:benign
# counter:
# 19139
# label:benign
# [[-0.11114557 -0.18825893 -0.01844479 ... -0.25786975 -0.2043272
#   -0.18352568]
#  [-0.10032393 -0.12061599 -0.17207317 ... -0.19065915 -0.15385178
#   -0.1401804 ]
#  [-0.1580496  -0.12889954 -0.16181767 ... -0.05893565 -0.18852189
#   -0.16859265]
#  ...
#  [-0.07502641 -0.13066027 -0.17591853 ... -0.12588492 -0.16444948
#   -0.07949754]
#  [-0.0340063  -0.1799319  -0.2520773  ... -0.23827764 -0.19665873
#   -0.04303781]
#  [-0.11504623 -0.17246287 -0.23105992 ... -0.17182693 -0.18618658
#   -0.0165107 ]]
# counter:
# 19140
# label:benign
# counter:
# 19141
# label:benign
# counter:
# 19142
# label:benign
# counter:
# 19143
# label:benign
# counter:
# 19144
# label:benign
# counter:
# 19145
# label:benign
# counter:
# 19146
# label:benign
# counter:
# 19147
# label:benign
# counter:
# 19148
# label:benign
# counter:
# 19149
# label:benign
# [[-0.10955333 -0.18176751 -0.2409189  ...  0.03336032 -0.18131712
#    0.10637216]
#  [-0.12993653 -0.17218159 -0.24252379 ... -0.20162234 -0.13429372
#   -0.16140097]
#  [-0.09582122 -0.16266975 -0.13055006 ...  0.40395787 -0.23266447
#   -0.02767049]
#  ...
#  [-0.10111602 -0.19246338  0.38551384 ...  0.02649793 -0.24266815
#   -0.18549006]
#  [-0.15405011 -0.16370378 -0.23403136 ... -0.12706281 -0.15186566
#   -0.01717846]
#  [-0.04716387  0.14273268 -0.14444117 ... -0.21045975 -0.196979
#   -0.24369028]]
# counter:
# 19150
# label:benign
# counter:
# 19151
# label:benign
# counter:
# 19152
# label:benign
# counter:
# 19153
# label:benign
# counter:
# 19154
# label:benign
# counter:
# 19155
# label:benign
# counter:
# 19156
# label:benign
# counter:
# 19157
# label:benign
# counter:
# 19158
# label:benign
# counter:
# 19159
# label:benign
# [[-0.08880912 -0.14065143 -0.2096949  ... -0.02791812 -0.18458958
#    0.14392023]
#  [-0.07389448 -0.11976019 -0.17218056 ... -0.1182135  -0.16941738
#    0.3077187 ]
#  [-0.07012956 -0.06936508 -0.2352956  ... -0.24087717 -0.16881332
#   -0.20544013]
#  ...
#  [-0.1536045  -0.11813473 -0.21315369 ... -0.1488083  -0.12602398
#   -0.14269102]
#  [-0.11131035 -0.1419067  -0.19088976 ... -0.24142893 -0.20991655
#    0.01749785]
#  [-0.1036425  -0.13028364 -0.23443656 ... -0.17165922 -0.09588623
#   -0.15017487]]
# counter:
# 19160
# label:benign
# counter:
# 19161
# label:benign
# counter:
# 19162
# label:benign
# counter:
# 19163
# label:benign
# counter:
# 19164
# label:benign
# counter:
# 19165
# label:benign
# counter:
# 19166
# label:benign
# counter:
# 19167
# label:benign
# counter:
# 19168
# label:benign
# counter:
# 19169
# label:benign
# [[ 3.89998928e-02 -6.37788102e-02 -2.10911259e-01 ...  3.67577595e-04
#   -1.87140003e-01 -1.83059767e-01]
#  [-1.12974830e-01 -1.53611794e-01 -2.25046217e-01 ... -4.23273928e-02
#   -1.02043524e-01 -7.68629014e-02]
#  [-1.17670000e-01 -1.36823773e-01 -2.37417907e-01 ... -1.95630446e-01
#   -1.42573088e-01 -5.66749386e-02]
#  ...
#  [-1.50113106e-01 -1.66551098e-01 -2.13145912e-01 ... -2.48648375e-01
#   -1.60995796e-01 -1.39010251e-01]
#  [-1.04868449e-01 -8.62623230e-02 -1.28990158e-01 ... -2.61296630e-01
#   -1.84492469e-01 -1.96254075e-01]
#  [-5.70203885e-02 -1.28154576e-01 -2.50134766e-01 ... -6.95054084e-02
#   -1.79951206e-01  4.29854840e-01]]
# counter:
# 19170
# label:benign
# counter:
# 19171
# label:benign
# counter:
# 19172
# label:benign
# counter:
# 19173
# label:benign
# counter:
# 19174
# label:benign
# counter:
# 19175
# label:benign
# counter:
# 19176
# label:benign
# counter:
# 19177
# label:benign
# counter:
# 19178
# label:benign
# counter:
# 19179
# label:benign
# [[-0.11829388 -0.10510136 -0.2233566  ... -0.20288488 -0.13348097
#    0.10781183]
#  [-0.16349559 -0.17687955 -0.19760267 ... -0.22789796 -0.18216915
#   -0.14146735]
#  [-0.00433194 -0.14271703 -0.2326906  ... -0.19372311 -0.2103422
#    0.39052787]
#  ...
#  [-0.04355498 -0.0919452  -0.08951868 ... -0.25127476 -0.1341562
#   -0.15813537]
#  [-0.0548302  -0.13902844 -0.16885471 ... -0.17145184 -0.13525745
#   -0.08301364]
#  [-0.09171797 -0.11681825 -0.21916693 ... -0.183096   -0.20434779
#    0.4271726 ]]
# counter:
# 19180
# label:benign
# counter:
# 19181
# label:benign
# counter:
# 19182
# label:benign
# counter:
# 19183
# label:benign
# counter:
# 19184
# label:benign
# counter:
# 19185
# label:benign
# counter:
# 19186
# label:benign
# counter:
# 19187
# label:benign
# counter:
# 19188
# label:benign
# counter:
# 19189
# label:benign
# [[-0.04450359 -0.12199265 -0.13168381 ... -0.22989368 -0.17174773
#   -0.15750362]
#  [-0.11754836 -0.13266432 -0.15448974 ... -0.15904532 -0.18604118
#   -0.15933417]
#  [-0.1186017  -0.12200947 -0.20826933 ... -0.0192514  -0.20638175
#   -0.03550881]
#  ...
#  [-0.03497346  0.02698689 -0.22726753 ... -0.17676775 -0.19767998
#   -0.1665842 ]
#  [-0.09974663 -0.12024847 -0.09946451 ... -0.11147778 -0.12707022
#   -0.04116011]
#  [-0.13465308 -0.14842303 -0.00812293 ...  1.3397261  -0.13265564
#   -0.26367858]]
# counter:
# 19190
# label:benign
# counter:
# 19191
# label:benign
# counter:
# 19192
# label:benign
# counter:
# 19193
# label:benign
# counter:
# 19194
# label:benign
# counter:
# 19195
# label:benign
# counter:
# 19196
# label:benign
# counter:
# 19197
# label:benign
# counter:
# 19198
# label:benign
# counter:
# 19199
# label:benign
# [[ 0.0169068  -0.17796464  0.03749922 ... -0.19214618 -0.23185197
#   -0.20245592]
#  [-0.11071974 -0.17825551 -0.16928393 ... -0.14709014 -0.21230368
#   -0.17528526]
#  [-0.05380416 -0.09576622 -0.04785857 ... -0.20784675 -0.136031
#   -0.10430225]
#  ...
#  [-0.1499278  -0.1374627  -0.24570245 ... -0.07970709 -0.19057198
#    0.09276337]
#  [-0.15544106 -0.03363681 -0.1188493  ... -0.25576013 -0.15801543
#   -0.18890044]
#  [-0.05210096 -0.17970023 -0.21825564 ... -0.23510121 -0.08493087
#   -0.16962075]]
# counter:
# 19200
# label:benign
# counter:
# 19201
# label:benign
# counter:
# 19202
# label:benign
# counter:
# 19203
# label:benign
# counter:
# 19204
# label:benign
# counter:
# 19205
# label:benign
# counter:
# 19206
# label:benign
# counter:
# 19207
# label:benign
# counter:
# 19208
# label:benign
# counter:
# 19209
# label:benign
# [[-0.00328648 -0.1111727  -0.21096687 ... -0.19137718 -0.16633184
#    0.26704663]
#  [-0.11121801 -0.09920137 -0.13508153 ...  0.15940672 -0.15070555
#    0.20178308]
#  [-0.10935915 -0.09612242 -0.19489977 ... -0.05720096 -0.17367224
#   -0.05388864]
#  ...
#  [-0.14112179 -0.11355513  0.34879136 ... -0.08096084 -0.21207936
#   -0.19483961]
#  [-0.10868306 -0.206858   -0.1475327  ... -0.13122965 -0.20873433
#   -0.11707325]
#  [-0.09215205 -0.16953975 -0.21549165 ... -0.08398136 -0.22360878
#   -0.11164487]]
# counter:
# 19210
# label:benign
# counter:
# 19211
# label:benign
# counter:
# 19212
# label:benign
# counter:
# 19213
# label:benign
# counter:
# 19214
# label:benign
# counter:
# 19215
# label:benign
# counter:
# 19216
# label:benign
# counter:
# 19217
# label:benign
# counter:
# 19218
# label:benign
# counter:
# 19219
# label:benign
# [[-0.05448064 -0.10922568 -0.18078876 ...  0.06764915 -0.19975412
#   -0.15690286]
#  [ 0.04331574 -0.20834306 -0.06754523 ... -0.20464075 -0.13504048
#   -0.22630043]
#  [ 0.01207516 -0.14601277 -0.25100508 ... -0.22237167 -0.16948552
#   -0.02446859]
#  ...
#  [-0.1492964   0.01346096 -0.22802892 ... -0.22607367 -0.21657263
#   -0.21493955]
#  [ 0.00957839 -0.14530477 -0.09698247 ... -0.23308383 -0.1572682
#   -0.03745209]
#  [-0.10913751  0.05656795 -0.18476516 ... -0.20986421 -0.13933936
#   -0.0539162 ]]
# counter:
# 19220
# label:benign
# counter:
# 19221
# label:benign
# counter:
# 19222
# label:benign
# counter:
# 19223
# label:benign
# counter:
# 19224
# label:benign
# counter:
# 19225
# label:benign
# counter:
# 19226
# label:benign
# counter:
# 19227
# label:benign
# counter:
# 19228
# label:benign
# counter:
# 19229
# label:benign
# [[-0.06234648 -0.05519112 -0.17376578 ... -0.15430883 -0.14489079
#   -0.12597206]
#  [-0.15087368 -0.17977995 -0.19268651 ...  0.22438993 -0.21726464
#   -0.07504272]
#  [-0.01646994 -0.1027175  -0.22653177 ... -0.13455658 -0.17230451
#    0.18607812]
#  ...
#  [-0.14220157 -0.09305522 -0.12098528 ... -0.21068664 -0.163225
#   -0.18669397]
#  [-0.14440654 -0.09589259 -0.21111818 ... -0.1922512  -0.15878096
#   -0.06705585]
#  [-0.15764318 -0.15340509 -0.08467989 ... -0.19629082 -0.11938495
#   -0.21250507]]
# counter:
# 19230
# label:benign
# counter:
# 19231
# label:benign
# counter:
# 19232
# label:benign
# counter:
# 19233
# label:benign
# counter:
# 19234
# label:benign
# counter:
# 19235
# label:benign
# counter:
# 19236
# label:benign
# counter:
# 19237
# label:benign
# counter:
# 19238
# label:benign
# counter:
# 19239
# label:benign
# [[ 0.00446516 -0.09301105  0.30732048 ... -0.18118021 -0.17665245
#   -0.08202833]
#  [-0.15950644 -0.09908539 -0.23675291 ... -0.21376953 -0.16811766
#    0.03692311]
#  [-0.08940513 -0.06907989 -0.11823858 ... -0.17791076 -0.19001639
#   -0.20406327]
#  ...
#  [-0.01414575 -0.09047616 -0.14951847 ... -0.03971857 -0.13209501
#   -0.12783849]
#  [-0.14653212 -0.14892472 -0.19880149 ... -0.18792287 -0.18456982
#    0.05594279]
#  [-0.07543013 -0.10140286 -0.24190837 ... -0.05916994 -0.18599525
#    0.49541655]]
# counter:
# 19240
# label:benign
# counter:
# 19241
# label:benign
# counter:
# 19242
# label:benign
# counter:
# 19243
# label:benign
# counter:
# 19244
# label:benign
# counter:
# 19245
# label:benign
# counter:
# 19246
# label:benign
# counter:
# 19247
# label:benign
# counter:
# 19248
# label:benign
# counter:
# 19249
# label:benign
# [[-2.0938675e-01 -1.7421803e-01 -2.5936586e-01 ...  3.3693661e-03
#   -1.9423687e-01 -2.0974819e-01]
#  [-3.4894962e-02 -8.5440256e-02 -1.3991950e-01 ... -1.5838802e-01
#   -1.8261373e-01  7.6480590e-02]
#  [-1.8245028e-01 -1.7934360e-01 -1.8406034e-01 ... -2.3920949e-01
#   -7.0975073e-02 -1.6239887e-01]
#  ...
#  [-9.8689489e-02 -1.5353799e-01 -8.3033204e-02 ... -2.6264518e-01
#   -1.9040030e-01 -4.6518384e-05]
#  [-8.6852908e-02 -1.7203952e-01 -2.2695279e-01 ... -1.5477403e-01
#   -1.7533626e-01  3.6357209e-01]
#  [-7.8096449e-02 -1.3153072e-01 -3.3017982e-02 ... -9.6506119e-02
#   -2.2471701e-01 -2.2253469e-01]]
# counter:
# 19250
# label:benign
# counter:
# 19251
# label:benign
# counter:
# 19252
# label:benign
# counter:
# 19253
# label:benign
# counter:
# 19254
# label:benign
# counter:
# 19255
# label:benign
# counter:
# 19256
# label:benign
# counter:
# 19257
# label:benign
# counter:
# 19258
# label:benign
# counter:
# 19259
# label:benign
# [[-0.08220778 -0.1794435  -0.20410049 ... -0.07376636 -0.14818865
#   -0.04717261]
#  [-0.07179321 -0.23720525  0.62296337 ... -0.21012336 -0.19201392
#   -0.15138122]
#  [-0.05865518 -0.07136239 -0.25825498 ... -0.06446142 -0.15734975
#   -0.04902667]
#  ...
#  [-0.12201176 -0.13873427 -0.22522157 ... -0.18950626 -0.17498595
#   -0.14138646]
#  [-0.10329641 -0.10167901 -0.10885102 ... -0.1504556   0.00195557
#   -0.17399809]
#  [-0.10829068 -0.12216721 -0.15296537 ... -0.13841847 -0.18941261
#   -0.17491862]]
# counter:
# 19260
# label:benign
# counter:
# 19261
# label:benign
# counter:
# 19262
# label:benign
# counter:
# 19263
# label:benign
# counter:
# 19264
# label:benign
# counter:
# 19265
# label:benign
# counter:
# 19266
# label:benign
# counter:
# 19267
# label:benign
# counter:
# 19268
# label:benign
# counter:
# 19269
# label:benign
# [[-0.08588152 -0.1139315  -0.24875598 ... -0.18597357 -0.16655803
#   -0.18721601]
#  [-0.16128634 -0.00688956 -0.25014684 ...  0.02979346 -0.23944506
#   -0.17592886]
#  [-0.16577892 -0.17326368 -0.20403188 ... -0.09877573 -0.1047485
#    0.02807286]
#  ...
#  [-0.04402456 -0.09307485 -0.167169   ... -0.20285009 -0.21223265
#    0.07573214]
#  [-0.02559598 -0.1410795  -0.23750971 ... -0.21012375 -0.19001906
#    0.00884837]
#  [-0.08459281 -0.09871744 -0.172228   ... -0.22483736 -0.18795606
#   -0.19035898]]
# counter:
# 19270
# label:benign
# counter:
# 19271
# label:benign
# counter:
# 19272
# label:benign
# counter:
# 19273
# label:benign
# counter:
# 19274
# label:benign
# counter:
# 19275
# label:benign
# counter:
# 19276
# label:benign
# counter:
# 19277
# label:benign
# counter:
# 19278
# label:benign
# counter:
# 19279
# label:benign
# [[-0.2033727  -0.15617688  0.04746383 ...  0.13348603 -0.11589998
#   -0.05847855]
#  [-0.1992065  -0.12562345 -0.24768609 ...  0.034324   -0.06768318
#   -0.22357097]
#  [-0.10122538 -0.18174757 -0.11803669 ... -0.1555714  -0.22681607
#   -0.05869594]
#  ...
#  [-0.15651517 -0.1774983  -0.21572477 ... -0.01883715 -0.22288622
#    0.46815443]
#  [-0.11302084 -0.11126694 -0.2205735  ... -0.20572512 -0.1369406
#   -0.1684744 ]
#  [ 0.02434875 -0.06826888  0.18242037 ... -0.19750412  0.08193303
#   -0.19799161]]
# counter:
# 19280
# label:benign
# counter:
# 19281
# label:benign
# counter:
# 19282
# label:benign
# counter:
# 19283
# label:benign
# counter:
# 19284
# label:benign
# counter:
# 19285
# label:benign
# counter:
# 19286
# label:benign
# counter:
# 19287
# label:benign
# counter:
# 19288
# label:benign
# counter:
# 19289
# label:benign
# [[-0.13838023 -0.11683474 -0.2392219  ...  0.00416753 -0.18360591
#    0.07545874]
#  [-0.05071425 -0.19174106 -0.23222597 ... -0.15597405 -0.21431032
#   -0.18882588]
#  [-0.01696898 -0.1825006  -0.21756895 ... -0.09544299 -0.23287342
#   -0.0229065 ]
#  ...
#  [-0.18129592 -0.20783098 -0.12241894 ... -0.11713964 -0.15574919
#   -0.10241894]
#  [-0.17999211  0.03751306 -0.23367608 ... -0.10643584 -0.23351273
#   -0.23929839]
#  [-0.07014798 -0.13031082 -0.18466994 ... -0.1593576  -0.08201609
#    0.2587186 ]]
# counter:
# 19290
# label:benign
# counter:
# 19291
# label:benign
# counter:
# 19292
# label:benign
# counter:
# 19293
# label:benign
# counter:
# 19294
# label:benign
# counter:
# 19295
# label:benign
# counter:
# 19296
# label:benign
# counter:
# 19297
# label:benign
# counter:
# 19298
# label:benign
# counter:
# 19299
# label:benign
# [[-0.10345758 -0.13638896 -0.22888535 ... -0.17917812 -0.15254724
#    0.0695878 ]
#  [-0.06187463 -0.19503272 -0.19181429 ... -0.11834914 -0.1609983
#   -0.18781401]
#  [-0.04180524 -0.18553434 -0.1916002  ...  0.37275735 -0.20820478
#   -0.20858021]
#  ...
#  [-0.15606746  0.05079366 -0.15731746 ...  0.16664824 -0.21303757
#   -0.1485987 ]
#  [-0.15548393 -0.12908085 -0.13840108 ... -0.21847951 -0.17789738
#   -0.10857601]
#  [-0.11927935 -0.20616858 -0.17629911 ... -0.20782262 -0.1850577
#    0.55517495]]
# counter:
# 19300
# label:benign
# counter:
# 19301
# label:benign
# counter:
# 19302
# label:benign
# counter:
# 19303
# label:benign
# counter:
# 19304
# label:benign
# counter:
# 19305
# label:benign
# counter:
# 19306
# label:benign
# counter:
# 19307
# label:benign
# counter:
# 19308
# label:benign
# counter:
# 19309
# label:benign
# [[-0.00834    -0.04929315 -0.1443803  ... -0.12677017 -0.21407485
#   -0.15997888]
#  [-0.1459413  -0.09689093 -0.23352157 ... -0.14804193 -0.21467564
#   -0.04055262]
#  [-0.00767418 -0.17851289 -0.24023277 ... -0.21632995 -0.1779164
#   -0.12050375]
#  ...
#  [-0.08934519 -0.08063985 -0.20243649 ...  0.15603153 -0.22768714
#    0.412118  ]
#  [-0.14026737 -0.14457098 -0.01654402 ...  0.13571894 -0.19616382
#    0.01412114]
#  [-0.09952772 -0.12664202 -0.19655344 ... -0.02859269 -0.19275519
#    0.06046528]]
# counter:
# 19310
# label:benign
# counter:
# 19311
# label:benign
# counter:
# 19312
# label:benign
# counter:
# 19313
# label:benign
# counter:
# 19314
# label:benign
# counter:
# 19315
# label:benign
# counter:
# 19316
# label:benign
# counter:
# 19317
# label:benign
# counter:
# 19318
# label:benign
# counter:
# 19319
# label:benign
# [[-0.09366939 -0.12330338 -0.23921637 ... -0.07008898 -0.15902576
#    0.10169914]
#  [-0.09771436 -0.12927659 -0.1698983  ... -0.1749378  -0.20867851
#   -0.22120608]
#  [-0.11081987  0.00312025 -0.2076832  ... -0.24116524 -0.0424153
#   -0.16053589]
#  ...
#  [ 0.02885541 -0.13544302  0.0966718  ... -0.21276626 -0.21225269
#   -0.24367358]
#  [-0.0983485  -0.18842822 -0.22920117 ... -0.08019596 -0.17000143
#    0.5083085 ]
#  [-0.20130615 -0.07190191 -0.10041288 ...  0.09074278 -0.2008485
#   -0.01960422]]
# counter:
# 19320
# label:benign
# counter:
# 19321
# label:benign
# counter:
# 19322
# label:benign
# counter:
# 19323
# label:benign
# counter:
# 19324
# label:benign
# counter:
# 19325
# label:benign
# counter:
# 19326
# label:benign
# counter:
# 19327
# label:benign
# counter:
# 19328
# label:benign
# counter:
# 19329
# label:benign
# [[ 0.0880846  -0.07507115  0.36213556 ... -0.22566406 -0.06267501
#   -0.23224576]
#  [-0.09365965  0.30454746 -0.19489834 ... -0.20666105 -0.13958178
#   -0.19437574]
#  [-0.09810813 -0.16337638 -0.17563358 ... -0.20970817 -0.186434
#   -0.19834924]
#  ...
#  [-0.21806026 -0.1007242  -0.21492228 ...  0.07997156 -0.21043682
#   -0.18863799]
#  [-0.10582793 -0.11610106 -0.25081077 ...  0.07160584 -0.14523241
#   -0.17948906]
#  [ 0.06464382 -0.17117983 -0.14332874 ... -0.20826422 -0.17328101
#    0.15534139]]
# counter:
# 19330
# label:benign
# counter:
# 19331
# label:benign
# counter:
# 19332
# label:benign
# counter:
# 19333
# label:benign
# counter:
# 19334
# label:benign
# counter:
# 19335
# label:benign
# counter:
# 19336
# label:benign
# counter:
# 19337
# label:benign
# counter:
# 19338
# label:benign
# counter:
# 19339
# label:benign
# [[ 0.01746783 -0.16288921 -0.2247107  ... -0.17899683 -0.21340896
#   -0.18798395]
#  [-0.1257073  -0.1155351  -0.10509498 ... -0.14491922 -0.18242902
#   -0.10322873]
#  [-0.12649213 -0.17095324 -0.00774215 ... -0.2210202  -0.24461466
#    0.08104057]
#  ...
#  [-0.18101195 -0.10946289 -0.24310894 ... -0.15636624 -0.15392013
#    0.04444356]
#  [-0.07753914 -0.14597131 -0.19494076 ...  0.06395929 -0.15134026
#    0.06307335]
#  [-0.03545744 -0.14784706  0.10026169 ... -0.06340953 -0.15511203
#   -0.24008161]]
# counter:
# 19340
# label:benign
# counter:
# 19341
# label:benign
# counter:
# 19342
# label:benign
# counter:
# 19343
# label:benign
# counter:
# 19344
# label:benign
# counter:
# 19345
# label:benign
# counter:
# 19346
# label:benign
# counter:
# 19347
# label:benign
# counter:
# 19348
# label:benign
# counter:
# 19349
# label:benign
# [[-0.05443995 -0.1709645  -0.1789753  ...  0.02707752 -0.20566404
#   -0.2163517 ]
#  [-0.08546518 -0.19068457 -0.11843592 ... -0.09941869 -0.23518105
#    0.2337411 ]
#  [-0.10001516  0.01200191 -0.22946219 ... -0.05177824 -0.19363764
#    0.1696312 ]
#  ...
#  [-0.1636917  -0.0564942  -0.23508163 ... -0.20818748 -0.18690066
#   -0.04386622]
#  [ 0.00445936 -0.06422006 -0.19461128 ... -0.16925788 -0.11858892
#   -0.14669564]
#  [-0.03323223  0.07686379 -0.21958338 ...  0.15019087 -0.17983958
#    0.01283358]]
# counter:
# 19350
# label:benign
# counter:
# 19351
# label:benign
# counter:
# 19352
# label:benign
# counter:
# 19353
# label:benign
# counter:
# 19354
# label:benign
# counter:
# 19355
# label:benign
# counter:
# 19356
# label:benign
# counter:
# 19357
# label:benign
# counter:
# 19358
# label:benign
# counter:
# 19359
# label:benign
# [[-0.08962972 -0.21082167 -0.1884425  ...  0.21156412 -0.15362096
#   -0.19086272]
#  [-0.12188546 -0.2062394  -0.2348343  ... -0.16368845 -0.18882686
#    0.6941701 ]
#  [-0.05830358  0.01830204 -0.23638228 ... -0.19891112 -0.08812228
#   -0.16791579]
#  ...
#  [-0.14335856  0.2502297  -0.20719863 ... -0.21589017 -0.13969289
#   -0.21919537]
#  [-0.05395731 -0.15846701 -0.12876174 ... -0.23424567 -0.12547354
#   -0.21932265]
#  [-0.12237149 -0.14744642 -0.16340397 ... -0.0913242  -0.20656931
#   -0.09290686]]
# counter:
# 19360
# label:benign
# counter:
# 19361
# label:benign
# counter:
# 19362
# label:benign
# counter:
# 19363
# label:benign
# counter:
# 19364
# label:benign
# counter:
# 19365
# label:benign
# counter:
# 19366
# label:benign
# counter:
# 19367
# label:benign
# counter:
# 19368
# label:benign
# counter:
# 19369
# label:benign
# [[-0.13066252 -0.10539118 -0.22826155 ... -0.25300938 -0.19674793
#   -0.17919981]
#  [-0.0724069  -0.12407579 -0.09111603 ... -0.10649385 -0.08016734
#   -0.07615469]
#  [ 0.08283041 -0.13504064  0.03532445 ... -0.23208943 -0.00430387
#   -0.23172176]
#  ...
#  [-0.18129385 -0.15039866 -0.24180055 ... -0.20699385 -0.15824008
#   -0.10324634]
#  [-0.02120651 -0.1716905   0.38392037 ... -0.23346785 -0.17348549
#   -0.13883467]
#  [-0.1167255  -0.11626147 -0.14502558 ... -0.14223039 -0.22255369
#   -0.12291755]]
# counter:
# 19370
# label:benign
# counter:
# 19371
# label:benign
# counter:
# 19372
# label:benign
# counter:
# 19373
# label:benign
# counter:
# 19374
# label:benign
# counter:
# 19375
# label:benign
# counter:
# 19376
# label:benign
# counter:
# 19377
# label:benign
# counter:
# 19378
# label:benign
# counter:
# 19379
# label:benign
# [[-0.14115952 -0.1577438   0.60123557 ... -0.09922447 -0.17203847
#   -0.14405434]
#  [-0.04086281 -0.08723411 -0.19644037 ... -0.2427552  -0.12926339
#    0.5201021 ]
#  [-0.13391449 -0.12039144 -0.22359465 ... -0.17982547 -0.19609548
#   -0.22260036]
#  ...
#  [-0.04603467 -0.19707738 -0.18920267 ... -0.20077667 -0.15866233
#   -0.20132709]
#  [-0.09129943  0.15145172  0.11893463 ... -0.20990016 -0.20135021
#   -0.14696714]
#  [-0.02360659 -0.15787801 -0.17897078 ... -0.23773868 -0.13373439
#    0.30946773]]
# counter:
# 19380
# label:benign
# counter:
# 19381
# label:benign
# counter:
# 19382
# label:benign
# counter:
# 19383
# label:benign
# counter:
# 19384
# label:benign
# counter:
# 19385
# label:benign
# counter:
# 19386
# label:benign
# counter:
# 19387
# label:benign
# counter:
# 19388
# label:benign
# counter:
# 19389
# label:benign
# [[-0.03869162 -0.06910326 -0.17079271 ... -0.03359498 -0.13253011
#    0.03376666]
#  [-0.1592663  -0.05436407 -0.23019925 ... -0.1446266  -0.17164534
#    0.06046952]
#  [-0.04377687 -0.13256472 -0.08400673 ... -0.01868622 -0.16410145
#   -0.18195443]
#  ...
#  [-0.06743523 -0.16489255 -0.2289783  ... -0.11850049 -0.19098404
#    0.01686705]
#  [-0.0784768  -0.13960992 -0.22286217 ... -0.19408831 -0.14324737
#   -0.07783596]
#  [-0.11769761 -0.10646247 -0.13304105 ...  0.03791366 -0.19265631
#    0.4111284 ]]
# counter:
# 19390
# label:benign
# counter:
# 19391
# label:benign
# counter:
# 19392
# label:benign
# counter:
# 19393
# label:benign
# counter:
# 19394
# label:benign
# counter:
# 19395
# label:benign
# counter:
# 19396
# label:benign
# counter:
# 19397
# label:benign
# counter:
# 19398
# label:benign
# counter:
# 19399
# label:benign
# [[ 0.14131455 -0.18361087 -0.12882361 ... -0.20888086 -0.19042332
#    0.25024801]
#  [-0.11214957 -0.10240565 -0.22470303 ... -0.12115955 -0.11376077
#   -0.19467525]
#  [-0.13767517 -0.14225008 -0.25353244 ... -0.08360554 -0.22087695
#    0.19272995]
#  ...
#  [-0.02668416 -0.02332219 -0.22490652 ... -0.02440429 -0.00753101
#   -0.08471267]
#  [-0.12201141 -0.06533954 -0.19275334 ... -0.2547597  -0.1383572
#   -0.16148126]
#  [-0.03229083 -0.14853255 -0.18582876 ... -0.19613875 -0.15393668
#   -0.14104895]]
# counter:
# 19400
# label:benign
# counter:
# 19401
# label:benign
# counter:
# 19402
# label:benign
# counter:
# 19403
# label:benign
# counter:
# 19404
# label:benign
# counter:
# 19405
# label:benign
# counter:
# 19406
# label:benign
# counter:
# 19407
# label:benign
# counter:
# 19408
# label:benign
# counter:
# 19409
# label:benign
# [[-0.07070482 -0.18760012 -0.16796711 ... -0.23108397 -0.1900706
#   -0.10418168]
#  [-0.16297567 -0.2042448   0.01810945 ...  0.13198623 -0.12696658
#   -0.24374212]
#  [-0.20562889  0.17195366 -0.0915287  ... -0.11620922 -0.23910482
#   -0.2099736 ]
#  ...
#  [-0.14924541 -0.22785051  0.04912506 ... -0.13988554 -0.16029586
#   -0.07754436]
#  [-0.14791559 -0.16022511 -0.19105512 ... -0.05098858 -0.19955766
#   -0.09044725]
#  [-0.06174985 -0.03602019 -0.2103227  ... -0.170494   -0.19033784
#   -0.10364065]]
# counter:
# 19410
# label:benign
# counter:
# 19411
# label:benign
# counter:
# 19412
# label:benign
# counter:
# 19413
# label:benign
# counter:
# 19414
# label:benign
# counter:
# 19415
# label:benign
# counter:
# 19416
# label:benign
# counter:
# 19417
# label:benign
# counter:
# 19418
# label:benign
# counter:
# 19419
# label:benign
# [[-0.05197518 -0.16104306 -0.231445   ... -0.1269828  -0.14782465
#   -0.11118069]
#  [-0.01860634 -0.14361218 -0.19802514 ... -0.18366036 -0.05834193
#   -0.08600385]
#  [-0.01337495 -0.15607016 -0.2166629  ... -0.19029187 -0.12043282
#   -0.18844934]
#  ...
#  [-0.03737185 -0.13420959 -0.19820921 ... -0.08717187 -0.18336152
#   -0.1435226 ]
#  [-0.0036853   0.02793847 -0.16378987 ... -0.25094107 -0.15192808
#   -0.19845666]
#  [ 0.00843246 -0.16296099  0.09285564 ...  0.2740012  -0.1585158
#    0.02569599]]
# counter:
# 19420
# label:benign
# counter:
# 19421
# label:benign
# counter:
# 19422
# label:benign
# counter:
# 19423
# label:benign
# counter:
# 19424
# label:benign
# counter:
# 19425
# label:benign
# counter:
# 19426
# label:benign
# counter:
# 19427
# label:benign
# counter:
# 19428
# label:benign
# counter:
# 19429
# label:benign
# [[-0.06661435 -0.11310557 -0.22636797 ... -0.04016826 -0.13762301
#   -0.10173554]
#  [-0.02867093 -0.1511547  -0.20839232 ... -0.09406587 -0.14603266
#   -0.00364012]
#  [-0.01363396 -0.08111355 -0.13555205 ... -0.23992792 -0.15367532
#   -0.12554716]
#  ...
#  [-0.06342485 -0.14368089 -0.2083041  ... -0.17214109 -0.19728687
#   -0.0379888 ]
#  [-0.08632951 -0.141377   -0.18399169 ... -0.19933343 -0.17839712
#   -0.02128499]
#  [-0.10731514 -0.19338855 -0.20792006 ... -0.16696066 -0.14819312
#   -0.17174262]]
# counter:
# 19430
# label:benign
# counter:
# 19431
# label:benign
# counter:
# 19432
# label:benign
# counter:
# 19433
# label:benign
# counter:
# 19434
# label:benign
# counter:
# 19435
# label:benign
# counter:
# 19436
# label:benign
# counter:
# 19437
# label:benign
# counter:
# 19438
# label:benign
# counter:
# 19439
# label:benign
# [[-6.2478188e-02 -1.2914285e-01 -2.3530751e-01 ... -8.7938048e-02
#   -2.2638908e-01  3.0783802e-01]
#  [-2.3782347e-01 -1.8852431e-02 -7.6251008e-02 ... -2.0711087e-01
#   -1.8584158e-01 -1.6886094e-01]
#  [-4.3054037e-02 -1.1679445e-01 -2.1144429e-01 ... -9.6016787e-02
#   -1.6648781e-01 -2.1179332e-01]
#  ...
#  [-1.6259053e-04 -1.2853506e-01 -2.0634243e-01 ... -1.4948851e-01
#   -1.6093598e-01  9.1216266e-02]
#  [-1.3309443e-01 -1.9015014e-01 -2.1527253e-01 ... -2.3591511e-01
#   -1.6274644e-01  2.1748498e-02]
#  [-4.9050089e-02 -9.7402900e-02 -2.0194067e-01 ...  7.5656421e-02
#   -2.3317724e-01 -2.0740622e-01]]
# counter:
# 19440
# label:benign
# counter:
# 19441
# label:benign
# counter:
# 19442
# label:benign
# counter:
# 19443
# label:benign
# counter:
# 19444
# label:benign
# counter:
# 19445
# label:benign
# counter:
# 19446
# label:benign
# counter:
# 19447
# label:benign
# counter:
# 19448
# label:benign
# counter:
# 19449
# label:benign
# [[-0.13836779 -0.10091484 -0.19047917 ... -0.2103403  -0.18301728
#   -0.17910741]
#  [-0.19416845 -0.20606233 -0.21201879 ...  0.14582849 -0.1435131
#   -0.0881135 ]
#  [-0.15165727 -0.1580746  -0.23644945 ... -0.22738571 -0.20675842
#   -0.12931705]
#  ...
#  [-0.11238963 -0.14039385 -0.20350045 ... -0.22480468 -0.21741219
#   -0.22474967]
#  [-0.09091671 -0.06477495 -0.2381506  ... -0.02957828 -0.12800524
#   -0.00836639]
#  [-0.1373666   0.09309497 -0.12852634 ... -0.00506405 -0.18921414
#   -0.17997143]]
# counter:
# 19450
# label:benign
# counter:
# 19451
# label:benign
# counter:
# 19452
# label:benign
# counter:
# 19453
# label:benign
# counter:
# 19454
# label:benign
# counter:
# 19455
# label:benign
# counter:
# 19456
# label:benign
# counter:
# 19457
# label:benign
# counter:
# 19458
# label:benign
# counter:
# 19459
# label:benign
# [[-0.0813223  -0.148961   -0.18072498 ... -0.0961004  -0.14489901
#   -0.12971355]
#  [-0.07700266 -0.02642038 -0.22318852 ... -0.21355323 -0.14011306
#   -0.18129781]
#  [-0.17738183 -0.12151071 -0.24423268 ... -0.14381339 -0.23577504
#   -0.17942834]
#  ...
#  [-0.107995   -0.18861349 -0.13145283 ... -0.03421927 -0.18258329
#    0.01292002]
#  [-0.06932008  0.23880856 -0.19767457 ... -0.26203272 -0.12605175
#   -0.21108608]
#  [-0.0515618  -0.09623578 -0.20088209 ... -0.20853773 -0.10772073
#    0.33108512]]
# counter:
# 19460
# label:benign
# counter:
# 19461
# label:benign
# counter:
# 19462
# label:benign
# counter:
# 19463
# label:benign
# counter:
# 19464
# label:benign
# counter:
# 19465
# label:benign
# counter:
# 19466
# label:benign
# counter:
# 19467
# label:benign
# counter:
# 19468
# label:benign
# counter:
# 19469
# label:benign
# [[-0.08402104 -0.11413822 -0.2366607  ... -0.06188738 -0.13623182
#   -0.18925722]
#  [-0.02214392 -0.13872574 -0.14294906 ... -0.21986884 -0.19074166
#   -0.1254067 ]
#  [-0.10452256 -0.15085387 -0.2343308  ... -0.19438066 -0.20831752
#   -0.23012233]
#  ...
#  [-0.09444436 -0.12457381 -0.23297255 ... -0.24026279 -0.15958034
#   -0.10180401]
#  [-0.08469167 -0.1952234  -0.12287334 ... -0.24766222 -0.14956108
#   -0.18299648]
#  [-0.07226217 -0.17777759 -0.08481238 ... -0.20888716 -0.12717177
#   -0.12169735]]
# counter:
# 19470
# label:benign
# counter:
# 19471
# label:benign
# counter:
# 19472
# label:benign
# counter:
# 19473
# label:benign
# counter:
# 19474
# label:benign
# counter:
# 19475
# label:benign
# counter:
# 19476
# label:benign
# counter:
# 19477
# label:benign
# counter:
# 19478
# label:benign
# counter:
# 19479
# label:benign
# [[ 0.12078276 -0.12858252 -0.1850549  ... -0.18241556 -0.17233913
#    0.06076381]
#  [-0.04230178 -0.16174029 -0.20917585 ... -0.08318068 -0.17016476
#   -0.21473229]
#  [-0.08725644 -0.15316656 -0.24414235 ... -0.02661379 -0.1746771
#   -0.19856945]
#  ...
#  [-0.13706426 -0.11667071 -0.10137761 ... -0.15305296 -0.206191
#    0.02423414]
#  [-0.19946423  0.24734807 -0.05729251 ... -0.1569281  -0.12261623
#   -0.1325439 ]
#  [ 0.01894467 -0.10172528  0.16359374 ... -0.24239706 -0.19197826
#   -0.19609673]]
# counter:
# 19480
# label:benign
# counter:
# 19481
# label:benign
# counter:
# 19482
# label:benign
# counter:
# 19483
# label:benign
# counter:
# 19484
# label:benign
# counter:
# 19485
# label:benign
# counter:
# 19486
# label:benign
# counter:
# 19487
# label:benign
# counter:
# 19488
# label:benign
# counter:
# 19489
# label:benign
# [[-0.05358088 -0.06929656 -0.19240075 ... -0.06473981 -0.14343618
#    0.18626003]
#  [-0.16424091 -0.1796308  -0.21172124 ... -0.2536511  -0.20351696
#   -0.19663616]
#  [-0.16418074 -0.18357722 -0.24957661 ... -0.084744   -0.20439963
#   -0.14544697]
#  ...
#  [-0.00181058 -0.13329661 -0.03386715 ... -0.18028603 -0.21272673
#   -0.0942628 ]
#  [-0.07721487 -0.00130773 -0.21245982 ... -0.06448863 -0.16305886
#   -0.16793469]
#  [-0.10479686 -0.1646601  -0.16787668 ... -0.24033153 -0.05962965
#   -0.12622912]]
# counter:
# 19490
# label:benign
# counter:
# 19491
# label:benign
# counter:
# 19492
# label:benign
# counter:
# 19493
# label:benign
# counter:
# 19494
# label:benign
# counter:
# 19495
# label:benign
# counter:
# 19496
# label:benign
# counter:
# 19497
# label:benign
# counter:
# 19498
# label:benign
# counter:
# 19499
# label:benign
# [[-2.46576760e-02 -1.60832286e-01 -2.06381217e-01 ... -1.85799539e-01
#   -2.09796697e-01 -7.71453753e-02]
#  [ 1.29655693e-02 -1.13784179e-01 -2.46019483e-01 ... -1.98363930e-01
#   -1.08882323e-01  2.03069702e-01]
#  [-5.80382347e-02 -2.01928034e-01 -2.24260017e-01 ... -4.33626696e-02
#   -9.61630195e-02 -1.92842215e-01]
#  ...
#  [ 9.09048468e-02 -1.61931053e-01 -1.33256108e-01 ... -1.84386075e-01
#   -8.84461999e-02 -2.29119629e-01]
#  [-2.39957273e-02  7.39063844e-02 -1.85720768e-04 ... -2.49192923e-01
#   -1.57609239e-01 -2.16873050e-01]
#  [ 3.49389799e-02 -2.08402678e-01 -2.17890278e-01 ...  1.72015756e-01
#   -1.99613899e-01  1.04280345e-01]]
# counter:
# 19500
# label:benign
# counter:
# 19501
# label:benign
# counter:
# 19502
# label:benign
# counter:
# 19503
# label:benign
# counter:
# 19504
# label:benign
# counter:
# 19505
# label:benign
# counter:
# 19506
# label:benign
# counter:
# 19507
# label:benign
# counter:
# 19508
# label:benign
# counter:
# 19509
# label:benign
# [[-0.03349106 -0.14719142  0.13955104 ... -0.1941394  -0.23935354
#   -0.20428535]
#  [ 0.01621696 -0.1773212  -0.03726942 ... -0.23173578 -0.17482314
#   -0.15429479]
#  [-0.10641873 -0.09713446 -0.19861433 ... -0.25432724 -0.18448359
#   -0.19456764]
#  ...
#  [-0.15528195 -0.19523023 -0.19441897 ... -0.2050747  -0.18401106
#   -0.18723609]
#  [ 0.05666637 -0.08422899  0.24197602 ... -0.1699003  -0.18402418
#   -0.23666681]
#  [-0.20692372 -0.09872995 -0.22952873 ... -0.2312114  -0.20224598
#   -0.1933513 ]]
# counter:
# 19510
# label:benign
# counter:
# 19511
# label:benign
# counter:
# 19512
# label:benign
# counter:
# 19513
# label:benign
# counter:
# 19514
# label:benign
# counter:
# 19515
# label:benign
# counter:
# 19516
# label:benign
# counter:
# 19517
# label:benign
# counter:
# 19518
# label:benign
# counter:
# 19519
# label:benign
# [[-0.15051256 -0.09897477 -0.2086941  ... -0.14375342 -0.17759666
#   -0.11353385]
#  [-0.0186753  -0.147305   -0.24592054 ... -0.25908393 -0.13856019
#    0.32845762]
#  [ 0.01430249 -0.08920179 -0.2190467  ... -0.21168122 -0.12189074
#    0.05809768]
#  ...
#  [-0.07973289 -0.1892278  -0.14961365 ... -0.19312742 -0.21756698
#   -0.16912647]
#  [-0.18068208 -0.14328672 -0.241005   ... -0.01177414 -0.1590687
#   -0.21146126]
#  [ 0.00400737 -0.14341292 -0.23006244 ... -0.13310741 -0.11714273
#    0.33811662]]
# counter:
# 19520
# label:benign
# counter:
# 19521
# label:benign
# counter:
# 19522
# label:benign
# counter:
# 19523
# label:benign
# counter:
# 19524
# label:benign
# counter:
# 19525
# label:benign
# counter:
# 19526
# label:benign
# counter:
# 19527
# label:benign
# counter:
# 19528
# label:benign
# counter:
# 19529
# label:benign
# [[-0.04320172 -0.16097227 -0.16535096 ... -0.23613775 -0.13940232
#   -0.16878599]
#  [ 0.01741728 -0.09983741  0.1663109  ... -0.20314431  0.10017941
#   -0.21265326]
#  [-0.10880225 -0.14268349 -0.20985897 ...  0.16073029 -0.14906496
#   -0.09752294]
#  ...
#  [-0.02982345 -0.16777813 -0.12792765 ... -0.2413159  -0.16932616
#   -0.20483574]
#  [-0.04178889 -0.12503241 -0.18408145 ...  0.20761237 -0.163688
#    0.02995663]
#  [-0.03919459 -0.1977591  -0.23442015 ... -0.22404921 -0.15273051
#   -0.23629488]]
# counter:
# 19530
# label:benign
# counter:
# 19531
# label:benign
# counter:
# 19532
# label:benign
# counter:
# 19533
# label:benign
# counter:
# 19534
# label:benign
# counter:
# 19535
# label:benign
# counter:
# 19536
# label:benign
# counter:
# 19537
# label:benign
# counter:
# 19538
# label:benign
# counter:
# 19539
# label:benign
# [[-0.00508828 -0.08795545 -0.13946487 ... -0.01336781 -0.16231163
#   -0.2017899 ]
#  [-0.07380221 -0.15416986 -0.1168347  ... -0.17448275 -0.11254251
#   -0.18081729]
#  [ 0.0445112  -0.10655107 -0.1184271  ... -0.23546284 -0.1378356
#    0.01067016]
#  ...
#  [-0.18660569 -0.06668752 -0.05375127 ... -0.23598641 -0.17241749
#    0.1415847 ]
#  [-0.04730191 -0.1361489   0.01168926 ... -0.11229562 -0.15729143
#   -0.16980833]
#  [-0.07713352 -0.0214936  -0.22556038 ... -0.24628277 -0.15256658
#   -0.17837588]]
# counter:
# 19540
# label:benign
# counter:
# 19541
# label:benign
# counter:
# 19542
# label:benign
# counter:
# 19543
# label:benign
# counter:
# 19544
# label:benign
# counter:
# 19545
# label:benign
# counter:
# 19546
# label:benign
# counter:
# 19547
# label:benign
# counter:
# 19548
# label:benign
# counter:
# 19549
# label:benign
# [[-0.10645667 -0.18599372 -0.24417455 ... -0.08785047 -0.14738186
#   -0.00062823]
#  [-0.10673482 -0.21104805 -0.24227805 ...  0.18705796 -0.1391699
#   -0.13311206]
#  [ 0.00200597 -0.10071704 -0.24298236 ... -0.12248608 -0.14617866
#    0.50788087]
#  ...
#  [-0.10744598  0.09224977  0.08615556 ...  0.14281316  0.16441357
#   -0.08418529]
#  [-0.15804438 -0.11641133 -0.22563343 ... -0.15180714 -0.17650838
#   -0.04952493]
#  [-0.12661481 -0.17504923  0.05232779 ... -0.04070284 -0.18551376
#   -0.01363427]]
# counter:
# 19550
# label:benign
# counter:
# 19551
# label:benign
# counter:
# 19552
# label:benign
# counter:
# 19553
# label:benign
# counter:
# 19554
# label:benign
# counter:
# 19555
# label:benign
# counter:
# 19556
# label:benign
# counter:
# 19557
# label:benign
# counter:
# 19558
# label:benign
# counter:
# 19559
# label:benign
# [[-0.09084482 -0.04830581 -0.17199203 ... -0.19688334 -0.2042555
#    0.03273879]
#  [-0.15322758 -0.09995674 -0.21956158 ...  0.06387112 -0.23265319
#   -0.16273113]
#  [ 0.06109067 -0.163748   -0.12554708 ... -0.20367101 -0.18318385
#   -0.20789443]
#  ...
#  [-0.12774971 -0.19463022 -0.08382456 ... -0.014507   -0.19033863
#   -0.10920443]
#  [-0.04363642 -0.19099596 -0.20864245 ... -0.1853632  -0.15980385
#    0.3630876 ]
#  [ 0.01614736 -0.0828407  -0.2506627  ... -0.18318829 -0.18224679
#   -0.23309821]]
# counter:
# 19560
# label:benign
# counter:
# 19561
# label:benign
# counter:
# 19562
# label:benign
# counter:
# 19563
# label:benign
# counter:
# 19564
# label:benign
# counter:
# 19565
# label:benign
# counter:
# 19566
# label:benign
# counter:
# 19567
# label:benign
# counter:
# 19568
# label:benign
# counter:
# 19569
# label:benign
# [[-0.10187806 -0.10612409 -0.24257919 ...  0.00171368 -0.15848133
#    0.08725585]
#  [-0.12504861 -0.07466789 -0.04118932 ... -0.24668361 -0.1394366
#   -0.21833643]
#  [-0.00565105 -0.07185028  0.05425807 ...  0.4399337   0.01415318
#   -0.14135629]
#  ...
#  [ 0.09180933 -0.09722622 -0.19975111 ...  0.20985964 -0.16980374
#   -0.18945535]
#  [-0.08131785 -0.108102   -0.13202609 ...  0.02500284 -0.195461
#   -0.12118043]
#  [ 0.01104749 -0.17791314 -0.21893334 ... -0.20551641 -0.21093783
#   -0.19315267]]
# counter:
# 19570
# label:benign
# counter:
# 19571
# label:benign
# counter:
# 19572
# label:benign
# counter:
# 19573
# label:benign
# counter:
# 19574
# label:benign
# counter:
# 19575
# label:benign
# counter:
# 19576
# label:benign
# counter:
# 19577
# label:benign
# counter:
# 19578
# label:benign
# counter:
# 19579
# label:benign
# [[-0.09658197 -0.19490509 -0.17074522 ...  0.07521449 -0.17303899
#    0.1166954 ]
#  [ 0.04017688 -0.06467386  0.5369987  ... -0.16532046 -0.19490789
#   -0.12776329]
#  [-0.05711956 -0.11475157 -0.12384033 ... -0.21902305 -0.21573506
#   -0.03008317]
#  ...
#  [ 0.07649422 -0.12473742 -0.15312147 ... -0.2084156  -0.19556743
#    0.0100867 ]
#  [-0.06781036 -0.11129972  0.09824957 ... -0.25114006 -0.20411484
#   -0.18111107]
#  [-0.05348583 -0.0879419  -0.14323795 ... -0.09225905 -0.08570372
#   -0.2169152 ]]
# counter:
# 19580
# label:benign
# counter:
# 19581
# label:benign
# counter:
# 19582
# label:benign
# counter:
# 19583
# label:benign
# counter:
# 19584
# label:benign
# counter:
# 19585
# label:benign
# counter:
# 19586
# label:benign
# counter:
# 19587
# label:benign
# counter:
# 19588
# label:benign
# counter:
# 19589
# label:benign
# [[-0.06224686 -0.18581346 -0.21220037 ...  0.00584712 -0.15313186
#   -0.03265916]
#  [-0.17965096 -0.10917349 -0.23469295 ... -0.11094926 -0.20024419
#   -0.13456623]
#  [-0.16597469 -0.06384452 -0.17435184 ...  0.02826213 -0.21573462
#    0.2798741 ]
#  ...
#  [-0.16381715 -0.12390874 -0.21893817 ...  0.06260424 -0.15438212
#   -0.03986968]
#  [-0.152228   -0.1771436  -0.23998775 ... -0.18783283 -0.17878337
#   -0.15872543]
#  [ 0.02676144 -0.07982932 -0.22520292 ... -0.14298731 -0.15880322
#   -0.00059662]]
# counter:
# 19590
# label:benign
# counter:
# 19591
# label:benign
# counter:
# 19592
# label:benign
# counter:
# 19593
# label:benign
# counter:
# 19594
# label:benign
# counter:
# 19595
# label:benign
# counter:
# 19596
# label:benign
# counter:
# 19597
# label:benign
# counter:
# 19598
# label:benign
# counter:
# 19599
# label:benign
# [[-0.02230245 -0.13678543 -0.18000461 ... -0.25225845 -0.1448251
#   -0.241778  ]
#  [ 0.00856169 -0.20272759 -0.22498009 ... -0.04232013 -0.20385727
#   -0.02775347]
#  [-0.13129665  0.10689377 -0.20454763 ... -0.25646046 -0.13777286
#   -0.12552008]
#  ...
#  [-0.20581812 -0.12016656 -0.19808014 ... -0.1474849  -0.19295534
#   -0.00967611]
#  [-0.09607366 -0.0329784   0.01518705 ...  0.05828141 -0.10974831
#    0.35239846]
#  [-0.12305597 -0.1289413  -0.07113873 ... -0.03848499 -0.2131331
#   -0.11688119]]
# counter:
# 19600
# label:benign
# counter:
# 19601
# label:benign
# counter:
# 19602
# label:benign
# counter:
# 19603
# label:benign
# counter:
# 19604
# label:benign
# counter:
# 19605
# label:benign
# counter:
# 19606
# label:benign
# counter:
# 19607
# label:benign
# counter:
# 19608
# label:benign
# counter:
# 19609
# label:benign
# [[-0.17882352 -0.06403805 -0.19878508 ... -0.21034713 -0.20170186
#   -0.07520939]
#  [-0.08550877 -0.11818635 -0.01810453 ... -0.22433768 -0.18535453
#   -0.18299298]
#  [-0.08374649 -0.14804895 -0.15562536 ... -0.25504282 -0.22688219
#   -0.19123884]
#  ...
#  [-0.12641159 -0.02594861 -0.14385317 ... -0.17088759 -0.18568666
#    0.01146685]
#  [-0.12079646 -0.15729861 -0.23628451 ...  0.29405573 -0.22517814
#   -0.18446171]
#  [ 0.00270738 -0.20449102  0.5801564  ... -0.23997709 -0.21800125
#   -0.24401653]]
# counter:
# 19610
# label:benign
# counter:
# 19611
# label:benign
# counter:
# 19612
# label:benign
# counter:
# 19613
# label:benign
# counter:
# 19614
# label:benign
# counter:
# ...
#   -0.09927122]
#  [-0.02625931 -0.11011098 -0.23027587 ... -0.05411534 -0.18707561
#    0.03707174]
#  ...
#  [-0.04762257 -0.13973263 -0.04737981 ... -0.1016789  -0.18859005
#   -0.0921114 ]
#  [ 0.06751084 -0.16104868 -0.23142114 ... -0.07467959 -0.25303227
#    0.06090694]
#  [ 0.01921856 -0.17781273 -0.08569404 ... -0.21679674 -0.17987402
#   -0.23830171]]
# counter:
# 19960
# label:benign
# counter:
# 19961
# label:benign
# counter:
# 19962
# label:benign
# counter:
# 19963
# label:benign
# counter:
# 19964
# label:benign
# counter:
# 19965
# label:benign
# counter:
# 19966
# label:benign
# counter:
# 19967
# label:benign
# counter:
# 19968
# label:benign
# counter:
# 19969
# label:benign
# [[-0.09083154 -0.127514   -0.24067155 ... -0.002195   -0.1983611
#    0.13903391]
#  [-0.00074695 -0.1265978  -0.03503587 ... -0.07322918 -0.17537297
#   -0.1604486 ]
#  [ 0.01582105 -0.17015736 -0.22970659 ... -0.23614202 -0.19137383
#   -0.05937784]
#  ...
#  [-0.05517134 -0.14405665 -0.0722882  ... -0.27081195 -0.0625492
#   -0.20965582]
#  [-0.14441384  0.0803677  -0.14129744 ... -0.24911875 -0.19826558
#   -0.193937  ]
#  [-0.08366535 -0.10206677 -0.17869543 ... -0.2205602  -0.14771128
#   -0.18030167]]
# counter:
# 19970
# label:benign
# counter:
# 19971
# label:benign
# counter:
# 19972
# label:benign
# counter:
# 19973
# label:benign
# counter:
# 19974
# label:benign
# counter:
# 19975
# label:benign
# counter:
# 19976
# label:benign
# counter:
# 19977
# label:benign
# counter:
# 19978
# label:benign
# counter:
# 19979
# label:benign
# [[-0.10132617 -0.15879461 -0.22839266 ... -0.2658301  -0.12146558
#   -0.06515296]
#  [-0.11348049 -0.14941509 -0.2626481  ... -0.14265123 -0.11195289
#    0.04935717]
#  [-0.1375424  -0.13133402 -0.23478793 ...  0.11771923 -0.13505225
#   -0.12755731]
#  ...
#  [-0.0664528  -0.06301137 -0.22611319 ... -0.22333418 -0.1447054
#    0.48643008]
#  [-0.01742224 -0.18084425 -0.17953178 ... -0.24855849 -0.189818
#   -0.2186554 ]
#  [-0.0112944  -0.17024481 -0.1900606  ... -0.08433104 -0.12048362
#    0.2666206 ]]
# counter:
# 19980
# label:benign
# counter:
# 19981
# label:benign
# counter:
# 19982
# label:benign
# counter:
# 19983
# label:benign
# counter:
# 19984
# label:benign
# counter:
# 19985
# label:benign
# counter:
# 19986
# label:benign
# counter:
# 19987
# label:benign
# counter:
# 19988
# label:benign
# counter:
# 19989
# label:benign
# [[ 0.02311319 -0.07458048 -0.2082849  ... -0.24656177 -0.13031156
#   -0.12810796]
#  [ 0.02945984 -0.14277112 -0.0880227  ... -0.11947527 -0.1463913
#   -0.21474284]
#  [-0.1390777  -0.0916815  -0.20159931 ... -0.04755945 -0.22846878
#   -0.12281004]
#  ...
#  [-0.13699673 -0.1833998  -0.2415978  ... -0.0011244  -0.15744969
#   -0.14748587]
#  [ 0.05324574 -0.17699902 -0.24278754 ... -0.21907982 -0.16040394
#   -0.18329631]
#  [-0.00823765 -0.21395181 -0.21467395 ... -0.22015522 -0.2105266
#   -0.23816496]]
# counter:
# 19990
# label:benign
# counter:
# 19991
# label:benign
# counter:
# 19992
# label:benign
# counter:
# 19993
# label:benign
# counter:
# 19994
# label:benign
# counter:
# 19995
# label:benign
# counter:
# 19996
# label:benign
# counter:
# 19997
# label:benign
# counter:
# 19998
# label:benign
# counter:
# 19999
# label:benign
# [[ 0.06043302 -0.15543257 -0.21840426 ... -0.1987512  -0.18805788
#   -0.07503398]
#  [-0.02957762 -0.16616815 -0.2493088  ... -0.24151576 -0.18264498
#   -0.21284477]
#  [-0.01708603 -0.21302314 -0.18215255 ... -0.23379767 -0.15780523
#   -0.2240459 ]
#  ...
#  [-0.10667979 -0.1739758  -0.04026097 ... -0.00357831 -0.15349537
#    0.20608182]
#  [-0.04100884 -0.13204926 -0.18698323 ... -0.19537365 -0.17679107
#   -0.05891424]
#  [-0.05286554 -0.15749998 -0.25065827 ... -0.19082838 -0.20080832
#   -0.18996876]]
# counter:
# 20000
# label:benign
# counter:
# 20001
# label:benign
# counter:
# 20002
# label:benign
# counter:
# 20003
# label:benign
# counter:
# 20004
# label:benign
# counter:
# 20005
# label:benign
# counter:
# 20006
# label:benign
# counter:
# 20007
# label:benign
# counter:
# 20008
# label:benign
# counter:
# 20009
# label:benign
# [[-8.63222852e-02 -1.57553151e-01 -2.11812153e-01 ... -1.10121354e-01
#   -9.93205756e-02  3.83748382e-01]
#  [-1.63731223e-04 -1.33235574e-01 -2.07077131e-01 ... -1.49099365e-01
#   -1.86337426e-01  1.09798402e-01]
#  [-9.85745490e-02 -1.43598631e-01 -2.12648124e-01 ... -7.52673745e-02
#   -1.47112906e-01  6.48363084e-02]
#  ...
#  [-3.45938802e-02 -1.24573641e-01 -2.45999590e-01 ... -6.07989356e-02
#   -2.44442090e-01 -2.14084089e-02]
#  [-1.38735533e-01 -1.52569339e-01 -2.53484190e-01 ...  1.70240983e-01
#   -2.15162829e-01 -2.21793935e-01]
#  [ 1.83633178e-01 -1.17590621e-01 -2.05198526e-01 ... -1.79512858e-01
#   -1.53863505e-01  1.28769502e-01]]
# counter:
# 20010
# label:benign
# counter:
# 20011
# label:benign
# counter:
# 20012
# label:benign
# counter:
# 20013
# label:benign
# counter:
# 20014
# label:benign
# counter:
# 20015
# label:benign
# counter:
# 20016
# label:benign
# counter:
# 20017
# label:benign
# counter:
# 20018
# label:benign
# counter:
# 20019
# label:benign
# [[-0.05860281  0.16396025 -0.00502156 ... -0.25980508 -0.08555593
#   -0.1954352 ]
#  [-0.15098421  0.04461171 -0.24354479 ... -0.25191873 -0.15920345
#   -0.20660974]
#  [-0.10801213 -0.03235859 -0.21944362 ... -0.21765654 -0.15119258
#   -0.16476312]
#  ...
#  [-0.016024   -0.07470199 -0.24683888 ... -0.18767619 -0.17636687
#    0.2958881 ]
#  [-0.14448628 -0.06031375 -0.23135899 ... -0.17869979 -0.12391106
#   -0.18288577]
#  [-0.14375463 -0.12972334 -0.10300832 ... -0.21911782 -0.09391957
#   -0.19740415]]
# counter:
# 20020
# label:benign
# counter:
# 20021
# label:benign
# counter:
# 20022
# label:benign
# counter:
# 20023
# label:benign
# counter:
# 20024
# label:benign
# counter:
# 20025
# label:benign
# counter:
# 20026
# label:benign
# counter:
# 20027
# label:benign
# counter:
# 20028
# label:benign
# counter:
# 20029
# label:benign
# [[ 0.11819436 -0.16763842 -0.17984268 ... -0.07774141 -0.22806223
#   -0.04019963]
#  [-0.15494277 -0.12107299 -0.19397067 ... -0.24253184 -0.11185654
#    0.14197285]
#  [-0.12623839 -0.1585702  -0.255172   ... -0.10577597 -0.18471006
#   -0.1628644 ]
#  ...
#  [-0.16438103 -0.15656123 -0.24228683 ... -0.02871233 -0.18665458
#   -0.05362698]
#  [-0.05836916 -0.14121644 -0.252792   ... -0.23900022 -0.13224113
#    0.4136845 ]
#  [ 0.04371245 -0.1289677  -0.22190781 ... -0.24093653 -0.07311825
#   -0.18859   ]]
# counter:
# 20030
# label:benign
# counter:
# 20031
# label:benign
# counter:
# 20032
# label:benign
# counter:
# 20033
# label:benign
# counter:
# 20034
# label:benign
# counter:
# 20035
# label:benign
# counter:
# 20036
# label:benign
# counter:
# 20037
# label:benign
# counter:
# 20038
# label:benign
# counter:
# 20039
# label:benign
# [[ 0.14245372 -0.09792842 -0.23208846 ... -0.22243169 -0.23528609
#   -0.09723884]
#  [-0.12442284 -0.12618454 -0.16544417 ...  0.11077004 -0.16681798
#   -0.0352308 ]
#  [-0.12845898 -0.0866119  -0.12330367 ...  0.05606442 -0.2357979
#    0.21859847]
#  ...
#  [-0.17513792 -0.07396846 -0.0845293  ... -0.00544931 -0.15475838
#   -0.12380275]
#  [ 0.02961894 -0.1753448  -0.16179165 ... -0.10199787 -0.19470401
#   -0.08813429]
#  [ 0.01895156 -0.16601487  0.02096493 ... -0.12900297 -0.18899472
#   -0.19920434]]
# counter:
# 20040
# label:benign
# counter:
# 20041
# label:benign
# counter:
# 20042
# label:benign
# counter:
# 20043
# label:benign
# counter:
# 20044
# label:benign
# counter:
# 20045
# label:benign
# counter:
# 20046
# label:benign
# counter:
# 20047
# label:benign
# counter:
# 20048
# label:benign
# counter:
# 20049
# label:benign
# [[ 0.04040108 -0.19379595 -0.09386903 ...  0.01391455 -0.1996519
#    0.08864634]
#  [ 0.04828081 -0.07290056  0.06861027 ... -0.23569061 -0.19964688
#   -0.21278107]
#  [-0.03138248 -0.09820023 -0.03159514 ... -0.2620147  -0.12458839
#   -0.19717543]
#  ...
#  [ 0.02022209 -0.17319432 -0.1925899  ... -0.22774632 -0.12732638
#   -0.20913501]
#  [-0.00755495 -0.12040075  0.09421479 ... -0.00731958 -0.2032543
#   -0.20122606]
#  [-0.09908199  0.26094517 -0.22135523 ... -0.0217039  -0.12800346
#    0.22551179]]
# counter:
# 20050
# label:benign
# counter:
# 20051
# label:benign
# counter:
# 20052
# label:benign
# counter:
# 20053
# label:benign
# counter:
# 20054
# label:benign
# counter:
# 20055
# label:benign
# counter:
# 20056
# label:benign
# counter:
# 20057
# label:benign
# counter:
# 20058
# label:benign
# counter:
# 20059
# label:benign
# [[-0.08426362 -0.0646669  -0.13889629 ... -0.18158019 -0.1805442
#   -0.06421863]
#  [-0.12276478 -0.18174091 -0.17921437 ... -0.00855891 -0.0895262
#    0.03379745]
#  [-0.14137308 -0.04693324 -0.22209786 ... -0.06764603 -0.18181306
#   -0.19692548]
#  ...
#  [-0.10306228 -0.04488358 -0.15027739 ... -0.14095412 -0.15606958
#   -0.06635079]
#  [-0.03923514 -0.1731217  -0.24198388 ... -0.1393884  -0.16800319
#   -0.17879675]
#  [-0.07938889 -0.15932567  0.21713054 ... -0.05076441 -0.18878338
#    0.10773811]]
# counter:
# 20060
# label:benign
# counter:
# 20061
# label:benign
# counter:
# 20062
# label:benign
# counter:
# 20063
# label:benign
# counter:
# 20064
# label:benign
# counter:
# 20065
# label:benign
# counter:
# 20066
# label:benign
# counter:
# 20067
# label:benign
# counter:
# 20068
# label:benign
# counter:
# 20069
# label:benign
# [[-0.14355604 -0.12157815 -0.23637779 ... -0.23879246 -0.14605401
#    0.2688061 ]
#  [-0.20816836 -0.13582517 -0.20343636 ...  0.20153527 -0.19432539
#    0.18177985]
#  [-0.09254336 -0.21375667 -0.2018833  ... -0.20229615 -0.20339811
#   -0.09004781]
#  ...
#  [-0.1543404  -0.15579952 -0.11491088 ... -0.24963011 -0.1636097
#   -0.22076383]
#  [-0.07832715 -0.15548491 -0.23413041 ... -0.21856748 -0.16801204
#   -0.1369934 ]
#  [-0.12014352 -0.13395858 -0.23293312 ... -0.21749319 -0.1554757
#   -0.1026706 ]]
# counter:
# 20070
# label:benign
# counter:
# 20071
# label:benign
# counter:
# 20072
# label:benign
# counter:
# 20073
# label:benign
# counter:
# 20074
# label:benign
# counter:
# 20075
# label:benign
# counter:
# 20076
# label:benign
# counter:
# 20077
# label:benign
# counter:
# 20078
# label:benign
# counter:
# 20079
# label:benign
# [[-0.183767   -0.11919402 -0.22821121 ... -0.14511913 -0.15721606
#    0.11953884]
#  [-0.06807369  0.24396577 -0.05327222 ... -0.08344853 -0.20610932
#   -0.20725341]
#  [-0.13133545 -0.01789905 -0.20409602 ...  0.3697413  -0.22979535
#   -0.01504698]
#  ...
#  [-0.06376635 -0.1171187  -0.15696073 ... -0.22296812 -0.18598907
#   -0.12055439]
#  [-0.06093176 -0.14001507  0.04785044 ... -0.22020085 -0.1653518
#   -0.08265412]
#  [-0.14817014 -0.20334569 -0.22594272 ... -0.15896128 -0.20279083
#   -0.18855871]]
# counter:
# 20080
# label:benign
# counter:
# 20081
# label:benign
# counter:
# 20082
# label:benign
# counter:
# 20083
# label:benign
# counter:
# 20084
# label:benign
# counter:
# 20085
# label:benign
# counter:
# 20086
# label:benign
# counter:
# 20087
# label:benign
# counter:
# 20088
# label:benign
# counter:
# 20089
# label:benign
# [[-0.13358355 -0.16447568 -0.04989973 ...  0.12542135 -0.20507318
#   -0.07280236]
#  [-0.06834784 -0.21393146 -0.23449294 ... -0.17377582 -0.17357951
#   -0.09296952]
#  [-0.0033997  -0.13775146 -0.20548503 ... -0.24135889 -0.2365066
#   -0.1410373 ]
#  ...
#  [-0.06936125 -0.18397401 -0.19243646 ... -0.19960077 -0.20113604
#    0.0455962 ]
#  [-0.15672949 -0.05855244 -0.17010796 ... -0.211069   -0.19737907
#   -0.1437443 ]
#  [-0.12595256 -0.17729166 -0.08846948 ... -0.2559882  -0.10214537
#    0.64617455]]
# counter:
# 20090
# label:benign
# counter:
# 20091
# label:benign
# counter:
# 20092
# label:benign
# counter:
# 20093
# label:benign
# counter:
# 20094
# label:benign
# counter:
# 20095
# label:benign
# counter:
# 20096
# label:benign
# counter:
# 20097
# label:benign
# counter:
# 20098
# label:benign
# counter:
# 20099
# label:benign
# [[-0.11284069 -0.1464476  -0.24259788 ...  0.03559909 -0.16037278
#   -0.07229003]
#  [-0.05758662 -0.04743937 -0.20480958 ... -0.25566602 -0.2034034
#   -0.18338284]
#  [-0.13161378 -0.18377544 -0.24407573 ... -0.01613995 -0.18357031
#   -0.12257969]
#  ...
#  [-0.06857581 -0.10135855 -0.25001258 ... -0.22271146 -0.1639079
#   -0.11824182]
#  [-0.10988769 -0.15031135 -0.23192014 ... -0.187625   -0.15981154
#   -0.09723313]
#  [-0.07688294 -0.0617791  -0.18883246 ... -0.07855924 -0.19427948
#   -0.2103471 ]]
# counter:
# 20100
# label:benign
# counter:
# 20101
# label:benign
# counter:
# 20102
# label:benign
# counter:
# 20103
# label:benign
# counter:
# 20104
# label:benign
# counter:
# 20105
# label:benign
# counter:
# 20106
# label:benign
# counter:
# 20107
# label:benign
# counter:
# 20108
# label:benign
# counter:
# 20109
# label:benign
# [[-0.09734506 -0.13886397 -0.0207868  ... -0.2380583  -0.13552019
#   -0.14204186]
#  [-0.10254256 -0.15815794 -0.23382244 ... -0.18946362 -0.12145692
#   -0.05014946]
#  [-0.06859095 -0.16247268 -0.18390374 ... -0.07789005 -0.11829294
#   -0.08511221]
#  ...
#  [-0.06634793 -0.20642032 -0.23315714 ... -0.00670272 -0.1599193
#   -0.17356695]
#  [-0.10543163 -0.17090836 -0.23724134 ... -0.13783596 -0.1917459
#   -0.11184444]
#  [-0.12871791 -0.14372422 -0.22364768 ... -0.18546277 -0.2492399
#   -0.0796983 ]]
# counter:
# 20110
# label:benign
# counter:
# 20111
# label:benign
# counter:
# 20112
# label:benign
# counter:
# 20113
# label:benign
# counter:
# 20114
# label:benign
# counter:
# 20115
# label:benign
# counter:
# 20116
# label:benign
# counter:
# 20117
# label:benign
# counter:
# 20118
# label:benign
# counter:
# 20119
# label:benign
# [[-0.0499057  -0.20565295 -0.21469569 ... -0.21251856 -0.13284834
#    0.03214157]
#  [-0.00405099 -0.229067    0.1908592  ... -0.11210846 -0.18120936
#   -0.05838711]
#  [-0.18314813 -0.14423254 -0.21598245 ... -0.20292729 -0.13525787
#    0.20928216]
#  ...
#  [-0.0737674  -0.10880616 -0.2140433  ... -0.23445888 -0.20065345
#   -0.14741407]
#  [-0.12883681 -0.16496448 -0.21466893 ...  0.22233321 -0.15948021
#   -0.08197577]
#  [-0.10687529 -0.15452068 -0.20369829 ... -0.24539825 -0.19346792
#    0.10176717]]
# counter:
# 20120
# label:benign
# counter:
# 20121
# label:benign
# counter:
# 20122
# label:benign
# counter:
# 20123
# label:benign
# counter:
# 20124
# label:benign
# counter:
# 20125
# label:benign
# counter:
# 20126
# label:benign
# counter:
# 20127
# label:benign
# counter:
# 20128
# label:benign
# counter:
# 20129
# label:benign
# [[-0.17686005 -0.1488399  -0.05593024 ... -0.18890716 -0.22922677
#    0.01710407]
#  [-0.11393334 -0.17241275 -0.07623458 ...  0.34014907 -0.14228025
#   -0.11669754]
#  [ 0.04466076 -0.17142713 -0.16430207 ... -0.23192906 -0.22974244
#   -0.06257857]
#  ...
#  [-0.02375135 -0.01181016 -0.23901474 ...  0.01235609 -0.19648705
#   -0.12152308]
#  [-0.07358585 -0.07337449 -0.2362569  ... -0.17849587 -0.20077409
#    0.2891366 ]
#  [ 0.06167578 -0.15886131 -0.2580739  ... -0.18346514 -0.14641179
#   -0.17130882]]
# counter:
# 20130
# label:benign
# counter:
# 20131
# label:benign
# counter:
# 20132
# label:benign
# counter:
# 20133
# label:benign
# counter:
# 20134
# label:benign
# counter:
# 20135
# label:benign
# counter:
# 20136
# label:benign
# counter:
# 20137
# label:benign
# counter:
# 20138
# label:benign
# counter:
# 20139
# label:benign
# [[-0.01449388 -0.05628387 -0.20116244 ... -0.08280478 -0.19141343
#    0.40865162]
#  [-0.04726612 -0.14083676 -0.24598566 ... -0.23321056 -0.19141757
#   -0.08778336]
#  [-0.14956231 -0.0652931   0.12153585 ... -0.01542126 -0.09826864
#   -0.16196145]
#  ...
#  [-0.15973186 -0.10717431 -0.13515984 ...  0.06391691 -0.18158066
#   -0.21505179]
#  [-0.17636696 -0.13732658 -0.12921874 ... -0.02521335 -0.17844953
#   -0.02662348]
#  [-0.1099604  -0.19168429 -0.25684518 ...  0.0132338  -0.2072116
#    0.20687108]]
# counter:
# 20140
# label:benign
# counter:
# 20141
# label:benign
# counter:
# 20142
# label:benign
# counter:
# 20143
# label:benign
# counter:
# 20144
# label:benign
# counter:
# 20145
# label:benign
# counter:
# 20146
# label:benign
# counter:
# 20147
# label:benign
# counter:
# 20148
# label:benign
# counter:
# 20149
# label:benign
# [[-0.17741813 -0.07553726 -0.03529399 ...  0.00086919 -0.15156011
#   -0.11097168]
#  [-0.13127269  0.06648438 -0.25710633 ... -0.1256618  -0.19483928
#   -0.14277059]
#  [-0.09076346 -0.09697609 -0.15009037 ... -0.11276385 -0.19368799
#    0.21556449]
#  ...
#  [ 0.03939286 -0.19231082 -0.04663238 ... -0.24795245 -0.13782977
#   -0.2418138 ]
#  [ 0.08577219 -0.11725532 -0.22509287 ...  0.09260226 -0.23843516
#   -0.08038904]
#  [-0.09396234 -0.07986246 -0.20909941 ... -0.19602545 -0.19254431
#    0.443519  ]]
# counter:
# 20150
# label:benign
# counter:
# 20151
# label:benign
# counter:
# 20152
# label:benign
# counter:
# 20153
# label:benign
# counter:
# 20154
# label:benign
# counter:
# 20155
# label:benign
# counter:
# 20156
# label:benign
# counter:
# 20157
# label:benign
# counter:
# 20158
# label:benign
# counter:
# 20159
# label:benign
# [[-0.02141934 -0.14457865 -0.17796446 ... -0.2169465  -0.11740142
#   -0.07376347]
#  [-0.1876629  -0.10021009 -0.19081086 ... -0.17098749 -0.105455
#   -0.21029828]
#  [-0.23798896 -0.05445568 -0.22750609 ... -0.24588273 -0.131703
#   -0.18942773]
#  ...
#  [-0.19176748 -0.1425854  -0.21850428 ... -0.24215776 -0.18035659
#   -0.05657096]
#  [-0.0679371  -0.17734966 -0.17728521 ... -0.17150097 -0.16687813
#   -0.1403289 ]
#  [-0.18489283 -0.13540672 -0.13336906 ... -0.1302062  -0.22549044
#   -0.1747837 ]]
# counter:
# 20160
# label:benign
# 51124224
# 33284

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
# from tensorflow.keras.applications.resnet50 import ResNet50
# from keras.models import Model
# import keras

x = np.array(X)
y = np.array(Y)
# pre_trained_models = {}
# pre_trained_models["ResNet50"] = ResNet50(include_top=False, input_shape=(224, 224, 3), pooling="avg", weights = 'imagenet')

# temp = 0
# for layer in pre_trained_models["ResNet50"].layers:
#     layer.trainable = False
#     temp += 1

# print("tedad:")
# print(temp)
# print(sys.getsizeof(pre_trained_models["ResNet50"].layers))
# print(pre_trained_models["ResNet50"].layers)

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=0)
# X_train = pre_trained_models["ResNet50"].predict(X_train)
# X_test = pre_trained_models["ResNet50"].predict(X_test)


# print("X_train:")
# print(X_train.shape)


# print(X_train)

# print("X_test:")
# print(X_test.shape)

print("x:")
print(x.shape)



# print("koltedad:")
# o = pre_trained_models["ResNet50"].predict(x)
# print(o.shape)
# print("kol:")
# print(o)






print(x[0])
# Out:
# x:
# (33284, 1536)
# [-0.15629721 -0.11510029 -0.11288424 ... -0.21911892 -0.19244389
#  -0.1859428 ]

# %% [markdown]
# VGG19

# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import preprocess_input
import numpy as np

model = VGG19(weights='imagenet', pooling="avg", include_top=False)

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# 80150528/80134624 [==============================] - 0s 0us/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-519e6949f247> in <module>()
#       6 model = VGG19(weights='imagenet', pooling="avg", include_top=False)
#       7
# ----> 8 features = model.predict(x)
#       9
#      10 print(features.shape)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     100       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101   ctx.ensure_initialized()
# --> 102   return ops.EagerTensor(value, ctx.device_name, dtype)
#     103
#     104
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type list).

# %% [markdown]
# DenseNet201

# %%
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.applications.densenet import preprocess_input
import numpy as np

model = DenseNet201(weights='imagenet', pooling="avg", include_top=False)

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 1s 0us/step
# 74850304/74836368 [==============================] - 1s 0us/step
# (80, 1920)

# %% [markdown]
# ResNet101

# %%
from tensorflow.keras.applications.resnet import ResNet101
import numpy as np

model = ResNet101(include_top=False, input_shape=(224, 224, 3), pooling="avg", weights = 'imagenet')
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171450368/171446536 [==============================] - 2s 0us/step
# 171458560/171446536 [==============================] - 2s 0us/step
# (80, 2048)

# %% [markdown]
# ResNet152

# %%
from tensorflow.keras.applications.resnet import ResNet152
import numpy as np

model = ResNet152(include_top=False, input_shape=(224, 224, 3), pooling="avg", weights = 'imagenet')
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234700800/234698864 [==============================] - 3s 0us/step
# 234708992/234698864 [==============================] - 3s 0us/step
# (80, 2048)

# %% [markdown]
# InceptionV3

# %%
from tensorflow.keras.applications import InceptionV3
import numpy as np

model = InceptionV3(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# 87924736/87910968 [==============================] - 1s 0us/step
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f582ad4ea70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (80, 2048)

# %% [markdown]
# InceptionResNetV2

# %%
from tensorflow.keras.applications import InceptionResNetV2
import numpy as np

model = InceptionResNetV2(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 2s 0us/step
# 219070464/219055592 [==============================] - 2s 0us/step
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f5827e72a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (80, 1536)

# %% [markdown]
# MobileNet

# %%
from tensorflow.keras.applications import MobileNet
import numpy as np

model = MobileNet(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 0s 0us/step
# 17235968/17225924 [==============================] - 0s 0us/step
# (80, 1024)

# %% [markdown]
# NASNetMobile

# %%
from tensorflow.keras.applications import NASNetMobile
import numpy as np

model = NASNetMobile(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19996672/19993432 [==============================] - 0s 0us/step
# 20004864/19993432 [==============================] - 0s 0us/step
# (80, 1056)

# %% [markdown]
# EfficientNetB0

# %%
from tensorflow.keras.applications import EfficientNetB0
import numpy as np

model = EfficientNetB0(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16711680/16705208 [==============================] - 0s 0us/step
# 16719872/16705208 [==============================] - 0s 0us/step
# (80, 1280)

# %% [markdown]
# EfficientNetB1

# %%
from tensorflow.keras.applications import EfficientNetB1
import numpy as np

model = EfficientNetB1(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb1_notop.h5
# 27025408/27018416 [==============================] - 0s 0us/step
# 27033600/27018416 [==============================] - 0s 0us/step
# (80, 1280)

# %% [markdown]
# EfficientNetB2

# %%
from tensorflow.keras.applications import EfficientNetB2
import numpy as np

model = EfficientNetB2(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31793152/31790344 [==============================] - 0s 0us/step
# 31801344/31790344 [==============================] - 0s 0us/step
# (80, 1408)

# %% [markdown]
# EfficientNetB3

# %%
from tensorflow.keras.applications import EfficientNetB3
import numpy as np

model = EfficientNetB3(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941888/43941136 [==============================] - 0s 0us/step
# 43950080/43941136 [==============================] - 0s 0us/step
# (80, 1536)

# %% [markdown]
# EfficientNetB4

# %%
from tensorflow.keras.applications import EfficientNetB4
import numpy as np

model = EfficientNetB4(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71688192/71686520 [==============================] - 1s 0us/step
# 71696384/71686520 [==============================] - 1s 0us/step
# (80, 1792)

# %% [markdown]
# EfficientNetB5

# %%
from tensorflow.keras.applications import EfficientNetB5
import numpy as np

model = EfficientNetB5(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115269632/115263384 [==============================] - 1s 0us/step
# 115277824/115263384 [==============================] - 1s 0us/step
# (80, 2048)

# %% [markdown]
# EfficientNetB6

# %%
from tensorflow.keras.applications import EfficientNetB6
import numpy as np

model = EfficientNetB6(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb6_notop.h5
# 165240832/165234480 [==============================] - 3s 0us/step
# 165249024/165234480 [==============================] - 3s 0us/step
# (80, 2304)

# %% [markdown]
# EfficientNetB7

# %%
from tensorflow.keras.applications import EfficientNetB7
import numpy as np

model = EfficientNetB7(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258080768/258076736 [==============================] - 3s 0us/step
# 258088960/258076736 [==============================] - 3s 0us/step
# (80, 2560)

# %% [markdown]
# DenseNet121

# %%
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input
import numpy as np

model = DenseNet121(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# 29097984/29084464 [==============================] - 0s 0us/step
# (80, 1024)

# %% [markdown]
# DenseNet169

# %%
from tensorflow.keras.applications import DenseNet169
from tensorflow.keras.applications.densenet import preprocess_input
import numpy as np

model = DenseNet169(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51879936/51877672 [==============================] - 1s 0us/step
# 51888128/51877672 [==============================] - 1s 0us/step
# (80, 1664)

# %% [markdown]
# VGG16

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
import numpy as np

model = VGG16(weights='imagenet', pooling="avg", include_top=False)

for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 58900480/58889256 [==============================] - 1s 0us/step
# (80, 512)

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
result = {}
Classifier = XGBClassifier(learning_rate=0.9, n_estimators=150, random_state=0, seed=0, gamma=0)
Classifier.fit(X_train, Y_train)
Y_pred = Classifier.predict(X_test)
print("Accuracy score : ", accuracy_score(Y_test, Y_pred))
# print(X_train)
# print(X_test)
# print(Y_train)
# print(Y_test)

# print(Y_test)
# print(Y_pred)
# Out:
# Accuracy score :  0.8708191468055277

# %% [markdown]
# ## Visualising the Linear Regression results
