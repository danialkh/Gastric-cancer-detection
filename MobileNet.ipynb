# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
from glob import glob
import cv2
from matplotlib import pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate, KFold
from keras.losses import SparseCategoricalCrossentropy, CategoricalCrossentropy
from xgboost import XGBClassifier
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, confusion_matrix, f1_score, precision_score, recall_score, roc_curve, auc
from google.colab import drive
# import glob



from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Importing the dataset

# %%
images_path = {}
images_path["malignant"] = glob("/content/drive/MyDrive/dani/GasHisSDB/160/Abnormal/*.png")
images_path["benign"] = glob("/content/drive/MyDrive/dani/GasHisSDB/160/Normal/*.png")


images_class = {
    'benign' : 0,
    'malignant' : 1
}

import sys

from tensorflow.keras.applications import ResNet50
from keras.models import Model
import keras

pre_trained_models = {}


from tensorflow.keras.applications import MobileNet
import numpy as np

pre_trained_models["MobileNet"] = MobileNet(weights='imagenet', pooling="avg", include_top=False)
for layer in pre_trained_models["MobileNet"].layers:
    layer.trainable = False


# print(images_path["malignant"])
counter = 0




Y = []
Z = []
pos = 0
for label in images_path:
    counter = 0
    for image_path in images_path[label]:
        # print(counter, ' / ', all)
        counter += 1
        if(1):
          image = cv2.imread(image_path)
          image = cv2.resize(image,(224, 224))
          Z.append(image)
          
          if(counter % 10 == 0):
            temp = np.array(Z)
            

            feature_MobileNet = pre_trained_models["MobileNet"].predict(temp)
            print(feature_MobileNet)

            for b in feature_MobileNet:
              c = b.tolist()
              if(pos == 0):
                  X =  [c]
              else:
                X.append(c)


              pos += 1
              # print("shapeX:")
              # o = np.array(X)
              # print(o.shape)


           
            
            # print(X)
            Z = []
          

          Y.append(images_class[label])
          # print(sys.getsizeof(X)/1000000)
          print("counter:")
          print(counter)
          print("label:" + label)
        else:
          continue

print(np.size(X))
print(np.size(Y))
# Out:
# Streaming output truncated to the last 5000 lines.
# label:benign
# counter:
# 18855
# label:benign
# counter:
# 18856
# label:benign
# counter:
# 18857
# label:benign
# counter:
# 18858
# label:benign
# counter:
# 18859
# label:benign
# [[0.         0.9272901  0.         ... 0.68044275 0.         0.        ]
#  [0.         1.0045775  0.         ... 0.3434661  0.         0.        ]
#  [0.         0.6902516  0.         ... 0.02633177 0.         0.        ]
#  ...
#  [0.         1.3426397  0.         ... 0.30225313 0.         0.00545478]
#  [0.         0.48836446 0.         ... 0.10882064 0.         0.        ]
#  [0.         0.7817003  0.         ... 0.68506444 0.         0.        ]]
# counter:
# 18860
# label:benign
# counter:
# 18861
# label:benign
# counter:
# 18862
# label:benign
# counter:
# 18863
# label:benign
# counter:
# 18864
# label:benign
# counter:
# 18865
# label:benign
# counter:
# 18866
# label:benign
# counter:
# 18867
# label:benign
# counter:
# 18868
# label:benign
# counter:
# 18869
# label:benign
# [[0.         0.39463404 0.         ... 0.01227335 0.         0.        ]
#  [0.         0.6511385  0.         ... 0.03009855 0.         0.        ]
#  [0.00575918 1.1847771  0.         ... 0.7120397  0.         0.        ]
#  ...
#  [0.         2.2238622  0.         ... 0.5078144  0.         0.        ]
#  [0.         0.65111077 0.         ... 0.599009   0.         0.00856337]
#  [0.         0.3058437  0.         ... 0.08226889 0.         0.        ]]
# counter:
# 18870
# label:benign
# counter:
# 18871
# label:benign
# counter:
# 18872
# label:benign
# counter:
# 18873
# label:benign
# counter:
# 18874
# label:benign
# counter:
# 18875
# label:benign
# counter:
# 18876
# label:benign
# counter:
# 18877
# label:benign
# counter:
# 18878
# label:benign
# counter:
# 18879
# label:benign
# [[0.         0.6464704  0.         ... 0.02631725 0.         0.        ]
#  [0.         0.6119732  0.         ... 0.         0.         0.        ]
#  [0.00663258 0.6255744  0.         ... 0.10539582 0.         0.        ]
#  ...
#  [0.         0.11018176 0.         ... 0.0126817  0.         0.        ]
#  [0.         1.0872632  0.         ... 0.06140626 0.         0.        ]
#  [0.         0.28563914 0.         ... 0.32799736 0.         0.00464294]]
# counter:
# 18880
# label:benign
# counter:
# 18881
# label:benign
# counter:
# 18882
# label:benign
# counter:
# 18883
# label:benign
# counter:
# 18884
# label:benign
# counter:
# 18885
# label:benign
# counter:
# 18886
# label:benign
# counter:
# 18887
# label:benign
# counter:
# 18888
# label:benign
# counter:
# 18889
# label:benign
# [[0.         0.4364867  0.         ... 0.         0.         0.        ]
#  [0.         0.30906293 0.         ... 0.15702784 0.00834717 0.        ]
#  [0.         0.8271576  0.         ... 0.15247251 0.         0.        ]
#  ...
#  [0.         1.4497778  0.         ... 0.5152614  0.         0.        ]
#  [0.         0.4274109  0.         ... 0.04202167 0.         0.        ]
#  [0.         1.8666553  0.         ... 0.23943286 0.         0.        ]]
# counter:
# 18890
# label:benign
# counter:
# 18891
# label:benign
# counter:
# 18892
# label:benign
# counter:
# 18893
# label:benign
# counter:
# 18894
# label:benign
# counter:
# 18895
# label:benign
# counter:
# 18896
# label:benign
# counter:
# 18897
# label:benign
# counter:
# 18898
# label:benign
# counter:
# 18899
# label:benign
# [[0.         0.6950145  0.         ... 0.61678123 0.         0.01555205]
#  [0.         0.         0.         ... 0.09295816 0.         0.        ]
#  [0.         1.5638653  0.         ... 0.10755109 0.         0.        ]
#  ...
#  [0.         1.6565555  0.         ... 0.20152442 0.         0.        ]
#  [0.         0.7734059  0.         ... 0.04517695 0.         0.        ]
#  [0.         0.71755046 0.         ... 0.33924273 0.         0.        ]]
# counter:
# 18900
# label:benign
# counter:
# 18901
# label:benign
# counter:
# 18902
# label:benign
# counter:
# 18903
# label:benign
# counter:
# 18904
# label:benign
# counter:
# 18905
# label:benign
# counter:
# 18906
# label:benign
# counter:
# 18907
# label:benign
# counter:
# 18908
# label:benign
# counter:
# 18909
# label:benign
# [[0.         0.62534946 0.         ... 0.11083864 0.         0.        ]
#  [0.         0.0873767  0.         ... 0.035831   0.         0.        ]
#  [0.         1.4129293  0.         ... 0.03317286 0.         0.        ]
#  ...
#  [0.         0.4569662  0.         ... 0.01725765 0.         0.        ]
#  [0.         1.0840158  0.         ... 0.02866921 0.         0.10262085]
#  [0.         0.2136218  0.         ... 0.1141706  0.         0.        ]]
# counter:
# 18910
# label:benign
# counter:
# 18911
# label:benign
# counter:
# 18912
# label:benign
# counter:
# 18913
# label:benign
# counter:
# 18914
# label:benign
# counter:
# 18915
# label:benign
# counter:
# 18916
# label:benign
# counter:
# 18917
# label:benign
# counter:
# 18918
# label:benign
# counter:
# 18919
# label:benign
# [[0.         0.1274096  0.0089052  ... 0.1397823  0.         0.        ]
#  [0.         1.1409718  0.         ... 0.39658365 0.         0.        ]
#  [0.         1.527954   0.         ... 0.4458646  0.         0.        ]
#  ...
#  [0.         0.30407408 0.         ... 0.         0.         0.01256486]
#  [0.         0.97984827 0.         ... 0.3121475  0.         0.        ]
#  [0.         0.20325643 0.         ... 0.6507149  0.         0.04037578]]
# counter:
# 18920
# label:benign
# counter:
# 18921
# label:benign
# counter:
# 18922
# label:benign
# counter:
# 18923
# label:benign
# counter:
# 18924
# label:benign
# counter:
# 18925
# label:benign
# counter:
# 18926
# label:benign
# counter:
# 18927
# label:benign
# counter:
# 18928
# label:benign
# counter:
# 18929
# label:benign
# [[0.         0.46190932 0.         ... 0.0730371  0.         0.1365395 ]
#  [0.         0.59110063 0.         ... 0.26890257 0.         0.        ]
#  [0.         0.70563304 0.         ... 0.09142216 0.         0.        ]
#  ...
#  [0.         0.9025138  0.         ... 1.2234852  0.         0.        ]
#  [0.         1.1514266  0.         ... 0.3681177  0.         0.        ]
#  [0.0127349  1.3177316  0.         ... 0.31833342 0.         0.        ]]
# counter:
# 18930
# label:benign
# counter:
# 18931
# label:benign
# counter:
# 18932
# label:benign
# counter:
# 18933
# label:benign
# counter:
# 18934
# label:benign
# counter:
# 18935
# label:benign
# counter:
# 18936
# label:benign
# counter:
# 18937
# label:benign
# counter:
# 18938
# label:benign
# counter:
# 18939
# label:benign
# [[0.0000000e+00 1.0632675e+00 0.0000000e+00 ... 1.2133968e-03
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 2.1751961e-01 0.0000000e+00 ... 4.5152538e-02
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 2.4690624e-01 0.0000000e+00 ... 4.4361513e-02
#   0.0000000e+00 0.0000000e+00]
#  ...
#  [0.0000000e+00 1.0065221e+00 0.0000000e+00 ... 9.1173247e-02
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 8.7516852e-02 0.0000000e+00 ... 3.8451898e-01
#   0.0000000e+00 4.2591337e-02]
#  [0.0000000e+00 1.6807489e+00 0.0000000e+00 ... 7.4068695e-02
#   0.0000000e+00 0.0000000e+00]]
# counter:
# 18940
# label:benign
# counter:
# 18941
# label:benign
# counter:
# 18942
# label:benign
# counter:
# 18943
# label:benign
# counter:
# 18944
# label:benign
# counter:
# 18945
# label:benign
# counter:
# 18946
# label:benign
# counter:
# 18947
# label:benign
# counter:
# 18948
# label:benign
# counter:
# 18949
# label:benign
# [[0.0000000e+00 5.0785887e-01 0.0000000e+00 ... 6.8280841e-03
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 1.1292205e+00 0.0000000e+00 ... 4.2745373e-01
#   0.0000000e+00 1.3009681e-03]
#  [0.0000000e+00 3.0039558e-01 0.0000000e+00 ... 5.1718551e-01
#   0.0000000e+00 0.0000000e+00]
#  ...
#  [0.0000000e+00 3.6680517e-01 2.6841125e-02 ... 1.7829720e-02
#   0.0000000e+00 1.0077884e-02]
#  [0.0000000e+00 1.4088497e+00 0.0000000e+00 ... 8.7716080e-02
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]]
# counter:
# 18950
# label:benign
# counter:
# 18951
# label:benign
# counter:
# 18952
# label:benign
# counter:
# 18953
# label:benign
# counter:
# 18954
# label:benign
# counter:
# 18955
# label:benign
# counter:
# 18956
# label:benign
# counter:
# 18957
# label:benign
# counter:
# 18958
# label:benign
# counter:
# 18959
# label:benign
# [[0.         0.9342435  0.         ... 0.5426255  0.         0.        ]
#  [0.         1.2877016  0.         ... 0.02082193 0.         0.00455449]
#  [0.         0.7142749  0.         ... 0.3293593  0.         0.        ]
#  ...
#  [0.         0.9316491  0.         ... 0.31745845 0.         0.        ]
#  [0.         1.1928183  0.         ... 0.         0.         0.04916647]
#  [0.         0.32363597 0.         ... 0.15259327 0.         0.        ]]
# counter:
# 18960
# label:benign
# counter:
# 18961
# label:benign
# counter:
# 18962
# label:benign
# counter:
# 18963
# label:benign
# counter:
# 18964
# label:benign
# counter:
# 18965
# label:benign
# counter:
# 18966
# label:benign
# counter:
# 18967
# label:benign
# counter:
# 18968
# label:benign
# counter:
# 18969
# label:benign
# [[0.         0.61410505 0.         ... 0.1355893  0.         0.        ]
#  [0.         0.82675046 0.         ... 0.11653526 0.         0.        ]
#  [0.         0.95572126 0.         ... 0.24243261 0.         0.        ]
#  ...
#  [0.         1.8425328  0.         ... 0.56655097 0.         0.05892485]
#  [0.         1.1599858  0.         ... 0.09200922 0.         0.        ]
#  [0.         0.9034391  0.         ... 0.7784189  0.         0.06905252]]
# counter:
# 18970
# label:benign
# counter:
# 18971
# label:benign
# counter:
# 18972
# label:benign
# counter:
# 18973
# label:benign
# counter:
# 18974
# label:benign
# counter:
# 18975
# label:benign
# counter:
# 18976
# label:benign
# counter:
# 18977
# label:benign
# counter:
# 18978
# label:benign
# counter:
# 18979
# label:benign
# [[0.         1.1486104  0.         ... 0.86389947 0.         0.        ]
#  [0.         1.5775087  0.         ... 0.         0.         0.        ]
#  [0.         0.32920292 0.         ... 0.05714254 0.         0.00914872]
#  ...
#  [0.         0.12425239 0.         ... 0.3451317  0.         0.        ]
#  [0.         0.6708524  0.         ... 0.43113047 0.         0.03758302]
#  [0.         0.48619083 0.00358452 ... 0.         0.         0.        ]]
# counter:
# 18980
# label:benign
# counter:
# 18981
# label:benign
# counter:
# 18982
# label:benign
# counter:
# 18983
# label:benign
# counter:
# 18984
# label:benign
# counter:
# 18985
# label:benign
# counter:
# 18986
# label:benign
# counter:
# 18987
# label:benign
# counter:
# 18988
# label:benign
# counter:
# 18989
# label:benign
# [[0.         0.12427852 0.         ... 0.18948752 0.         0.        ]
#  [0.         0.7575598  0.         ... 0.0181703  0.         0.        ]
#  [0.         0.18616243 0.00566339 ... 0.27901214 0.0230842  0.        ]
#  ...
#  [0.         1.1851231  0.         ... 0.08463085 0.         0.        ]
#  [0.         0.09240402 0.         ... 0.         0.         0.01681725]
#  [0.         0.6134063  0.         ... 0.08667593 0.         0.        ]]
# counter:
# 18990
# label:benign
# counter:
# 18991
# label:benign
# counter:
# 18992
# label:benign
# counter:
# 18993
# label:benign
# counter:
# 18994
# label:benign
# counter:
# 18995
# label:benign
# counter:
# 18996
# label:benign
# counter:
# 18997
# label:benign
# counter:
# 18998
# label:benign
# counter:
# 18999
# label:benign
# [[0.         0.48428532 0.         ... 0.37288094 0.         0.        ]
#  [0.         0.8538884  0.         ... 0.32698214 0.         0.        ]
#  [0.         1.3898574  0.         ... 0.20808686 0.         0.        ]
#  ...
#  [0.         1.7653697  0.         ... 0.53269356 0.         0.        ]
#  [0.         1.1346631  0.         ... 0.18406059 0.         0.        ]
#  [0.         0.43113112 0.         ... 0.13239917 0.         0.        ]]
# counter:
# 19000
# label:benign
# counter:
# 19001
# label:benign
# counter:
# 19002
# label:benign
# counter:
# 19003
# label:benign
# counter:
# 19004
# label:benign
# counter:
# 19005
# label:benign
# counter:
# 19006
# label:benign
# counter:
# 19007
# label:benign
# counter:
# 19008
# label:benign
# counter:
# 19009
# label:benign
# [[0.0000000e+00 3.7946215e-01 0.0000000e+00 ... 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 5.3743237e-01 0.0000000e+00 ... 4.7218736e-02
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 2.1415018e-01 0.0000000e+00 ... 2.6506332e-01
#   0.0000000e+00 0.0000000e+00]
#  ...
#  [0.0000000e+00 2.0663915e+00 0.0000000e+00 ... 3.2565799e-01
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 2.7271065e-01 0.0000000e+00 ... 8.0400443e-01
#   0.0000000e+00 4.0816184e-04]
#  [0.0000000e+00 5.8010763e-01 0.0000000e+00 ... 4.5103329e-01
#   0.0000000e+00 0.0000000e+00]]
# counter:
# 19010
# label:benign
# counter:
# 19011
# label:benign
# counter:
# 19012
# label:benign
# counter:
# 19013
# label:benign
# counter:
# 19014
# label:benign
# counter:
# 19015
# label:benign
# counter:
# 19016
# label:benign
# counter:
# 19017
# label:benign
# counter:
# 19018
# label:benign
# counter:
# 19019
# label:benign
# [[0.0000000e+00 8.4895527e-01 0.0000000e+00 ... 1.8209031e-01
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 1.0365721e+00 0.0000000e+00 ... 1.0112557e+00
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#   0.0000000e+00 5.4515724e-04]
#  ...
#  [0.0000000e+00 4.5953789e-01 0.0000000e+00 ... 2.5864047e-01
#   0.0000000e+00 1.6425885e-02]
#  [0.0000000e+00 5.9812832e-01 0.0000000e+00 ... 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 1.1547271e+00 0.0000000e+00 ... 6.2730473e-01
#   0.0000000e+00 0.0000000e+00]]
# counter:
# 19020
# label:benign
# counter:
# 19021
# label:benign
# counter:
# 19022
# label:benign
# counter:
# 19023
# label:benign
# counter:
# 19024
# label:benign
# counter:
# 19025
# label:benign
# counter:
# 19026
# label:benign
# counter:
# 19027
# label:benign
# counter:
# 19028
# label:benign
# counter:
# 19029
# label:benign
# [[0.         1.6762518  0.         ... 0.26376322 0.         0.        ]
#  [0.         0.7809126  0.         ... 0.23091674 0.         0.        ]
#  [0.         1.2710909  0.         ... 0.3397427  0.09732269 0.        ]
#  ...
#  [0.         0.75194365 0.         ... 0.14954916 0.         0.        ]
#  [0.         0.7454971  0.         ... 0.13252169 0.         0.01534728]
#  [0.         0.7320765  0.         ... 0.16535683 0.         0.05411323]]
# counter:
# 19030
# label:benign
# counter:
# 19031
# label:benign
# counter:
# 19032
# label:benign
# counter:
# 19033
# label:benign
# counter:
# 19034
# label:benign
# counter:
# 19035
# label:benign
# counter:
# 19036
# label:benign
# counter:
# 19037
# label:benign
# counter:
# 19038
# label:benign
# counter:
# 19039
# label:benign
# [[0.         0.13430813 0.         ... 0.01390722 0.         0.042837  ]
#  [0.         0.37040928 0.         ... 0.0308512  0.         0.        ]
#  [0.         0.06330337 0.         ... 0.3852885  0.         0.        ]
#  ...
#  [0.         0.57627535 0.         ... 0.09587888 0.         0.        ]
#  [0.         0.42889115 0.         ... 0.02439759 0.         0.        ]
#  [0.         0.7031945  0.         ... 0.         0.         0.        ]]
# counter:
# 19040
# label:benign
# counter:
# 19041
# label:benign
# counter:
# 19042
# label:benign
# counter:
# 19043
# label:benign
# counter:
# 19044
# label:benign
# counter:
# 19045
# label:benign
# counter:
# 19046
# label:benign
# counter:
# 19047
# label:benign
# counter:
# 19048
# label:benign
# counter:
# 19049
# label:benign
# [[0.         0.02250397 0.         ... 0.07487498 0.         0.        ]
#  [0.         1.6488429  0.         ... 0.2144391  0.         0.        ]
#  [0.         0.6067578  0.         ... 0.21563636 0.         0.        ]
#  ...
#  [0.         0.8852483  0.         ... 0.31764174 0.         0.        ]
#  [0.         0.6700992  0.         ... 0.04816254 0.         0.        ]
#  [0.         1.174847   0.         ... 0.0989708  0.         0.0559218 ]]
# counter:
# 19050
# label:benign
# counter:
# 19051
# label:benign
# counter:
# 19052
# label:benign
# counter:
# 19053
# label:benign
# counter:
# 19054
# label:benign
# counter:
# 19055
# label:benign
# counter:
# 19056
# label:benign
# counter:
# 19057
# label:benign
# counter:
# 19058
# label:benign
# counter:
# 19059
# label:benign
# [[0.         0.20707446 0.         ... 0.14434245 0.01735636 0.        ]
#  [0.         0.6091646  0.         ... 0.20929757 0.         0.        ]
#  [0.         1.0407262  0.         ... 0.47568852 0.         0.00642312]
#  ...
#  [0.         0.5068914  0.         ... 0.05450969 0.         0.01705363]
#  [0.         0.35279334 0.         ... 0.26085034 0.         0.        ]
#  [0.         0.4584127  0.         ... 0.         0.         0.        ]]
# counter:
# 19060
# label:benign
# counter:
# 19061
# label:benign
# counter:
# 19062
# label:benign
# counter:
# 19063
# label:benign
# counter:
# 19064
# label:benign
# counter:
# 19065
# label:benign
# counter:
# 19066
# label:benign
# counter:
# 19067
# label:benign
# counter:
# 19068
# label:benign
# counter:
# 19069
# label:benign
# [[0.0000000e+00 2.1591246e+00 0.0000000e+00 ... 3.1426892e-01
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 2.2317182e-01 0.0000000e+00 ... 1.6020401e-01
#   0.0000000e+00 6.4996333e-04]
#  [0.0000000e+00 1.1614901e+00 0.0000000e+00 ... 7.2286904e-02
#   0.0000000e+00 0.0000000e+00]
#  ...
#  [0.0000000e+00 8.9823119e-02 0.0000000e+00 ... 5.6391481e-02
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 1.5131199e-01 0.0000000e+00 ... 1.0172736e-01
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 2.1453018e-01 0.0000000e+00 ... 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]]
# counter:
# 19070
# label:benign
# counter:
# 19071
# label:benign
# counter:
# 19072
# label:benign
# counter:
# 19073
# label:benign
# counter:
# 19074
# label:benign
# counter:
# 19075
# label:benign
# counter:
# 19076
# label:benign
# counter:
# 19077
# label:benign
# counter:
# 19078
# label:benign
# counter:
# 19079
# label:benign
# [[0.0000000e+00 5.3393281e-01 0.0000000e+00 ... 3.1627196e-01
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 1.1991842e+00 0.0000000e+00 ... 3.5807872e-01
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 1.3472477e+00 0.0000000e+00 ... 3.2643355e-02
#   0.0000000e+00 0.0000000e+00]
#  ...
#  [0.0000000e+00 3.0128276e-01 0.0000000e+00 ... 4.5024734e-03
#   0.0000000e+00 1.4232838e-01]
#  [0.0000000e+00 1.0260960e+00 0.0000000e+00 ... 2.1633781e-02
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 7.4817425e-01 0.0000000e+00 ... 2.9472679e-01
#   0.0000000e+00 8.7865657e-05]]
# counter:
# 19080
# label:benign
# counter:
# 19081
# label:benign
# counter:
# 19082
# label:benign
# counter:
# 19083
# label:benign
# counter:
# 19084
# label:benign
# counter:
# 19085
# label:benign
# counter:
# 19086
# label:benign
# counter:
# 19087
# label:benign
# counter:
# 19088
# label:benign
# counter:
# 19089
# label:benign
# [[0.         0.27838653 0.         ... 0.1754709  0.         0.        ]
#  [0.         0.         0.00164428 ... 0.         0.         0.        ]
#  [0.         0.44057995 0.         ... 0.0110368  0.         0.        ]
#  ...
#  [0.         0.93215466 0.         ... 0.14340696 0.         0.        ]
#  [0.         1.492166   0.         ... 0.15945731 0.         0.        ]
#  [0.         1.5883042  0.         ... 0.34646317 0.         0.        ]]
# counter:
# 19090
# label:benign
# counter:
# 19091
# label:benign
# counter:
# 19092
# label:benign
# counter:
# 19093
# label:benign
# counter:
# 19094
# label:benign
# counter:
# 19095
# label:benign
# counter:
# 19096
# label:benign
# counter:
# 19097
# label:benign
# counter:
# 19098
# label:benign
# counter:
# 19099
# label:benign
# [[0.         1.3986049  0.         ... 0.45984307 0.         0.        ]
#  [0.         0.29436567 0.         ... 0.2996103  0.         0.        ]
#  [0.         1.0377032  0.         ... 0.4702561  0.         0.        ]
#  ...
#  [0.         0.1510136  0.         ... 0.00733952 0.         0.        ]
#  [0.         0.7617898  0.         ... 0.0569233  0.         0.01374224]
#  [0.         1.802616   0.         ... 0.23766723 0.         0.        ]]
# counter:
# 19100
# label:benign
# counter:
# 19101
# label:benign
# counter:
# 19102
# label:benign
# counter:
# 19103
# label:benign
# counter:
# 19104
# label:benign
# counter:
# 19105
# label:benign
# counter:
# 19106
# label:benign
# counter:
# 19107
# label:benign
# counter:
# 19108
# label:benign
# counter:
# 19109
# label:benign
# [[0.         0.49411613 0.         ... 0.11791312 0.07456298 0.        ]
#  [0.         0.60736513 0.         ... 0.31554583 0.         0.        ]
#  [0.         0.71716183 0.         ... 0.08035184 0.         0.14490299]
#  ...
#  [0.         0.39393753 0.         ... 0.09073477 0.         0.        ]
#  [0.         0.5760247  0.         ... 0.12870057 0.         0.        ]
#  [0.         0.41896632 0.         ... 0.02469975 0.         0.        ]]
# counter:
# 19110
# label:benign
# counter:
# 19111
# label:benign
# counter:
# 19112
# label:benign
# counter:
# 19113
# label:benign
# counter:
# 19114
# label:benign
# counter:
# 19115
# label:benign
# counter:
# 19116
# label:benign
# counter:
# 19117
# label:benign
# counter:
# 19118
# label:benign
# counter:
# 19119
# label:benign
# [[0.         1.3819283  0.         ... 0.07107803 0.         0.        ]
#  [0.         1.0504806  0.         ... 0.10118716 0.         0.        ]
#  [0.         0.         0.         ... 0.05706041 0.         0.        ]
#  ...
#  [0.         0.3462803  0.         ... 0.16138743 0.         0.        ]
#  [0.         0.73143613 0.         ... 0.7511637  0.         0.00622008]
#  [0.         0.4435846  0.         ... 0.12938884 0.         0.        ]]
# counter:
# 19120
# label:benign
# counter:
# 19121
# label:benign
# counter:
# 19122
# label:benign
# counter:
# 19123
# label:benign
# counter:
# 19124
# label:benign
# counter:
# 19125
# label:benign
# counter:
# 19126
# label:benign
# counter:
# 19127
# label:benign
# counter:
# 19128
# label:benign
# counter:
# 19129
# label:benign
# [[0.         1.5939817  0.         ... 0.57387584 0.         0.        ]
#  [0.         1.1266252  0.         ... 0.17778517 0.         0.        ]
#  [0.         0.13764946 0.         ... 0.         0.         0.02576155]
#  ...
#  [0.         1.1414307  0.         ... 0.04613623 0.         0.00449852]
#  [0.         0.7477751  0.         ... 0.         0.         0.        ]
#  [0.         0.32076883 0.         ... 0.06889699 0.         0.        ]]
# counter:
# 19130
# label:benign
# counter:
# 19131
# label:benign
# counter:
# 19132
# label:benign
# counter:
# 19133
# label:benign
# counter:
# 19134
# label:benign
# counter:
# 19135
# label:benign
# counter:
# 19136
# label:benign
# counter:
# 19137
# label:benign
# counter:
# 19138
# label:benign
# counter:
# 19139
# label:benign
# [[0.         0.7140157  0.         ... 0.04765558 0.         0.        ]
#  [0.         0.8082571  0.         ... 0.5241903  0.         0.        ]
#  [0.         1.7155497  0.         ... 0.25071865 0.         0.        ]
#  ...
#  [0.         0.7201932  0.         ... 0.5233073  0.         0.        ]
#  [0.         0.77597624 0.         ... 0.2937412  0.         0.        ]
#  [0.         0.52074194 0.         ... 0.548492   0.         0.        ]]
# counter:
# 19140
# label:benign
# counter:
# 19141
# label:benign
# counter:
# 19142
# label:benign
# counter:
# 19143
# label:benign
# counter:
# 19144
# label:benign
# counter:
# 19145
# label:benign
# counter:
# 19146
# label:benign
# counter:
# 19147
# label:benign
# counter:
# 19148
# label:benign
# counter:
# 19149
# label:benign
# [[0.         0.7211813  0.         ... 0.5101912  0.         0.        ]
#  [0.         0.00984028 0.         ... 0.01260129 0.         0.        ]
#  [0.05144039 0.3822543  0.         ... 0.1418029  0.         0.        ]
#  ...
#  [0.         0.76485157 0.         ... 0.4526442  0.         0.0020288 ]
#  [0.         1.0208726  0.         ... 0.19986841 0.         0.00105695]
#  [0.         0.18845297 0.         ... 0.10316805 0.         0.        ]]
# counter:
# 19150
# label:benign
# counter:
# 19151
# label:benign
# counter:
# 19152
# label:benign
# counter:
# 19153
# label:benign
# counter:
# 19154
# label:benign
# counter:
# 19155
# label:benign
# counter:
# 19156
# label:benign
# counter:
# 19157
# label:benign
# counter:
# 19158
# label:benign
# counter:
# 19159
# label:benign
# [[0.         1.3868189  0.         ... 0.16951789 0.         0.        ]
#  [0.         1.5872055  0.         ... 0.30251983 0.         0.        ]
#  [0.         1.0236057  0.         ... 0.2714729  0.         0.        ]
#  ...
#  [0.00665123 0.6269255  0.         ... 0.0914224  0.         0.        ]
#  [0.         0.3506999  0.         ... 0.8457436  0.         0.        ]
#  [0.         1.2124248  0.         ... 0.01024738 0.         0.        ]]
# counter:
# 19160
# label:benign
# counter:
# 19161
# label:benign
# counter:
# 19162
# label:benign
# counter:
# 19163
# label:benign
# counter:
# 19164
# label:benign
# counter:
# 19165
# label:benign
# counter:
# 19166
# label:benign
# counter:
# 19167
# label:benign
# counter:
# 19168
# label:benign
# counter:
# 19169
# label:benign
# [[0.         1.3755249  0.         ... 0.05991173 0.         0.        ]
#  [0.         1.126911   0.         ... 0.0804642  0.         0.        ]
#  [0.         1.1176777  0.         ... 0.         0.         0.00970432]
#  ...
#  [0.         0.32315555 0.         ... 0.17055593 0.         0.        ]
#  [0.         0.58865577 0.         ... 0.03023377 0.         0.        ]
#  [0.         1.3157678  0.         ... 1.4881337  0.         0.        ]]
# counter:
# 19170
# label:benign
# counter:
# 19171
# label:benign
# counter:
# 19172
# label:benign
# counter:
# 19173
# label:benign
# counter:
# 19174
# label:benign
# counter:
# 19175
# label:benign
# counter:
# 19176
# label:benign
# counter:
# 19177
# label:benign
# counter:
# 19178
# label:benign
# counter:
# 19179
# label:benign
# [[0.         0.265813   0.         ... 0.05853184 0.         0.        ]
#  [0.         1.619774   0.         ... 0.18336844 0.         0.        ]
#  [0.         1.9860718  0.         ... 0.15378241 0.         0.        ]
#  ...
#  [0.         0.56867385 0.         ... 0.05320629 0.         0.        ]
#  [0.         0.07692278 0.         ... 0.16071627 0.         0.03378772]
#  [0.         1.1092135  0.         ... 0.09125738 0.         0.        ]]
# counter:
# 19180
# label:benign
# counter:
# 19181
# label:benign
# counter:
# 19182
# label:benign
# counter:
# 19183
# label:benign
# counter:
# 19184
# label:benign
# counter:
# 19185
# label:benign
# counter:
# 19186
# label:benign
# counter:
# 19187
# label:benign
# counter:
# 19188
# label:benign
# counter:
# 19189
# label:benign
# [[0.         1.3430582  0.         ... 0.19368267 0.         0.01032033]
#  [0.         1.3594743  0.         ... 0.32617524 0.         0.        ]
#  [0.         0.75762683 0.         ... 0.08357718 0.         0.0619551 ]
#  ...
#  [0.         1.4748193  0.         ... 0.3897649  0.         0.        ]
#  [0.         0.41988218 0.         ... 0.         0.         0.        ]
#  [0.         0.47139788 0.         ... 0.         0.         0.        ]]
# counter:
# 19190
# label:benign
# counter:
# 19191
# label:benign
# counter:
# 19192
# label:benign
# counter:
# 19193
# label:benign
# counter:
# 19194
# label:benign
# counter:
# 19195
# label:benign
# counter:
# 19196
# label:benign
# counter:
# 19197
# label:benign
# counter:
# 19198
# label:benign
# counter:
# 19199
# label:benign
# [[0.         0.23343523 0.         ... 0.79263085 0.         0.        ]
#  [0.         0.2727834  0.         ... 0.2983105  0.         0.        ]
#  [0.         1.1583267  0.         ... 0.2131597  0.         0.        ]
#  ...
#  [0.         0.6933026  0.         ... 0.32756236 0.         0.        ]
#  [0.         0.3099878  0.         ... 0.09507709 0.         0.00556421]
#  [0.         0.29925245 0.         ... 0.14353125 0.         0.02437475]]
# counter:
# 19200
# label:benign
# counter:
# 19201
# label:benign
# counter:
# 19202
# label:benign
# counter:
# 19203
# label:benign
# counter:
# 19204
# label:benign
# counter:
# 19205
# label:benign
# counter:
# 19206
# label:benign
# counter:
# 19207
# label:benign
# counter:
# 19208
# label:benign
# counter:
# 19209
# label:benign
# [[0.         0.77463955 0.         ... 0.1760088  0.         0.        ]
#  [0.         0.18965207 0.         ... 0.         0.         0.        ]
#  [0.         0.5868956  0.         ... 0.03373763 0.         0.        ]
#  ...
#  [0.         0.83898705 0.         ... 0.4008617  0.         0.00203271]
#  [0.         0.51798767 0.         ... 0.01530892 0.         0.        ]
#  [0.         0.16846026 0.         ... 0.492294   0.         0.        ]]
# counter:
# 19210
# label:benign
# counter:
# 19211
# label:benign
# counter:
# 19212
# label:benign
# counter:
# 19213
# label:benign
# counter:
# 19214
# label:benign
# counter:
# 19215
# label:benign
# counter:
# 19216
# label:benign
# counter:
# 19217
# label:benign
# counter:
# 19218
# label:benign
# counter:
# 19219
# label:benign
# [[0.         0.62171775 0.         ... 0.11577822 0.         0.        ]
#  [0.         0.48827097 0.         ... 0.         0.         0.        ]
#  [0.         1.1204556  0.         ... 0.06272841 0.         0.        ]
#  ...
#  [0.         1.245528   0.         ... 0.5085568  0.         0.        ]
#  [0.         0.9233098  0.         ... 0.03703397 0.         0.        ]
#  [0.         0.01203501 0.         ... 0.003975   0.         0.        ]]
# counter:
# 19220
# label:benign
# counter:
# 19221
# label:benign
# counter:
# 19222
# label:benign
# counter:
# 19223
# label:benign
# counter:
# 19224
# label:benign
# counter:
# 19225
# label:benign
# counter:
# 19226
# label:benign
# counter:
# 19227
# label:benign
# counter:
# 19228
# label:benign
# counter:
# 19229
# label:benign
# [[0.         0.836277   0.         ... 0.2160218  0.00454002 0.        ]
#  [0.         0.4507134  0.         ... 0.05957195 0.         0.        ]
#  [0.         1.7543861  0.         ... 0.7553906  0.         0.        ]
#  ...
#  [0.         0.6860024  0.         ... 0.06393147 0.         0.        ]
#  [0.         0.23912406 0.         ... 0.46605814 0.         0.        ]
#  [0.         0.51669407 0.         ... 0.0157122  0.         0.        ]]
# counter:
# 19230
# label:benign
# counter:
# 19231
# label:benign
# counter:
# 19232
# label:benign
# counter:
# 19233
# label:benign
# counter:
# 19234
# label:benign
# counter:
# 19235
# label:benign
# counter:
# 19236
# label:benign
# counter:
# 19237
# label:benign
# counter:
# 19238
# label:benign
# counter:
# 19239
# label:benign
# [[0.0000000e+00 1.7599009e-01 0.0000000e+00 ... 1.5991101e-01
#   2.1045415e-02 0.0000000e+00]
#  [0.0000000e+00 1.7259634e+00 0.0000000e+00 ... 6.6356204e-02
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 1.8518183e-01 0.0000000e+00 ... 7.6044351e-02
#   0.0000000e+00 5.0139137e-02]
#  ...
#  [0.0000000e+00 3.4823585e-01 0.0000000e+00 ... 8.9587308e-02
#   0.0000000e+00 3.3700660e-02]
#  [1.1015488e-02 1.1997500e-03 0.0000000e+00 ... 2.8022438e-01
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 1.5416317e+00 0.0000000e+00 ... 8.5913904e-02
#   0.0000000e+00 0.0000000e+00]]
# counter:
# 19240
# label:benign
# counter:
# 19241
# label:benign
# counter:
# 19242
# label:benign
# counter:
# 19243
# label:benign
# counter:
# 19244
# label:benign
# counter:
# 19245
# label:benign
# counter:
# 19246
# label:benign
# counter:
# 19247
# label:benign
# counter:
# 19248
# label:benign
# counter:
# 19249
# label:benign
# [[0.         0.75653315 0.         ... 0.07081121 0.         0.0701932 ]
#  [0.         0.7230184  0.         ... 0.0634199  0.         0.        ]
#  [0.         0.         0.         ... 0.5587859  0.         0.00882465]
#  ...
#  [0.         0.25849822 0.         ... 0.02985457 0.         0.        ]
#  [0.         0.94117504 0.         ... 1.2084545  0.         0.        ]
#  [0.         0.8429555  0.         ... 0.01451926 0.         0.        ]]
# counter:
# 19250
# label:benign
# counter:
# 19251
# label:benign
# counter:
# 19252
# label:benign
# counter:
# 19253
# label:benign
# counter:
# 19254
# label:benign
# counter:
# 19255
# label:benign
# counter:
# 19256
# label:benign
# counter:
# 19257
# label:benign
# counter:
# 19258
# label:benign
# counter:
# 19259
# label:benign
# [[0.         0.45574078 0.         ... 0.46186092 0.         0.        ]
#  [0.         0.4055024  0.         ... 0.         0.         0.00898396]
#  [0.         0.7772972  0.         ... 0.5895778  0.         0.        ]
#  ...
#  [0.         0.9406468  0.         ... 0.67570645 0.         0.        ]
#  [0.         0.40009892 0.         ... 0.05675531 0.         0.        ]
#  [0.         0.42773232 0.         ... 0.35442165 0.         0.00722516]]
# counter:
# 19260
# label:benign
# counter:
# 19261
# label:benign
# counter:
# 19262
# label:benign
# counter:
# 19263
# label:benign
# counter:
# 19264
# label:benign
# counter:
# 19265
# label:benign
# counter:
# 19266
# label:benign
# counter:
# 19267
# label:benign
# counter:
# 19268
# label:benign
# counter:
# 19269
# label:benign
# [[0.0000000e+00 8.7108332e-01 0.0000000e+00 ... 1.4907314e-01
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 4.5650461e-01 0.0000000e+00 ... 3.9426106e-01
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 7.7074277e-01 0.0000000e+00 ... 4.5638481e-01
#   0.0000000e+00 0.0000000e+00]
#  ...
#  [0.0000000e+00 1.1381534e+00 0.0000000e+00 ... 1.7393082e-01
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 1.6132182e+00 0.0000000e+00 ... 1.9707374e-01
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 5.4360878e-01 0.0000000e+00 ... 4.9122720e-04
#   0.0000000e+00 4.2276941e-02]]
# counter:
# 19270
# label:benign
# counter:
# 19271
# label:benign
# counter:
# 19272
# label:benign
# counter:
# 19273
# label:benign
# counter:
# 19274
# label:benign
# counter:
# 19275
# label:benign
# counter:
# 19276
# label:benign
# counter:
# 19277
# label:benign
# counter:
# 19278
# label:benign
# counter:
# 19279
# label:benign
# [[0.0000000e+00 1.2786314e-01 0.0000000e+00 ... 2.7678627e-01
#   0.0000000e+00 1.9471072e-02]
#  [0.0000000e+00 3.7365249e-01 9.1679872e-04 ... 1.8461785e-01
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 4.2479250e-01 0.0000000e+00 ... 3.2534307e-01
#   0.0000000e+00 0.0000000e+00]
#  ...
#  [0.0000000e+00 5.1109254e-01 0.0000000e+00 ... 2.9089436e-02
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 1.4045119e+00 0.0000000e+00 ... 2.5421482e-01
#   0.0000000e+00 0.0000000e+00]
#  [5.4633763e-04 7.7842587e-01 0.0000000e+00 ... 0.0000000e+00
#   0.0000000e+00 8.9520700e-03]]
# counter:
# 19280
# label:benign
# counter:
# 19281
# label:benign
# counter:
# 19282
# label:benign
# counter:
# 19283
# label:benign
# counter:
# 19284
# label:benign
# counter:
# 19285
# label:benign
# counter:
# 19286
# label:benign
# counter:
# 19287
# label:benign
# counter:
# 19288
# label:benign
# counter:
# 19289
# label:benign
# [[0.0000000e+00 1.7400873e+00 0.0000000e+00 ... 7.2069347e-01
#   0.0000000e+00 1.1993797e-03]
#  [0.0000000e+00 1.1701508e+00 0.0000000e+00 ... 3.7633961e-01
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 1.0212814e+00
#   0.0000000e+00 0.0000000e+00]
#  ...
#  [0.0000000e+00 6.4335954e-01 0.0000000e+00 ... 1.3690211e-01
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 6.7936856e-01 0.0000000e+00 ... 6.0906500e-01
#   0.0000000e+00 2.9767131e-02]
#  [0.0000000e+00 6.2711620e-01 0.0000000e+00 ... 4.0402192e-01
#   0.0000000e+00 0.0000000e+00]]
# counter:
# 19290
# label:benign
# counter:
# 19291
# label:benign
# counter:
# 19292
# label:benign
# counter:
# 19293
# label:benign
# counter:
# 19294
# label:benign
# counter:
# 19295
# label:benign
# counter:
# 19296
# label:benign
# counter:
# 19297
# label:benign
# counter:
# 19298
# label:benign
# counter:
# 19299
# label:benign
# [[0.         1.1530583  0.         ... 0.17464827 0.         0.        ]
#  [0.         0.87253875 0.         ... 0.59431756 0.06544078 0.        ]
#  [0.         0.14734973 0.         ... 0.01418624 0.         0.        ]
#  ...
#  [0.         0.3291992  0.         ... 0.5806349  0.         0.        ]
#  [0.         0.25230458 0.         ... 0.0129873  0.         0.02590046]
#  [0.         0.53229195 0.         ... 0.07348347 0.         0.00560392]]
# counter:
# 19300
# label:benign
# counter:
# 19301
# label:benign
# counter:
# 19302
# label:benign
# counter:
# 19303
# label:benign
# counter:
# 19304
# label:benign
# counter:
# 19305
# label:benign
# counter:
# 19306
# label:benign
# counter:
# 19307
# label:benign
# counter:
# 19308
# label:benign
# counter:
# 19309
# label:benign
# [[0.         0.25857726 0.         ... 0.5259944  0.         0.        ]
#  [0.         0.22805502 0.         ... 0.00599317 0.         0.        ]
#  [0.         0.5831291  0.         ... 0.14386699 0.         0.        ]
#  ...
#  [0.         2.0061848  0.         ... 0.01226816 0.         0.        ]
#  [0.         0.2883961  0.         ... 0.15144423 0.         0.        ]
#  [0.         0.7459745  0.         ... 0.40565708 0.         0.        ]]
# counter:
# 19310
# label:benign
# counter:
# 19311
# label:benign
# counter:
# 19312
# label:benign
# counter:
# 19313
# label:benign
# counter:
# 19314
# label:benign
# counter:
# 19315
# label:benign
# counter:
# 19316
# label:benign
# counter:
# 19317
# label:benign
# counter:
# 19318
# label:benign
# counter:
# 19319
# label:benign
# [[0.         0.8081523  0.         ... 0.22998372 0.         0.04338676]
#  [0.         0.26135987 0.         ... 0.16485792 0.         0.        ]
#  [0.         0.69125056 0.         ... 0.15997043 0.         0.        ]
#  ...
#  [0.         0.2887863  0.         ... 0.         0.         0.00958109]
#  [0.         0.60532945 0.         ... 0.31471664 0.         0.        ]
#  [0.         1.2311196  0.         ... 0.18439317 0.         0.        ]]
# counter:
# 19320
# label:benign
# counter:
# 19321
# label:benign
# counter:
# 19322
# label:benign
# counter:
# 19323
# label:benign
# counter:
# 19324
# label:benign
# counter:
# 19325
# label:benign
# counter:
# 19326
# label:benign
# counter:
# 19327
# label:benign
# counter:
# 19328
# label:benign
# counter:
# 19329
# label:benign
# [[0.0000000e+00 7.2242486e-01 0.0000000e+00 ... 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 1.1855967e+00 0.0000000e+00 ... 4.0849730e-02
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 9.9101001e-01 0.0000000e+00 ... 5.4675959e-02
#   0.0000000e+00 0.0000000e+00]
#  ...
#  [0.0000000e+00 4.0024146e-01 0.0000000e+00 ... 2.6995325e-02
#   0.0000000e+00 5.6218561e-02]
#  [0.0000000e+00 5.2328157e-01 0.0000000e+00 ... 2.5891569e-01
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 1.4007217e-01 0.0000000e+00 ... 7.0951006e-04
#   0.0000000e+00 0.0000000e+00]]
# counter:
# 19330
# label:benign
# counter:
# 19331
# label:benign
# counter:
# 19332
# label:benign
# counter:
# 19333
# label:benign
# counter:
# 19334
# label:benign
# counter:
# 19335
# label:benign
# counter:
# 19336
# label:benign
# counter:
# 19337
# label:benign
# counter:
# 19338
# label:benign
# counter:
# 19339
# label:benign
# [[0.         0.50321543 0.07294465 ... 0.03024935 0.         0.        ]
#  [0.         0.9747323  0.         ... 0.38405877 0.         0.        ]
#  [0.         0.87701696 0.         ... 1.4874853  0.         0.02663755]
#  ...
#  [0.         0.3214857  0.         ... 0.14339812 0.         0.        ]
#  [0.         0.6427491  0.         ... 0.13387996 0.         0.        ]
#  [0.         0.39685607 0.         ... 0.3333308  0.         0.        ]]
# counter:
# 19340
# label:benign
# counter:
# 19341
# label:benign
# counter:
# 19342
# label:benign
# counter:
# 19343
# label:benign
# counter:
# 19344
# label:benign
# counter:
# 19345
# label:benign
# counter:
# 19346
# label:benign
# counter:
# 19347
# label:benign
# counter:
# 19348
# label:benign
# counter:
# 19349
# label:benign
# [[0.         0.36072922 0.         ... 0.10699607 0.         0.        ]
#  [0.         1.0562408  0.         ... 1.2969     0.         0.        ]
#  [0.         1.808675   0.         ... 0.40464786 0.         0.        ]
#  ...
#  [0.         1.6855104  0.         ... 0.03894701 0.         0.        ]
#  [0.         1.339586   0.         ... 0.2581402  0.         0.03547334]
#  [0.         0.80345225 0.07832247 ... 0.20159072 0.         0.        ]]
# counter:
# 19350
# label:benign
# counter:
# 19351
# label:benign
# counter:
# 19352
# label:benign
# counter:
# 19353
# label:benign
# counter:
# 19354
# label:benign
# counter:
# 19355
# label:benign
# counter:
# 19356
# label:benign
# counter:
# 19357
# label:benign
# counter:
# 19358
# label:benign
# counter:
# 19359
# label:benign
# [[0.         0.40125924 0.         ... 0.3325315  0.         0.        ]
#  [0.         1.415783   0.         ... 0.74958545 0.         0.        ]
#  [0.         0.22516027 0.         ... 0.10751108 0.         0.        ]
#  ...
#  [0.         0.44393197 0.         ... 0.00763272 0.         0.        ]
#  [0.         0.94091904 0.         ... 0.1618122  0.         0.        ]
#  [0.         1.767812   0.         ... 0.01837374 0.         0.00639435]]
# counter:
# 19360
# label:benign
# counter:
# 19361
# label:benign
# counter:
# 19362
# label:benign
# counter:
# 19363
# label:benign
# counter:
# 19364
# label:benign
# counter:
# 19365
# label:benign
# counter:
# 19366
# label:benign
# counter:
# 19367
# label:benign
# counter:
# 19368
# label:benign
# counter:
# 19369
# label:benign
# [[0.00000000e+00 5.07593870e-01 0.00000000e+00 ... 1.09613605e-01
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 1.44050229e+00 0.00000000e+00 ... 2.05308065e-01
#   0.00000000e+00 4.27137566e-04]
#  [0.00000000e+00 2.99354702e-01 1.18178818e-02 ... 3.85874361e-02
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [0.00000000e+00 1.80029345e+00 0.00000000e+00 ... 5.34150779e-01
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 6.68588653e-02 0.00000000e+00 ... 2.73821037e-02
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 6.34846568e-01 0.00000000e+00 ... 3.59863698e-01
#   0.00000000e+00 0.00000000e+00]]
# counter:
# 19370
# label:benign
# counter:
# 19371
# label:benign
# counter:
# 19372
# label:benign
# counter:
# 19373
# label:benign
# counter:
# 19374
# label:benign
# counter:
# 19375
# label:benign
# counter:
# 19376
# label:benign
# counter:
# 19377
# label:benign
# counter:
# 19378
# label:benign
# counter:
# 19379
# label:benign
# [[0.         0.7461855  0.         ... 0.25741383 0.         0.        ]
#  [0.         0.9692161  0.         ... 0.1198733  0.         0.00673524]
#  [0.         0.39195338 0.         ... 0.2135325  0.         0.        ]
#  ...
#  [0.         0.53833383 0.         ... 0.         0.         0.00377013]
#  [0.         0.06355444 0.         ... 0.03462341 0.         0.        ]
#  [0.         1.4239119  0.         ... 0.12192477 0.         0.        ]]
# counter:
# 19380
# label:benign
# counter:
# 19381
# label:benign
# counter:
# 19382
# label:benign
# counter:
# 19383
# label:benign
# counter:
# 19384
# label:benign
# counter:
# 19385
# label:benign
# counter:
# 19386
# label:benign
# counter:
# 19387
# label:benign
# counter:
# 19388
# label:benign
# counter:
# 19389
# label:benign
# [[0.         1.5270793  0.         ... 0.24334095 0.         0.        ]
#  [0.         1.05145    0.         ... 0.104776   0.         0.00897924]
#  [0.         0.534271   0.         ... 0.46711513 0.         0.        ]
#  ...
#  [0.         0.5222975  0.         ... 0.1292284  0.         0.        ]
#  [0.         0.15423138 0.         ... 0.13106039 0.         0.        ]
#  [0.         1.3974365  0.         ... 0.1369426  0.         0.        ]]
# counter:
# 19390
# label:benign
# counter:
# 19391
# label:benign
# counter:
# 19392
# label:benign
# counter:
# 19393
# label:benign
# counter:
# 19394
# label:benign
# counter:
# 19395
# label:benign
# counter:
# 19396
# label:benign
# counter:
# 19397
# label:benign
# counter:
# 19398
# label:benign
# counter:
# 19399
# label:benign
# [[0.         0.7106719  0.         ... 0.5507817  0.         0.        ]
#  [0.         0.42161304 0.         ... 0.23738518 0.         0.01679422]
#  [0.         1.5910115  0.         ... 0.5515939  0.         0.        ]
#  ...
#  [0.         0.07261318 0.         ... 0.37086955 0.         0.        ]
#  [0.         0.62523377 0.         ... 0.12264362 0.         0.        ]
#  [0.         0.41059408 0.         ... 0.90056515 0.00477696 0.        ]]
# counter:
# 19400
# label:benign
# counter:
# 19401
# label:benign
# counter:
# 19402
# label:benign
# counter:
# 19403
# label:benign
# counter:
# 19404
# label:benign
# counter:
# 19405
# label:benign
# counter:
# 19406
# label:benign
# counter:
# 19407
# label:benign
# counter:
# 19408
# label:benign
# counter:
# 19409
# label:benign
# [[0.         0.38566962 0.         ... 0.00772913 0.         0.        ]
#  [0.015689   0.9235217  0.05590364 ... 0.03166852 0.         0.        ]
#  [0.         1.0032668  0.         ... 0.13946018 0.         0.        ]
#  ...
#  [0.         0.425034   0.         ... 0.29637474 0.         0.        ]
#  [0.         1.2891027  0.         ... 0.16173209 0.         0.        ]
#  [0.         1.4033265  0.         ... 0.1749262  0.         0.        ]]
# counter:
# 19410
# label:benign
# counter:
# 19411
# label:benign
# counter:
# 19412
# label:benign
# counter:
# 19413
# label:benign
# counter:
# 19414
# label:benign
# counter:
# 19415
# label:benign
# counter:
# 19416
# label:benign
# counter:
# 19417
# label:benign
# counter:
# 19418
# label:benign
# counter:
# 19419
# label:benign
# [[0.         0.00925587 0.         ... 0.44982666 0.         0.        ]
#  [0.         0.79374075 0.         ... 0.294398   0.         0.        ]
#  [0.         0.3154852  0.         ... 0.04765451 0.         0.        ]
#  ...
#  [0.         0.32659262 0.         ... 0.10542405 0.         0.        ]
#  [0.         0.98684025 0.         ... 0.11697212 0.         0.        ]
#  [0.         0.8169141  0.         ... 0.29757425 0.         0.        ]]
# counter:
# 19420
# label:benign
# counter:
# 19421
# label:benign
# counter:
# 19422
# label:benign
# counter:
# 19423
# label:benign
# counter:
# 19424
# label:benign
# counter:
# 19425
# label:benign
# counter:
# 19426
# label:benign
# counter:
# 19427
# label:benign
# counter:
# 19428
# label:benign
# counter:
# 19429
# label:benign
# [[0.         0.8054193  0.         ... 0.06590663 0.         0.00709264]
#  [0.         0.8420382  0.         ... 0.28161478 0.         0.        ]
#  [0.         0.38890123 0.         ... 0.01194526 0.         0.        ]
#  ...
#  [0.         0.8954801  0.         ... 0.35624582 0.         0.        ]
#  [0.         0.1961671  0.         ... 0.5313166  0.         0.        ]
#  [0.         0.42974156 0.         ... 0.02360024 0.         0.01795829]]
# counter:
# 19430
# label:benign
# counter:
# 19431
# label:benign
# counter:
# 19432
# label:benign
# counter:
# 19433
# label:benign
# counter:
# 19434
# label:benign
# counter:
# 19435
# label:benign
# counter:
# 19436
# label:benign
# counter:
# 19437
# label:benign
# counter:
# 19438
# label:benign
# counter:
# 19439
# label:benign
# [[0.         2.1283705  0.         ... 0.4185153  0.         0.        ]
#  [0.         0.44151026 0.         ... 0.         0.         0.        ]
#  [0.         0.76194143 0.         ... 0.         0.         0.        ]
#  ...
#  [0.         1.0562463  0.         ... 0.31647617 0.         0.        ]
#  [0.         1.4787662  0.         ... 0.49942118 0.         0.        ]
#  [0.         1.0754877  0.         ... 0.09218901 0.         0.        ]]
# counter:
# 19440
# label:benign
# counter:
# 19441
# label:benign
# counter:
# 19442
# label:benign
# counter:
# 19443
# label:benign
# counter:
# 19444
# label:benign
# counter:
# 19445
# label:benign
# counter:
# 19446
# label:benign
# counter:
# 19447
# label:benign
# counter:
# 19448
# label:benign
# counter:
# 19449
# label:benign
# [[0.         1.3212389  0.         ... 0.2200611  0.         0.00745641]
#  [0.00576981 0.99998647 0.         ... 0.         0.         0.        ]
#  [0.         0.7403887  0.         ... 0.12471943 0.         0.        ]
#  ...
#  [0.         0.8814166  0.         ... 0.20369117 0.07058432 0.        ]
#  [0.         0.73704255 0.         ... 0.09933545 0.         0.        ]
#  [0.         0.27291998 0.         ... 0.09690009 0.         0.        ]]
# counter:
# 19450
# label:benign
# counter:
# 19451
# label:benign
# counter:
# 19452
# label:benign
# counter:
# 19453
# label:benign
# counter:
# 19454
# label:benign
# counter:
# 19455
# label:benign
# counter:
# 19456
# label:benign
# counter:
# 19457
# label:benign
# counter:
# 19458
# label:benign
# counter:
# 19459
# label:benign
# [[0.         1.0162756  0.         ... 0.02945649 0.         0.        ]
#  [0.         1.8424832  0.         ... 0.6384841  0.         0.        ]
#  [0.         0.58374715 0.         ... 0.5192427  0.         0.        ]
#  ...
#  [0.         0.26817003 0.         ... 0.09489125 0.         0.06201472]
#  [0.         1.155701   0.         ... 0.10077254 0.         0.        ]
#  [0.         0.436013   0.         ... 0.21171895 0.         0.        ]]
# counter:
# 19460
# label:benign
# counter:
# 19461
# label:benign
# counter:
# 19462
# label:benign
# counter:
# 19463
# label:benign
# counter:
# 19464
# label:benign
# counter:
# 19465
# label:benign
# counter:
# 19466
# label:benign
# counter:
# 19467
# label:benign
# counter:
# 19468
# label:benign
# counter:
# 19469
# label:benign
# [[0.00000000e+00 1.66150570e+00 0.00000000e+00 ... 5.56183122e-02
#   0.00000000e+00 1.28155025e-02]
#  [0.00000000e+00 1.63064018e-01 0.00000000e+00 ... 1.49704088e-02
#   0.00000000e+00 1.46131404e-03]
#  [0.00000000e+00 1.59225368e+00 0.00000000e+00 ... 2.80904561e-01
#   0.00000000e+00 8.82465485e-03]
#  ...
#  [0.00000000e+00 2.61579037e-01 0.00000000e+00 ... 1.13913558e-01
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 1.13184929e+00 0.00000000e+00 ... 2.66039222e-01
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 8.12995657e-02 0.00000000e+00 ... 4.84740734e-02
#   0.00000000e+00 1.40885189e-01]]
# counter:
# 19470
# label:benign
# counter:
# 19471
# label:benign
# counter:
# 19472
# label:benign
# counter:
# 19473
# label:benign
# counter:
# 19474
# label:benign
# counter:
# 19475
# label:benign
# counter:
# 19476
# label:benign
# counter:
# 19477
# label:benign
# counter:
# 19478
# label:benign
# counter:
# 19479
# label:benign
# [[0.         1.5049523  0.         ... 0.05644156 0.         0.18125312]
#  [0.         0.03056538 0.         ... 0.53851175 0.         0.0269373 ]
#  [0.         0.8901817  0.         ... 0.13786511 0.         0.        ]
#  ...
#  [0.         0.09177523 0.         ... 0.16027881 0.         0.        ]
#  [0.         0.4909424  0.         ... 0.38412958 0.         0.04896058]
#  [0.         0.88763964 0.         ... 0.02765756 0.         0.05643544]]
# counter:
# 19480
# label:benign
# counter:
# 19481
# label:benign
# counter:
# 19482
# label:benign
# counter:
# 19483
# label:benign
# counter:
# 19484
# label:benign
# counter:
# 19485
# label:benign
# counter:
# 19486
# label:benign
# counter:
# 19487
# label:benign
# counter:
# 19488
# label:benign
# counter:
# 19489
# label:benign
# [[0.00000000e+00 9.42173481e-01 0.00000000e+00 ... 1.21436059e-01
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 5.37645340e-01 0.00000000e+00 ... 1.21777505e-02
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 1.10456502e+00 0.00000000e+00 ... 1.24048645e-04
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [0.00000000e+00 4.27872002e-01 0.00000000e+00 ... 8.46589684e-01
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 6.62774742e-01 0.00000000e+00 ... 1.33647963e-01
#   0.00000000e+00 2.42019482e-02]
# ...
# counter:
# 19949
# label:benign
# [[0.         1.1633453  0.         ... 0.07408616 0.         0.        ]
#  [0.         0.09560862 0.         ... 0.22203127 0.         0.05568282]
#  [0.         1.0246007  0.         ... 0.06440694 0.         0.        ]
#  ...
#  [0.         0.95563805 0.         ... 0.12187032 0.         0.        ]
#  [0.         0.58053637 0.         ... 0.6886981  0.         0.        ]
#  [0.         0.794436   0.         ... 0.48107627 0.         0.        ]]
# counter:
# 19950
# label:benign
# counter:
# 19951
# label:benign
# counter:
# 19952
# label:benign
# counter:
# 19953
# label:benign
# counter:
# 19954
# label:benign
# counter:
# 19955
# label:benign
# counter:
# 19956
# label:benign
# counter:
# 19957
# label:benign
# counter:
# 19958
# label:benign
# counter:
# 19959
# label:benign
# [[0.         0.11229137 0.         ... 0.00477793 0.01760117 0.06371205]
#  [0.         1.1560898  0.         ... 0.4920813  0.         0.08250024]
#  [0.         1.1785425  0.         ... 0.27781522 0.         0.        ]
#  ...
#  [0.         0.3581922  0.         ... 0.5560412  0.         0.        ]
#  [0.         1.295389   0.         ... 0.06370842 0.         0.        ]
#  [0.         0.2875736  0.         ... 0.1120289  0.         0.        ]]
# counter:
# 19960
# label:benign
# counter:
# 19961
# label:benign
# counter:
# 19962
# label:benign
# counter:
# 19963
# label:benign
# counter:
# 19964
# label:benign
# counter:
# 19965
# label:benign
# counter:
# 19966
# label:benign
# counter:
# 19967
# label:benign
# counter:
# 19968
# label:benign
# counter:
# 19969
# label:benign
# [[0.         1.4572088  0.         ... 0.4623217  0.         0.        ]
#  [0.         0.09191907 0.         ... 0.20139784 0.         0.        ]
#  [0.         0.7717906  0.         ... 0.         0.         0.        ]
#  ...
#  [0.0152234  0.         0.         ... 0.00732977 0.02060356 0.        ]
#  [0.         0.89264256 0.         ... 0.         0.         0.        ]
#  [0.         0.42025363 0.         ... 0.24870783 0.         0.        ]]
# counter:
# 19970
# label:benign
# counter:
# 19971
# label:benign
# counter:
# 19972
# label:benign
# counter:
# 19973
# label:benign
# counter:
# 19974
# label:benign
# counter:
# 19975
# label:benign
# counter:
# 19976
# label:benign
# counter:
# 19977
# label:benign
# counter:
# 19978
# label:benign
# counter:
# 19979
# label:benign
# [[0.         0.72132283 0.02863944 ... 0.04280419 0.         0.        ]
#  [0.         1.4327103  0.         ... 0.1391909  0.         0.00828887]
#  [0.         1.3060068  0.         ... 0.68546987 0.         0.        ]
#  ...
#  [0.         0.21132481 0.04036344 ... 0.17335312 0.         0.01744756]
#  [0.         0.48439774 0.         ... 0.27703792 0.         0.        ]
#  [0.         1.452528   0.         ... 0.34563202 0.         0.        ]]
# counter:
# 19980
# label:benign
# counter:
# 19981
# label:benign
# counter:
# 19982
# label:benign
# counter:
# 19983
# label:benign
# counter:
# 19984
# label:benign
# counter:
# 19985
# label:benign
# counter:
# 19986
# label:benign
# counter:
# 19987
# label:benign
# counter:
# 19988
# label:benign
# counter:
# 19989
# label:benign
# [[0.         0.62697184 0.         ... 0.3335134  0.         0.        ]
#  [0.         0.31124157 0.         ... 0.43426186 0.         0.        ]
#  [0.         1.1000762  0.         ... 0.77730125 0.         0.        ]
#  ...
#  [0.         0.62958455 0.         ... 0.41444677 0.         0.00707801]
#  [0.         0.2110271  0.         ... 0.02680155 0.         0.0080479 ]
#  [0.         0.2622251  0.         ... 0.04812741 0.         0.08808938]]
# counter:
# 19990
# label:benign
# counter:
# 19991
# label:benign
# counter:
# 19992
# label:benign
# counter:
# 19993
# label:benign
# counter:
# 19994
# label:benign
# counter:
# 19995
# label:benign
# counter:
# 19996
# label:benign
# counter:
# 19997
# label:benign
# counter:
# 19998
# label:benign
# counter:
# 19999
# label:benign
# [[0.         0.8505817  0.         ... 0.19364718 0.         0.03163115]
#  [0.         0.8199091  0.         ... 0.09226379 0.         0.        ]
#  [0.         0.02566943 0.         ... 0.26500684 0.         0.        ]
#  ...
#  [0.         2.3000948  0.         ... 0.3620506  0.         0.0039257 ]
#  [0.         1.5775758  0.         ... 0.3100681  0.         0.        ]
#  [0.         0.2556821  0.         ... 0.         0.         0.        ]]
# counter:
# 20000
# label:benign
# counter:
# 20001
# label:benign
# counter:
# 20002
# label:benign
# counter:
# 20003
# label:benign
# counter:
# 20004
# label:benign
# counter:
# 20005
# label:benign
# counter:
# 20006
# label:benign
# counter:
# 20007
# label:benign
# counter:
# 20008
# label:benign
# counter:
# 20009
# label:benign
# [[0.         1.0675614  0.         ... 0.10684567 0.         0.01024904]
#  [0.         0.00405648 0.         ... 0.         0.0581788  0.00809101]
#  [0.         0.49418396 0.         ... 0.         0.         0.        ]
#  ...
#  [0.         1.7291633  0.         ... 0.49768665 0.         0.04105953]
#  [0.         0.1667425  0.03997764 ... 0.54688156 0.04511513 0.01587439]
#  [0.         0.55749434 0.         ... 0.01968086 0.         0.02537321]]
# counter:
# 20010
# label:benign
# counter:
# 20011
# label:benign
# counter:
# 20012
# label:benign
# counter:
# 20013
# label:benign
# counter:
# 20014
# label:benign
# counter:
# 20015
# label:benign
# counter:
# 20016
# label:benign
# counter:
# 20017
# label:benign
# counter:
# 20018
# label:benign
# counter:
# 20019
# label:benign
# [[0.         0.00426928 0.         ... 0.         0.         0.        ]
#  [0.         1.0483527  0.         ... 0.         0.         0.        ]
#  [0.         0.2605579  0.         ... 0.06857659 0.0092728  0.        ]
#  ...
#  [0.         0.73642546 0.         ... 0.29213655 0.         0.        ]
#  [0.         0.4785282  0.         ... 0.02520801 0.         0.        ]
#  [0.         0.72844154 0.         ... 0.02480397 0.         0.        ]]
# counter:
# 20020
# label:benign
# counter:
# 20021
# label:benign
# counter:
# 20022
# label:benign
# counter:
# 20023
# label:benign
# counter:
# 20024
# label:benign
# counter:
# 20025
# label:benign
# counter:
# 20026
# label:benign
# counter:
# 20027
# label:benign
# counter:
# 20028
# label:benign
# counter:
# 20029
# label:benign
# [[0.         1.0864553  0.         ... 0.87262756 0.         0.        ]
#  [0.         1.1942424  0.         ... 0.35882723 0.         0.        ]
#  [0.         1.7198344  0.         ... 0.18165258 0.         0.        ]
#  ...
#  [0.         1.2580268  0.         ... 0.5341716  0.         0.        ]
#  [0.         0.6759508  0.         ... 0.01741231 0.         0.        ]
#  [0.         0.31931487 0.         ... 0.39526215 0.         0.        ]]
# counter:
# 20030
# label:benign
# counter:
# 20031
# label:benign
# counter:
# 20032
# label:benign
# counter:
# 20033
# label:benign
# counter:
# 20034
# label:benign
# counter:
# 20035
# label:benign
# counter:
# 20036
# label:benign
# counter:
# 20037
# label:benign
# counter:
# 20038
# label:benign
# counter:
# 20039
# label:benign
# [[0.         0.20131303 0.         ... 0.03335701 0.         0.        ]
#  [0.         0.41012776 0.         ... 0.         0.01392529 0.01476412]
#  [0.         1.2220852  0.         ... 0.40016407 0.         0.        ]
#  ...
#  [0.         0.01530328 0.         ... 0.0755413  0.         0.        ]
#  [0.         1.2924594  0.         ... 0.08112971 0.         0.00463088]
#  [0.         0.37602425 0.         ... 0.39773348 0.         0.08429161]]
# counter:
# 20040
# label:benign
# counter:
# 20041
# label:benign
# counter:
# 20042
# label:benign
# counter:
# 20043
# label:benign
# counter:
# 20044
# label:benign
# counter:
# 20045
# label:benign
# counter:
# 20046
# label:benign
# counter:
# 20047
# label:benign
# counter:
# 20048
# label:benign
# counter:
# 20049
# label:benign
# [[0.0000000e+00 3.8128978e-01 0.0000000e+00 ... 0.0000000e+00
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 1.3546798e+00 0.0000000e+00 ... 1.1135395e-01
#   0.0000000e+00 0.0000000e+00]
#  [2.2165472e-02 8.0360370e-03 0.0000000e+00 ... 5.0017226e-02
#   1.2391903e-01 0.0000000e+00]
#  ...
#  [0.0000000e+00 1.1250529e+00 0.0000000e+00 ... 9.2640758e-02
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 4.3041483e-01 0.0000000e+00 ... 1.1527803e-01
#   0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 4.2359382e-01 0.0000000e+00 ... 8.8116743e-02
#   0.0000000e+00 5.3916371e-04]]
# counter:
# 20050
# label:benign
# counter:
# 20051
# label:benign
# counter:
# 20052
# label:benign
# counter:
# 20053
# label:benign
# counter:
# 20054
# label:benign
# counter:
# 20055
# label:benign
# counter:
# 20056
# label:benign
# counter:
# 20057
# label:benign
# counter:
# 20058
# label:benign
# counter:
# 20059
# label:benign
# [[0.         0.1322331  0.         ... 0.04787766 0.         0.        ]
#  [0.         0.09399481 0.         ... 0.         0.         0.        ]
#  [0.         0.28614905 0.         ... 0.22783113 0.         0.        ]
#  ...
#  [0.         0.5296387  0.         ... 0.         0.         0.        ]
#  [0.         0.41485548 0.         ... 0.20770942 0.         0.        ]
#  [0.         0.2960703  0.         ... 0.         0.         0.        ]]
# counter:
# 20060
# label:benign
# counter:
# 20061
# label:benign
# counter:
# 20062
# label:benign
# counter:
# 20063
# label:benign
# counter:
# 20064
# label:benign
# counter:
# 20065
# label:benign
# counter:
# 20066
# label:benign
# counter:
# 20067
# label:benign
# counter:
# 20068
# label:benign
# counter:
# 20069
# label:benign
# [[0.         0.5149696  0.01750586 ... 0.13415955 0.         0.01965525]
#  [0.         0.39880955 0.         ... 0.52423483 0.         0.        ]
#  [0.         0.02046718 0.         ... 0.         0.         0.        ]
#  ...
#  [0.         0.22219864 0.         ... 0.05659496 0.         0.        ]
#  [0.         0.5888857  0.         ... 0.08869553 0.         0.        ]
#  [0.         0.80931497 0.         ... 0.02728766 0.         0.        ]]
# counter:
# 20070
# label:benign
# counter:
# 20071
# label:benign
# counter:
# 20072
# label:benign
# counter:
# 20073
# label:benign
# counter:
# 20074
# label:benign
# counter:
# 20075
# label:benign
# counter:
# 20076
# label:benign
# counter:
# 20077
# label:benign
# counter:
# 20078
# label:benign
# counter:
# 20079
# label:benign
# [[0.         0.00883177 0.         ... 0.02009543 0.         0.        ]
#  [0.         1.1438925  0.         ... 0.2759126  0.         0.        ]
#  [0.         0.2348256  0.         ... 0.2110017  0.         0.        ]
#  ...
#  [0.         0.64761066 0.         ... 0.19347635 0.         0.07324531]
#  [0.         0.99157506 0.         ... 0.07977983 0.         0.        ]
#  [0.         1.3908973  0.         ... 0.11183466 0.         0.        ]]
# counter:
# 20080
# label:benign
# counter:
# 20081
# label:benign
# counter:
# 20082
# label:benign
# counter:
# 20083
# label:benign
# counter:
# 20084
# label:benign
# counter:
# 20085
# label:benign
# counter:
# 20086
# label:benign
# counter:
# 20087
# label:benign
# counter:
# 20088
# label:benign
# counter:
# 20089
# label:benign
# [[0.         1.3390111  0.         ... 0.         0.         0.        ]
#  [0.         0.5313117  0.         ... 0.04686251 0.         0.        ]
#  [0.         1.1349058  0.         ... 0.47691768 0.         0.        ]
#  ...
#  [0.         0.71438265 0.         ... 0.37185794 0.         0.        ]
#  [0.         1.4465469  0.         ... 0.2020615  0.         0.        ]
#  [0.         0.7203844  0.         ... 0.4421247  0.         0.        ]]
# counter:
# 20090
# label:benign
# counter:
# 20091
# label:benign
# counter:
# 20092
# label:benign
# counter:
# 20093
# label:benign
# counter:
# 20094
# label:benign
# counter:
# 20095
# label:benign
# counter:
# 20096
# label:benign
# counter:
# 20097
# label:benign
# counter:
# 20098
# label:benign
# counter:
# 20099
# label:benign
# [[0.         0.5664695  0.         ... 0.         0.         0.        ]
#  [0.         0.21442005 0.         ... 1.3737464  0.         0.        ]
#  [0.         0.49095365 0.         ... 0.32442707 0.         0.        ]
#  ...
#  [0.         1.2623384  0.         ... 0.49249893 0.         0.        ]
#  [0.         0.49895337 0.         ... 0.9409353  0.         0.        ]
#  [0.         1.3975768  0.         ... 0.15851378 0.         0.00171596]]
# counter:
# 20100
# label:benign
# counter:
# 20101
# label:benign
# counter:
# 20102
# label:benign
# counter:
# 20103
# label:benign
# counter:
# 20104
# label:benign
# counter:
# 20105
# label:benign
# counter:
# 20106
# label:benign
# counter:
# 20107
# label:benign
# counter:
# 20108
# label:benign
# counter:
# 20109
# label:benign
# [[0.00000000e+00 2.08476081e-01 0.00000000e+00 ... 1.53574883e-03
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 1.66166246e+00 0.00000000e+00 ... 2.99097657e-01
#   0.00000000e+00 6.46255612e-02]
#  [0.00000000e+00 1.25615382e+00 0.00000000e+00 ... 4.16844264e-02
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 7.13734269e-01 0.00000000e+00 ... 5.46322882e-01
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 1.14307985e-01 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]
# counter:
# 20110
# label:benign
# counter:
# 20111
# label:benign
# counter:
# 20112
# label:benign
# counter:
# 20113
# label:benign
# counter:
# 20114
# label:benign
# counter:
# 20115
# label:benign
# counter:
# 20116
# label:benign
# counter:
# 20117
# label:benign
# counter:
# 20118
# label:benign
# counter:
# 20119
# label:benign
# [[0.         0.         0.01483671 ... 0.06522231 0.         0.        ]
#  [0.         0.56030244 0.         ... 0.05117659 0.         0.        ]
#  [0.         0.11470875 0.         ... 0.27245903 0.         0.        ]
#  ...
#  [0.         0.35236982 0.         ... 0.31068268 0.         0.        ]
#  [0.         0.22574185 0.         ... 0.24335068 0.         0.        ]
#  [0.         0.00883705 0.         ... 0.17570324 0.         0.        ]]
# counter:
# 20120
# label:benign
# counter:
# 20121
# label:benign
# counter:
# 20122
# label:benign
# counter:
# 20123
# label:benign
# counter:
# 20124
# label:benign
# counter:
# 20125
# label:benign
# counter:
# 20126
# label:benign
# counter:
# 20127
# label:benign
# counter:
# 20128
# label:benign
# counter:
# 20129
# label:benign
# [[0.         0.9080118  0.         ... 0.0342661  0.         0.        ]
#  [0.         0.         0.         ... 0.06186467 0.         0.        ]
#  [0.         0.02304025 0.         ... 0.         0.01453668 0.        ]
#  ...
#  [0.         0.38284373 0.         ... 0.04843742 0.         0.        ]
#  [0.         0.25255576 0.         ... 0.2004502  0.         0.        ]
#  [0.         1.3703803  0.         ... 0.         0.         0.00139462]]
# counter:
# 20130
# label:benign
# counter:
# 20131
# label:benign
# counter:
# 20132
# label:benign
# counter:
# 20133
# label:benign
# counter:
# 20134
# label:benign
# counter:
# 20135
# label:benign
# counter:
# 20136
# label:benign
# counter:
# 20137
# label:benign
# counter:
# 20138
# label:benign
# counter:
# 20139
# label:benign
# [[0.         0.9797724  0.         ... 0.43389216 0.         0.        ]
#  [0.         0.42628455 0.         ... 0.5777511  0.         0.04738757]
#  [0.         0.15391907 0.         ... 0.06643873 0.         0.        ]
#  ...
#  [0.         1.1012281  0.         ... 0.26184958 0.         0.        ]
#  [0.         0.12304818 0.         ... 0.28316662 0.         0.        ]
#  [0.         1.1020491  0.         ... 0.2811442  0.         0.        ]]
# counter:
# 20140
# label:benign
# counter:
# 20141
# label:benign
# counter:
# 20142
# label:benign
# counter:
# 20143
# label:benign
# counter:
# 20144
# label:benign
# counter:
# 20145
# label:benign
# counter:
# 20146
# label:benign
# counter:
# 20147
# label:benign
# counter:
# 20148
# label:benign
# counter:
# 20149
# label:benign
# [[0.         0.38641304 0.         ... 0.13071522 0.         0.        ]
#  [0.         0.48131257 0.         ... 0.17063448 0.         0.        ]
#  [0.         1.0731155  0.         ... 0.5469546  0.         0.        ]
#  ...
#  [0.         0.45246163 0.         ... 0.19935282 0.         0.        ]
#  [0.         0.00529573 0.         ... 0.09811793 0.00610704 0.        ]
#  [0.         2.420532   0.         ... 0.41540056 0.         0.        ]]
# counter:
# 20150
# label:benign
# counter:
# 20151
# label:benign
# counter:
# 20152
# label:benign
# counter:
# 20153
# label:benign
# counter:
# 20154
# label:benign
# counter:
# 20155
# label:benign
# counter:
# 20156
# label:benign
# counter:
# 20157
# label:benign
# counter:
# 20158
# label:benign
# counter:
# 20159
# label:benign
# [[0.         0.45254266 0.         ... 0.05375773 0.         0.        ]
#  [0.         0.36545587 0.         ... 0.03736858 0.         0.        ]
#  [0.         1.2814833  0.         ... 0.03891134 0.         0.        ]
#  ...
#  [0.         0.12421645 0.         ... 0.         0.         0.12815908]
#  [0.         0.63471395 0.         ... 0.         0.         0.        ]
#  [0.         1.2773352  0.         ... 0.16279638 0.         0.        ]]
# counter:
# 20160
# label:benign
# 34082816
# 33284

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
# from tensorflow.keras.applications.resnet50 import ResNet50
# from keras.models import Model
# import keras

x = np.array(X)
y = np.array(Y)
# pre_trained_models = {}
# pre_trained_models["ResNet50"] = ResNet50(include_top=False, input_shape=(224, 224, 3), pooling="avg", weights = 'imagenet')

# temp = 0
# for layer in pre_trained_models["ResNet50"].layers:
#     layer.trainable = False
#     temp += 1

# print("tedad:")
# print(temp)
# print(sys.getsizeof(pre_trained_models["ResNet50"].layers))
# print(pre_trained_models["ResNet50"].layers)

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=0)
# X_train = pre_trained_models["ResNet50"].predict(X_train)
# X_test = pre_trained_models["ResNet50"].predict(X_test)


# print("X_train:")
# print(X_train.shape)


# print(X_train)

# print("X_test:")
# print(X_test.shape)

print("x:")
print(x.shape)



# print("koltedad:")
# o = pre_trained_models["ResNet50"].predict(x)
# print(o.shape)
# print("kol:")
# print(o)






print(x[0])
# Out:
# x:
# (33284, 1024)
# [0.         1.11739862 0.         ... 0.         0.         0.        ]

# %% [markdown]
# VGG19

# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import preprocess_input
import numpy as np

model = VGG19(weights='imagenet', pooling="avg", include_top=False)

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# 80150528/80134624 [==============================] - 0s 0us/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-519e6949f247> in <module>()
#       6 model = VGG19(weights='imagenet', pooling="avg", include_top=False)
#       7
# ----> 8 features = model.predict(x)
#       9
#      10 print(features.shape)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     100       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101   ctx.ensure_initialized()
# --> 102   return ops.EagerTensor(value, ctx.device_name, dtype)
#     103
#     104
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type list).

# %% [markdown]
# DenseNet201

# %%
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.applications.densenet import preprocess_input
import numpy as np

model = DenseNet201(weights='imagenet', pooling="avg", include_top=False)

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 1s 0us/step
# 74850304/74836368 [==============================] - 1s 0us/step
# (80, 1920)

# %% [markdown]
# ResNet101

# %%
from tensorflow.keras.applications.resnet import ResNet101
import numpy as np

model = ResNet101(include_top=False, input_shape=(224, 224, 3), pooling="avg", weights = 'imagenet')
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171450368/171446536 [==============================] - 2s 0us/step
# 171458560/171446536 [==============================] - 2s 0us/step
# (80, 2048)

# %% [markdown]
# ResNet152

# %%
from tensorflow.keras.applications.resnet import ResNet152
import numpy as np

model = ResNet152(include_top=False, input_shape=(224, 224, 3), pooling="avg", weights = 'imagenet')
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234700800/234698864 [==============================] - 3s 0us/step
# 234708992/234698864 [==============================] - 3s 0us/step
# (80, 2048)

# %% [markdown]
# InceptionV3

# %%
from tensorflow.keras.applications import InceptionV3
import numpy as np

model = InceptionV3(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# 87924736/87910968 [==============================] - 1s 0us/step
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f582ad4ea70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (80, 2048)

# %% [markdown]
# InceptionResNetV2

# %%
from tensorflow.keras.applications import InceptionResNetV2
import numpy as np

model = InceptionResNetV2(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 2s 0us/step
# 219070464/219055592 [==============================] - 2s 0us/step
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f5827e72a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (80, 1536)

# %% [markdown]
# MobileNet

# %%
from tensorflow.keras.applications import MobileNet
import numpy as np

model = MobileNet(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 0s 0us/step
# 17235968/17225924 [==============================] - 0s 0us/step
# (80, 1024)

# %% [markdown]
# NASNetMobile

# %%
from tensorflow.keras.applications import NASNetMobile
import numpy as np

model = NASNetMobile(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19996672/19993432 [==============================] - 0s 0us/step
# 20004864/19993432 [==============================] - 0s 0us/step
# (80, 1056)

# %% [markdown]
# EfficientNetB0

# %%
from tensorflow.keras.applications import EfficientNetB0
import numpy as np

model = EfficientNetB0(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16711680/16705208 [==============================] - 0s 0us/step
# 16719872/16705208 [==============================] - 0s 0us/step
# (80, 1280)

# %% [markdown]
# EfficientNetB1

# %%
from tensorflow.keras.applications import EfficientNetB1
import numpy as np

model = EfficientNetB1(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb1_notop.h5
# 27025408/27018416 [==============================] - 0s 0us/step
# 27033600/27018416 [==============================] - 0s 0us/step
# (80, 1280)

# %% [markdown]
# EfficientNetB2

# %%
from tensorflow.keras.applications import EfficientNetB2
import numpy as np

model = EfficientNetB2(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31793152/31790344 [==============================] - 0s 0us/step
# 31801344/31790344 [==============================] - 0s 0us/step
# (80, 1408)

# %% [markdown]
# EfficientNetB3

# %%
from tensorflow.keras.applications import EfficientNetB3
import numpy as np

model = EfficientNetB3(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941888/43941136 [==============================] - 0s 0us/step
# 43950080/43941136 [==============================] - 0s 0us/step
# (80, 1536)

# %% [markdown]
# EfficientNetB4

# %%
from tensorflow.keras.applications import EfficientNetB4
import numpy as np

model = EfficientNetB4(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71688192/71686520 [==============================] - 1s 0us/step
# 71696384/71686520 [==============================] - 1s 0us/step
# (80, 1792)

# %% [markdown]
# EfficientNetB5

# %%
from tensorflow.keras.applications import EfficientNetB5
import numpy as np

model = EfficientNetB5(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115269632/115263384 [==============================] - 1s 0us/step
# 115277824/115263384 [==============================] - 1s 0us/step
# (80, 2048)

# %% [markdown]
# EfficientNetB6

# %%
from tensorflow.keras.applications import EfficientNetB6
import numpy as np

model = EfficientNetB6(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb6_notop.h5
# 165240832/165234480 [==============================] - 3s 0us/step
# 165249024/165234480 [==============================] - 3s 0us/step
# (80, 2304)

# %% [markdown]
# EfficientNetB7

# %%
from tensorflow.keras.applications import EfficientNetB7
import numpy as np

model = EfficientNetB7(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258080768/258076736 [==============================] - 3s 0us/step
# 258088960/258076736 [==============================] - 3s 0us/step
# (80, 2560)

# %% [markdown]
# DenseNet121

# %%
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input
import numpy as np

model = DenseNet121(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# 29097984/29084464 [==============================] - 0s 0us/step
# (80, 1024)

# %% [markdown]
# DenseNet169

# %%
from tensorflow.keras.applications import DenseNet169
from tensorflow.keras.applications.densenet import preprocess_input
import numpy as np

model = DenseNet169(weights='imagenet', pooling="avg", include_top=False)
for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51879936/51877672 [==============================] - 1s 0us/step
# 51888128/51877672 [==============================] - 1s 0us/step
# (80, 1664)

# %% [markdown]
# VGG16

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
import numpy as np

model = VGG16(weights='imagenet', pooling="avg", include_top=False)

for layer in model.layers:
    layer.trainable = False

features = model.predict(x)

print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 58900480/58889256 [==============================] - 1s 0us/step
# (80, 512)

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
result = {}
Classifier = XGBClassifier(learning_rate=0.9, n_estimators=150, random_state=0, seed=0, gamma=0)
Classifier.fit(X_train, Y_train)
Y_pred = Classifier.predict(X_test)
print("Accuracy score : ", accuracy_score(Y_test, Y_pred))
# print(X_train)
# print(X_test)
# print(Y_train)
# print(Y_test)

# print(Y_test)
# print(Y_pred)
# Out:
# Accuracy score :  0.8159423192469457

# %% [markdown]
# ## Visualising the Linear Regression results
